# %% [markdown]
# # Full Text Frequency for BookInXisto search
# ## Script to generate a frequency table from input xlsx file
# ### BookInXisto - Getin
# ### Monique Borges <monique@ua.pt>, Gonçalo Barros, Fillipe Feitosa <fillipefeitosa@ua.pt>

# %%
# List of Imports
import pandas as pd
import json
import datetime
from urllib import parse
from urllib.parse import parse_qs, urlparse
# Out:
# /home/fillipe/anaconda3/envs/pandas/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/fillipe/anaconda3/envs/pandas/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
# load data
# Only FullText
# fullText = pd.read_excel('fulltext.xlsx')
# Complete Data
fullText = pd.read_excel('pagepath_newusers_FINAL.xlsx')

# %%
fullText
# Out:
#                                                  pagePath  \
# 0                                                       /
# 1                                     /checkout/anonymous
# 2                                                     /de
# 3                                                     /de
# 4                                                     /de
# 5                                            /de?has_js=1
# 6                                   /de/account/dashboard
# 7                                   /de/account/dashboard
# 8                                 /de/account/order-index
# 9                                 /de/account/order-index
# 10      /de/account/order-view?auth=1KZFsL6xf3A9wYyxm8...
# 11      /de/account/order-view?auth=2-dUDozJrm7-0xKa4i...
# 12      /de/account/order-view?id=539&auth=1KZFsL6xf3A...
# 13      /de/account/order-view?id=655&auth=6APo-0JBkDE...
# 14      /de/account/order-view?id=733&auth=mP1dVgYQRt5...
# 15      /de/account/order-view?id=783&auth=2-dUDozJrm7...
# 16      /de/account/order-view?id=795&auth=--9-vbRAjJC...
# 17                                         /de/cart/index
# 18                                 /de/checkout/anonymous
# 19      /de/checkout/finish?id=538&item_l=80&success=true
# 20      /de/checkout/finish?id=539&item_l=37&success=true
# 21      /de/checkout/finish?id=655&item_l=37&success=true
# 22      /de/checkout/finish?id=783&item_l=40&success=true
# 23       /de/checkout/finish?id=795&item_l=2&success=true
# 24                                     /de/checkout/index
# 25      /de/experience-catalog/experience?id=140&Exper...
# 26      /de/experience-catalog/experience?id=140&Exper...
# 27      /de/experience-catalog/experience?id=140&Exper...
# 28      /de/experience-catalog/experience?id=144&Exper...
# 29      /de/experience-catalog/experience?id=146&Exper...
# ...                                                   ...
# 137662  /pt/transaction/pay?id=842&auth=3JmzYTzMTZZntm...
# 137663  /pt/transaction/pay?id=875&auth=cs2V5mONQLwj01...
# 137664  /pt/transaction/pay?id=879&auth=kOMZGJkjXiGnKY...
# 137665  /pt/transaction/pay?id=884&auth=q7F5u4yOC__wGH...
# 137666  /pt/transaction/pay?id=888&auth=XaD2RyrvXipPCL...
# 137667  /pt/transaction/pay?id=892&auth=gsos5CW5vdTh7o...
# 137668  /pt/transaction/pay?id=894&auth=n7wwsxDlK7jnEh...
# 137669  /pt/transaction/pay?id=901&auth=Yfxjy97erRutJw...
# 137670  /pt/upalod/images/slider/mobile/aldeias-xisto-...
# 137671  /pt/upload/images/slider/mobile/aldeias-xisto-...
# 137672                            /pt/wallet/update?id=18
# 137673                                            /pt/web
# 137674                                   /pt/web/mercados
# 137675                     /pt/web/pt-pt/negocio/mercados
# 137676                                   /pt/web/wp-admin
# 137677                                       /pt/wp-admin
# 137678  /search?q=cache:tuqtXr0ArWkJ:https://bookinxis...
# 137679  /search?q=cache:yWXIF0tEJYQJ:https://bookinxis...
# 137680  /search?q=cache:yWXIF0tEJYQJ:https://bookinxis...
# 137681  /translate_c?anno=2&depth=1&hl=da&rurl=transla...
# 137682  /translate_c?anno=2&depth=1&hl=es&rurl=transla...
# 137683  /translate_c?depth=1&hl=es&prev=search&rurl=tr...
# 137684  /translate_c?depth=1&hl=es&prev=search&rurl=tr...
# 137685  /translate_c?depth=1&hl=es&prev=search&rurl=tr...
# 137686  /translate_c?depth=1&hl=es&prev=search&rurl=tr...
# 137687  /translate_c?depth=1&hl=es&prev=search&rurl=tr...
# 137688  /translate_c?depth=1&hl=es&prev=search&rurl=tr...
# 137689  /translate_c?depth=1&hl=es&prev=search&rurl=tr...
# 137690  /translate_c?depth=1&hl=es&prev=search&rurl=tr...
# 137691  /translate_c?depth=1&hl=pt-PT&prev=search&rurl...
#
#                                                 pageTitle  users  newUsers  \
# 0                                              Erro (#32)      4         2
# 1                                              Erro (#32)      1         0
# 2                                               (not set)      2         0
# 3                                           Book in Xisto     76        65
# 4                 Integrity constraint violation (#23000)      1         0
# 5                                           Book in Xisto     10         6
# 6                                       Account Dashboard      1         0
# 7                                               Kontofeld      1         0
# 8                                      Meine Bestellungen      1         0
# 9                                             Order index      1         0
# 10                                         Bestellung 538      1         0
# 11                                         Bestellung 783      1         0
# 12                                         Bestellung 539      1         1
# 13                                         Bestellung 655      5         5
# 14                                         Bestellung 733      2         1
# 15                                         Bestellung 783      1         0
# 16                                         Bestellung 795      2         1
# 17                                              Warenkorb     11         0
# 18                               Als Besucher reservieren      3         0
# 19                                          Book in Xisto      1         0
# 20                                          Book in Xisto      1         0
# 21                                          Book in Xisto      1         0
# 22                                          Book in Xisto      1         0
# 23                                          Book in Xisto      1         0
# 24                                          Book in Xisto      6         0
# 25                Integrity constraint violation (#23000)      1         1
# 26      Restaurante Bem me Quer - Menu Degustação # 2 ...      1         0
# 27      Restaurante Bem me Quer - Menu Degustação # 2 ...      1         0
# 28      Reise zu Fuß durch die Schieferdörfer (Aldeias...      1         1
# 29      Viagem em BTT pelas Aldeias do Xisto # 2 Teiln...      1         0
# ...                                                   ...    ...       ...
# 137662                                      Book in Xisto      1         0
# 137663                                      Book in Xisto      1         0
# 137664                                      Book in Xisto      1         0
# 137665                                 Bad Request (#400)      1         0
# 137666                                      Book in Xisto      1         0
# 137667                                      Book in Xisto      1         0
# 137668                                      Book in Xisto      1         0
# 137669                                      Book in Xisto      1         0
# 137670                                   Not Found (#404)      1         0
# 137671                                   Not Found (#404)      1         0
# 137672                                   Not Found (#404)      1         0
# 137673                                   Not Found (#404)      3         1
# 137674                                   Not Found (#404)      1         0
# 137675                                   Not Found (#404)      1         1
# 137676                                   Not Found (#404)      1         1
# 137677                                   Not Found (#404)      2         0
# 137678                                 Termos e Condições      1         0
# 137679                               Conditions générales      1         1
# 137680                               Conditions générales      1         1
# 137681                                      Book in Xisto      1         1
# 137682                                      Book in Xisto      1         0
# 137683            Casinha do Conde # 5 noites, 2 hóspedes      1         1
# 137684                                         Pagamentos      1         0
# 137685                                 Termos e Condições      1         0
# 137686                                      Book in Xisto      1         0
# 137687                              No encontrado (# 404)      1         0
# 137688                                      Book in Xisto      1         0
# 137689                                      Book in Xisto      1         1
# 137690                                      Book in Xisto      1         1
# 137691                                     Livro em Xisto      1         1
#
#         ContainsSampledData
# 0                     False
# 1                     False
# 2                     False
# 3                     False
# 4                     False
# 5                     False
# 6                     False
# 7                     False
# 8                     False
# 9                     False
# 10                    False
# 11                    False
# 12                    False
# 13                    False
# 14                    False
# 15                    False
# 16                    False
# 17                    False
# 18                    False
# 19                    False
# 20                    False
# 21                    False
# 22                    False
# 23                    False
# 24                    False
# 25                    False
# 26                    False
# 27                    False
# 28                    False
# 29                    False
# ...                     ...
# 137662                False
# 137663                False
# 137664                False
# 137665                False
# 137666                False
# 137667                False
# 137668                False
# 137669                False
# 137670                False
# 137671                False
# 137672                False
# 137673                False
# 137674                False
# 137675                False
# 137676                False
# 137677                False
# 137678                False
# 137679                False
# 137680                False
# 137681                False
# 137682                False
# 137683                False
# 137684                False
# 137685                False
# 137686                False
# 137687                False
# 137688                False
# 137689                False
# 137690                False
# 137691                False
#
# [137692 rows x 5 columns]

# %%
# Routine to calculate a duration, given to date strings. 
def calculateDuration(startDate, endDate):
    print(str(startDate) + ' - ' + str(endDate))
    startDateDelta = datetime.datetime.strptime(startDate, "%Y-%m-%d")
    endDateDelta = datetime.datetime.strptime(endDate, "%Y-%m-%d")
    duration = endDateDelta - startDateDelta
    return duration.days

# %%
# Split url data
hash_map = {}
# Creating another hash layer to calculate time
listOfParams = []
denayDateParams = ['experiencesearch[date_end]','experiencesearch[date_start]','lodgesearch[date_start]', 'lodgesearch[date_end]', 'LodgeSearch[date_start]','LodgeSearch[date_end]', 'ExperienceSearch[date_start]','ExperienceSearch[date_end]']
for index, row in fullText.iterrows():
    url = parse.urlsplit(row.pagePath)
#     print(url.path)
    params = parse_qs(url.query, keep_blank_values=True)
    listOfParams.append(params)
#     print(params)
    for key in params.keys():
        # Date related keys
        if key not in denayDateParams:
            hash_map[key.lower()] = {}
# Out:
# /de/experience-catalog/experience
# /de/experience-catalog/experience
# /de/experience-catalog/experience
# /de/experience-catalog/experience
# /de/experience-catalog/experience
# /de/experience-catalog/experience
# /de/experience-catalog/experience
# /de/experience-catalog/experience
# /de/experience-catalog/experience
# /de/experience-catalog/experience
# /de/experience-catalog/experience
# /de/experience-catalog/experience
# /de/experience-catalog/experience
# /de/lodge-catalog/index
# /de/lodge-catalog/lodge
# /de/lodge-catalog/lodge
# /de/lodge-catalog/lodge
# /de/lodge-catalog/lodge
# /de/lodge-catalog/lodge
# /de/lodge-catalog/lodge
# /de/lodge-catalog/lodge
# /de/lodge-catalog/lodge
# /de/lodge-catalog/lodge
# /de/lodge-catalog/lodge
# /de/lodge-catalog/lodge
# /de/lodge-catalog/lodge
# /de/lodge-catalog/lodge
# /de/lodge-catalog/lodge
# /de/lodge-catalog/lodge
# /de/lodge-catalog/lodge
# /de/lodge-catalog/lodge
# /de/lodge-catalog/lodge
# /de/lodge-catalog/lodge
# /de/lodge-catalog/lodge
# /de/lodge-catalog/lodge
# /de/lodge-catalog/lodge
# /de/lodge-catalog/lodge
# /de/lodge-catalog/lodge
# /de/lodge-catalog/lodge
# /de/lodge-catalog/lodge
# /de/lodge-catalog/lodge
# /de/lodge-catalog/lodge
# /de/lodge-catalog/lodge
# /de/lodge-catalog/lodge
# /de/lodge-catalog/lodge
# /de/lodge-catalog/lodge
# /de/lodge-catalog/lodge
# /de/lodge-catalog/lodge
# /de/lodge-catalog/lodge
# /en/experience-catalog/experience
# /en/experience-catalog/experience
# /en/experience-catalog/experience
# /en/experience-catalog/experience
# /en/experience-catalog/experience
# /en/experience-catalog/experience
# /en/experience-catalog/experience
# /en/experience-catalog/experience
# /en/experience-catalog/experience
# /en/experience-catalog/experience
# /en/experience-catalog/experience
# /en/experience-catalog/experience
# /en/experience-catalog/experience
# /en/experience-catalog/experience
# /en/experience-catalog/experience
# /en/experience-catalog/experience
# /en/experience-catalog/experience
# /en/experience-catalog/experience
# /en/experience-catalog/experience
# /en/experience-catalog/experience
# /en/experience-catalog/experience
# /en/experience-catalog/experience
# /en/experience-catalog/experience
# /en/experience-catalog/experience
# /en/experience-catalog/experience
# /en/experience-catalog/experience
# /en/experience-catalog/experience
# /en/experience-catalog/experience
# /en/experience-catalog/experience
# /en/experience-catalog/experience
# /en/experience-catalog/experience
# /en/experience-catalog/experience
# /en/experience-catalog/experience
# /en/experience-catalog/experience
# /en/experience-catalog/experience
# /en/experience-catalog/experience
# /en/experience-catalog/experience
# /en/experience-catalog/experience
# /en/experience-catalog/experience
# /en/experience-catalog/experience
# /en/experience-catalog/experience
# /en/experience-catalog/experience
# /en/experience-catalog/experience
# /en/lodge-catalog/index
# /en/lodge-catalog/index
# /en/lodge-catalog/index
# /en/lodge-catalog/index
# /en/lodge-catalog/index
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/lodge
# /en/lodge-catalog/odlge
# /es/experience-catalog/experience
# /es/experience-catalog/experience
# /es/experience-catalog/experience
# /es/experience-catalog/experience
# /es/experience-catalog/experience
# /es/experience-catalog/experience
# /es/experience-catalog/experience
# /es/experience-catalog/experience
# /es/experience-catalog/experience
# /es/experience-catalog/experience
# /es/experience-catalog/experience
# /es/experience-catalog/experience
# /es/experience-catalog/experience
# /es/experience-catalog/experience
# /es/experience-catalog/experience
# /es/experience-catalog/experience
# /es/experience-catalog/experience
# /es/experience-catalog/experience
# /es/experience-catalog/experience
# /es/experience-catalog/experience
# /es/experience-catalog/experience
# /es/experience-catalog/experience
# /es/experience-catalog/experience
# /es/experience-catalog/experience
# /es/experience-catalog/experience
# /es/experience-catalog/experience
# /es/experience-catalog/experience
# /es/experience-catalog/experience
# /es/experience-catalog/experience
# /es/experience-catalog/experience
# /es/experience-catalog/experience
# /es/experience-catalog/experience
# /es/experience-catalog/experience
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/lodge
# /es/lodge-catalog/odlge
# /fr/experience-catalog/experience
# /fr/experience-catalog/experience
# /fr/experience-catalog/experience
# /fr/experience-catalog/experience
# /fr/experience-catalog/experience
# /fr/experience-catalog/experience
# /fr/experience-catalog/experience
# /fr/experience-catalog/experience
# /fr/experience-catalog/experience
# /fr/experience-catalog/experience
# /fr/experience-catalog/experience
# /fr/experience-catalog/experience
# /fr/experience-catalog/experience
# /fr/experience-catalog/experience
# /fr/experience-catalog/experience
# /fr/experience-catalog/experience
# /fr/experience-catalog/experience
# /fr/experience-catalog/experience
# /fr/experience-catalog/experience
# /fr/experience-catalog/experience
# /fr/experience-catalog/experience
# /fr/experience-catalog/experience
# /fr/experience-catalog/experience
# /fr/experience-catalog/experience
# /fr/experience-catalog/experience
# /fr/experience-catalog/experience
# /fr/experience-catalog/experience
# /fr/experience-catalog/experience
# /fr/experience-catalog/experience
# /fr/experience-catalog/experience
# /fr/experience-catalog/experience
# /fr/experience-catalog/experience
# /fr/experience-catalog/experience
# /fr/experience-catalog/experience
# /fr/experience-catalog/experience
# /fr/experience-catalog/experience
# /fr/experience-catalog/experience
# /fr/experience-catalog/experience
# /fr/experience-catalog/experience
# /fr/experience-catalog/experience
# /fr/experience-catalog/experience
# /fr/experience-catalog/experience
# /fr/experience-catalog/experience
# /fr/experience-catalog/experience
# /fr/experience-catalog/experience
# /fr/experience-catalog/experience
# /fr/experience-catalog/experience
# /fr/experience-catalog/experience
# /fr/experience-catalog/experience
# /fr/lodge-catalog/index
# /fr/lodge-catalog/index
# /fr/lodge-catalog/lodge
# /fr/lodge-catalog/lodge
# /fr/lodge-catalog/lodge
# /fr/lodge-catalog/lodge
# /fr/lodge-catalog/lodge
# /fr/lodge-catalog/lodge
# /fr/lodge-catalog/lodge
# /fr/lodge-catalog/lodge
# /fr/lodge-catalog/lodge
# /fr/lodge-catalog/lodge
# /fr/lodge-catalog/lodge
# /fr/lodge-catalog/lodge
# /fr/lodge-catalog/lodge
# /fr/lodge-catalog/lodge
# /fr/lodge-catalog/lodge
# /fr/lodge-catalog/lodge
# /fr/lodge-catalog/lodge
# /fr/lodge-catalog/lodge
# /fr/lodge-catalog/lodge
# /fr/lodge-catalog/lodge
# /fr/lodge-catalog/lodge
# /fr/lodge-catalog/lodge
# /fr/lodge-catalog/lodge
# /fr/lodge-catalog/lodge
# /fr/lodge-catalog/lodge
# /fr/lodge-catalog/lodge
# /fr/lodge-catalog/lodge
# /fr/lodge-catalog/lodge
# /fr/lodge-catalog/lodge
# /fr/lodge-catalog/lodge
# /fr/lodge-catalog/lodge
# /fr/lodge-catalog/lodge
# /fr/lodge-catalog/lodge
# /fr/lodge-catalog/lodge
# /fr/lodge-catalog/lodge
# /fr/lodge-catalog/lodge
# /fr/lodge-catalog/lodge
# /fr/lodge-catalog/lodge
# /fr/lodge-catalog/lodge
# /fr/lodge-catalog/lodge
# /fr/lodge-catalog/lodge
# /fr/lodge-catalog/lodge
# /fr/lodge-catalog/lodge
# /fr/lodge-catalog/lodge
# /fr/lodge-catalog/lodge
# /fr/lodge-catalog/lodge
# /fr/lodge-catalog/lodge
# /fr/lodge-catalog/lodge
# /fr/lodge-catalog/lodge
# /fr/lodge-catalog/lodge
# /fr/lodge-catalog/lodge
# /fr/lodge-catalog/lodge
# /fr/lodge-catalog/lodge
# /fr/lodge-catalog/lodge
# /fr/lodge-catalog/lodge
# /fr/lodge-catalog/lodge
# /fr/lodge-catalog/lodge
# /fr/lodge-catalog/lodge
# /fr/lodge-catalog/lodge
# /fr/lodge-catalog/lodge
# /fr/lodge-catalog/lodge
# /fr/lodge-catalog/lodge
# /fr/lodge-catalog/lodge
# /fr/lodge-catalog/lodge
# /fr/lodge-catalog/lodge
# /https://bookinxisto.com/pt/lodge-catalog/lodge
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/experience
# /pt/experience-catalog/index
# /pt/experience-catalog/index
# /pt/experience-catalog/index
# /pt/experience-catalog/index
# /pt/experience-catalog/index
# /pt/experience-catalog/index
# /pt/experience-catalog/index
# /pt/experience-catalog/index
# /pt/experience-catalog/index
# /pt/experience-catalog/index
# /pt/experience-catalog/index
# /pt/experience-catalog/index
# /pt/experience-catalog/index
# /pt/experience-catalog/index
# /pt/experience-catalog/index
# /pt/experience-catalog/index
# /pt/experience-catalog/index
# /pt/experience-catalog/index
# /pt/experience-catalog/index
# /pt/experience-catalog/index
# /pt/experience-catalog/index
# /pt/experience-catalog/index
# /pt/experience-catalog/index
# /pt/experience-catalog/index
# /pt/experience-catalog/index
# /pt/experience-catalog/index
# /pt/experience-catalog/index
# /pt/experience-catalog/index
# /pt/experience-catalog/index
# /pt/experience-catalog/index
# /pt/experience-catalog/index
# /pt/experience-catalog/index
# /pt/experience-catalog/index
# /pt/experience-catalog/index
# /pt/experience-catalog/index
# /pt/experience-catalog/index
# /pt/experience-catalog/index
# /pt/experience-catalog/index
# /pt/experience-catalog/index
# /pt/experience-catalog/index
# /pt/experience-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/index
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# ...
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge
# /pt/lodge-catalog/lodge

# %%
# Calculate Order Durations
hash_map['LodgeSearch_duration'] = {}
hash_map['ExperienceSearch_duration'] = {}
hash_map['Index_duration'] = {}
hash_map['id_LodgeSearch'] = {}
hash_map['id_ExperienceSearch'] = {}
hash_map['id_Index'] = {}
# Small Hack to user lower case on DataFrame pagePath
pagePathLower = pd.DataFrame(fullText['pagePath'].str.lower())
for index, row in pagePathLower.iterrows():
    # Getting dataframe.users for the current index
    weightedSum = 1*fullText.iloc[index].newUsers
    expSearch = ['experiencesearch[date_start]', 'experiencesearch[date_end]']
    lodgeSearch = ['lodgesearch[date_start]', 'lodgesearch[date_end]']
    url = parse.urlsplit(row.pagePath)
    params = parse_qs(url.query, keep_blank_values=True)
    
    # Clear empty Data
    if 'id' not in params.keys():
        params['id'] = 'n'
    
    try:    
        # ID Frequency Verification
        if url.path.endswith('experience'):
            # Count Id Frequency for ExperienceSearch
            if params['id'][0] in hash_map['id_ExperienceSearch']:
                hash_map['id_ExperienceSearch'][params['id'][0]] = hash_map['id_ExperienceSearch'][params['id'][0]] + weightedSum
            else:
                hash_map['id_ExperienceSearch'][params['id'][0]] = weightedSum
        if url.path.endswith('lodge'):
            # Count Id Frequency for LodgeSearch
            if params['id'][0] in hash_map['id_LodgeSearch']:
                hash_map['id_LodgeSearch'][params['id'][0]] = hash_map['id_LodgeSearch'][params['id'][0]] +weightedSum
            else:
                hash_map['id_LodgeSearch'][params['id'][0]] = weightedSum
        if url.path.endswith('index'):
            if params['id'][0] in hash_map['id_Index']:
                hash_map['id_Index'][params['id'][0]] = hash_map['id_Index'][params['id'][0]] + weightedSum
            else:
                hash_map['id_Index'][params['id'][0]] = weightedSum


        # If Date is related to EXPERIENCE
        if expSearch[0] in params:
    #         if 'lodgesearch[date_end]' not in params.keys():
    #             params['lodgesearch[date_end]'] = '2018-12-30'
    #         if 'lodgesearch[date_start]' not in params.keys():
    #             params['lodgesearch[date_start]'] = '2018-12-30

            daysExp = calculateDuration(params[expSearch[0]][0], params[expSearch[1]][0])
            if daysExp < 0:
                print("DATA NEGATIVA BAD SMELL")
                print(row)
                print(daysExp)
            if daysExp in hash_map['ExperienceSearch_duration']:
                hash_map['ExperienceSearch_duration'][daysExp] = hash_map['ExperienceSearch_duration'][daysExp] + weightedSum
            else:
                hash_map['ExperienceSearch_duration'][daysExp] = weightedSum       

        # If Date is related to LODGE
        elif lodgeSearch[0] in params:
            
            dayLodge = calculateDuration(params[lodgeSearch[0]][0], params[lodgeSearch[1]][0])
            if dayLodge < 0:
                print("DATA NEGATIVA BAD SMELL")
                print(row)
                print(daysLodge)
            if dayLodge in hash_map['LodgeSearch_duration']:
                hash_map['LodgeSearch_duration'][dayLodge] = hash_map['LodgeSearch_duration'][dayLodge] + weightedSum
            else:
                hash_map['LodgeSearch_duration'][dayLodge] = weightedSum
    except:
        print('ERRO: ' + str(index) + ' - ' + str(row))
# Out:
# pagePath    /de/experience-catalog/experience?id=140&exper...
# Name: 0, dtype: object
# 2018-02-15 - 2018-02-20
# pagePath    /de/experience-catalog/experience?id=144&exper...
# Name: 1, dtype: object
# 2018-01-28 - 2018-02-02
# pagePath    /de/experience-catalog/experience?id=155&exper...
# Name: 2, dtype: object
# 2017-12-11 - 2017-12-16
# pagePath    /de/experience-catalog/experience?id=157
# Name: 3, dtype: object
# pagePath    /de/experience-catalog/experience?id=157&exper...
# Name: 4, dtype: object
# 2018-02-10 - 2018-02-15
# pagePath    /de/experience-catalog/experience?id=22
# Name: 5, dtype: object
# pagePath    /de/experience-catalog/experience?id=22&experi...
# Name: 6, dtype: object
# 2018-07-26 - 2018-07-31
# pagePath    /de/experience-catalog/experience?id=235&exper...
# Name: 7, dtype: object
# 2018-08-03 - 2018-08-08
# pagePath    /de/experience-catalog/experience?id=246&exper...
# Name: 8, dtype: object
# 2018-02-02 - 2018-02-07
# pagePath    /de/experience-catalog/experience?id=252&exper...
# Name: 9, dtype: object
# 2018-02-02 - 2018-02-07
# pagePath    /de/experience-catalog/experience?id=282&exper...
# Name: 10, dtype: object
# 2018-07-29 - 2018-08-03
# pagePath    /de/experience-catalog/experience?id=31&experi...
# Name: 11, dtype: object
# 2018-02-16 - 2018-02-21
# pagePath    /de/experience-catalog/experience?id=32&experi...
# Name: 12, dtype: object
# 2018-02-24 - 2018-03-01
# pagePath    /de/lodge-catalog/index?lodgesearch[type_id]=&...
# Name: 13, dtype: object
# pagePath    /de/lodge-catalog/lodge?id=1&lodgesearch[date_...
# Name: 14, dtype: object
# SplitResult(scheme='', netloc='', path='/de/lodge-catalog/lodge', query='id=1&lodgesearch[date_start]=2018-07-20&lodgesearch[date_end]=2018-08-19&lodgesearch[num_adults]=2&lodgesearch[num_children]=0&lodgesearch[price_low]=0&lodgesearch[price_high]=9999', fragment='')
# 2018-07-20 - 2018-08-19
# pagePath    /de/lodge-catalog/lodge?id=11&lodgesearch[date...
# Name: 15, dtype: object
# SplitResult(scheme='', netloc='', path='/de/lodge-catalog/lodge', query='id=11&lodgesearch[date_start]=2018-08-20&lodgesearch[date_end]=2018-08-25', fragment='')
# 2018-08-20 - 2018-08-25
# pagePath    /de/lodge-catalog/lodge?id=14&lodgesearch[date...
# Name: 16, dtype: object
# SplitResult(scheme='', netloc='', path='/de/lodge-catalog/lodge', query='id=14&lodgesearch[date_start]=2018-01-25&lodgesearch[date_end]=2018-01-30', fragment='')
# 2018-01-25 - 2018-01-30
# pagePath    /de/lodge-catalog/lodge?id=17&lodgesearch[date...
# Name: 17, dtype: object
# SplitResult(scheme='', netloc='', path='/de/lodge-catalog/lodge', query='id=17&lodgesearch[date_start]=2018-01-09&lodgesearch[date_end]=2018-01-14', fragment='')
# 2018-01-09 - 2018-01-14
# pagePath    /de/lodge-catalog/lodge?id=19&lodgesearch[date...
# Name: 18, dtype: object
# SplitResult(scheme='', netloc='', path='/de/lodge-catalog/lodge', query='id=19&lodgesearch[date_start]=2018-03-05&lodgesearch[date_end]=2018-03-10', fragment='')
# 2018-03-05 - 2018-03-10
# pagePath    /de/lodge-catalog/lodge?id=19&lodgesearch[date...
# Name: 19, dtype: object
# SplitResult(scheme='', netloc='', path='/de/lodge-catalog/lodge', query='id=19&lodgesearch[date_start]=2018-07-09&lodgesearch[date_end]=2018-07-14', fragment='')
# 2018-07-09 - 2018-07-14
# pagePath    /de/lodge-catalog/lodge?id=2&lodgesearch[date_...
# Name: 20, dtype: object
# SplitResult(scheme='', netloc='', path='/de/lodge-catalog/lodge', query='id=2&lodgesearch[date_start]=2017-12-22&lodgesearch[date_end]=2017-12-27', fragment='')
# 2017-12-22 - 2017-12-27
# pagePath    /de/lodge-catalog/lodge?id=22
# Name: 21, dtype: object
# pagePath    /de/lodge-catalog/lodge?id=29&lodgesearch[date...
# Name: 22, dtype: object
# SplitResult(scheme='', netloc='', path='/de/lodge-catalog/lodge', query='id=29&lodgesearch[date_start]=2018-03-03&lodgesearch[date_end]=2018-03-08', fragment='')
# 2018-03-03 - 2018-03-08
# pagePath    /de/lodge-catalog/lodge?id=35&lodgesearch[date...
# Name: 23, dtype: object
# SplitResult(scheme='', netloc='', path='/de/lodge-catalog/lodge', query='id=35&lodgesearch[date_start]=2018-09-10&lodgesearch[date_end]=2018-09-12&lodgesearch[num_adults]=2&lodgesearch[num_children]=0&lodgesearch[price_low]=0&lodgesearch[price_high]=9999&lodgesearch[village_id]=1&lodgesearch[relevance]=', fragment='')
# 2018-09-10 - 2018-09-12
# pagePath    /de/lodge-catalog/lodge?id=40
# Name: 24, dtype: object
# pagePath    /de/lodge-catalog/lodge?id=40&lodgesearch[date...
# Name: 25, dtype: object
# SplitResult(scheme='', netloc='', path='/de/lodge-catalog/lodge', query='id=40&lodgesearch[date_start]=2018-06-19&lodgesearch[date_end]=2018-06-24', fragment='')
# 2018-06-19 - 2018-06-24
# pagePath    /de/lodge-catalog/lodge?id=45&lodgesearch[date...
# Name: 26, dtype: object
# SplitResult(scheme='', netloc='', path='/de/lodge-catalog/lodge', query='id=45&lodgesearch[date_start]=2018-05-12&lodgesearch[date_end]=2018-05-19&lodgesearch[num_adults]=2&lodgesearch[num_children]=0&lodgesearch[price_low]=0&lodgesearch[price_high]=79&lodgesearch[village_id]=&lodgesearch[relevance]=cheap', fragment='')
# 2018-05-12 - 2018-05-19
# pagePath    /de/lodge-catalog/lodge?id=47&lodgesearch[date...
# Name: 27, dtype: object
# SplitResult(scheme='', netloc='', path='/de/lodge-catalog/lodge', query='id=47&lodgesearch[date_start]=2018-02-15&lodgesearch[date_end]=2018-02-20', fragment='')
# 2018-02-15 - 2018-02-20
# pagePath    /de/lodge-catalog/lodge?id=51
# Name: 28, dtype: object
# pagePath    /de/lodge-catalog/lodge?id=51&lodgesearch[date...
# Name: 29, dtype: object
# SplitResult(scheme='', netloc='', path='/de/lodge-catalog/lodge', query='id=51&lodgesearch[date_start]=2018-01-28&lodgesearch[date_end]=2018-12-31&lodgesearch[num_adults]=2&lodgesearch[num_children]=0&lodgesearch[price_low]=0&lodgesearch[price_high]=9999', fragment='')
# 2018-01-28 - 2018-12-31
# pagePath    /de/lodge-catalog/lodge?id=52
# Name: 30, dtype: object
# pagePath    /de/lodge-catalog/lodge?id=52&lodgesearch[date...
# Name: 31, dtype: object
# SplitResult(scheme='', netloc='', path='/de/lodge-catalog/lodge', query='id=52&lodgesearch[date_start]=2018-02-11&lodgesearch[date_end]=2018-02-16', fragment='')
# 2018-02-11 - 2018-02-16
# pagePath    /de/lodge-catalog/lodge?id=53&lodgesearch[date...
# Name: 32, dtype: object
# SplitResult(scheme='', netloc='', path='/de/lodge-catalog/lodge', query='id=53&lodgesearch[date_start]=2018-01-10&lodgesearch[date_end]=2018-01-15', fragment='')
# 2018-01-10 - 2018-01-15
# pagePath    /de/lodge-catalog/lodge?id=53&lodgesearch[date...
# Name: 33, dtype: object
# SplitResult(scheme='', netloc='', path='/de/lodge-catalog/lodge', query='id=53&lodgesearch[date_start]=2018-01-25&lodgesearch[date_end]=2018-12-31&lodgesearch[num_adults]=2&lodgesearch[num_children]=0&lodgesearch[price_low]=0&lodgesearch[price_high]=9999', fragment='')
# 2018-01-25 - 2018-12-31
# pagePath    /de/lodge-catalog/lodge?id=53&lodgesearch[date...
# Name: 34, dtype: object
# SplitResult(scheme='', netloc='', path='/de/lodge-catalog/lodge', query='id=53&lodgesearch[date_start]=2018-02-27&lodgesearch[date_end]=2018-03-04', fragment='')
# 2018-02-27 - 2018-03-04
# pagePath    /de/lodge-catalog/lodge?id=55
# Name: 35, dtype: object
# pagePath    /de/lodge-catalog/lodge?id=57
# Name: 36, dtype: object
# pagePath    /de/lodge-catalog/lodge?id=57&lodgesearch[date...
# Name: 37, dtype: object
# SplitResult(scheme='', netloc='', path='/de/lodge-catalog/lodge', query='id=57&lodgesearch[date_start]=2017-12-24&lodgesearch[date_end]=2017-12-29', fragment='')
# 2017-12-24 - 2017-12-29
# pagePath    /de/lodge-catalog/lodge?id=6&lodgesearch[date_...
# Name: 38, dtype: object
# SplitResult(scheme='', netloc='', path='/de/lodge-catalog/lodge', query='id=6&lodgesearch[date_start]=2018-08-19&lodgesearch[date_end]=2018-08-24', fragment='')
# 2018-08-19 - 2018-08-24
# pagePath    /de/lodge-catalog/lodge?id=62&lodgesearch[date...
# Name: 39, dtype: object
# SplitResult(scheme='', netloc='', path='/de/lodge-catalog/lodge', query='id=62&lodgesearch[date_start]=2018-05-12&lodgesearch[date_end]=2018-05-19&lodgesearch[num_adults]=2&lodgesearch[num_children]=0&lodgesearch[price_low]=0&lodgesearch[price_high]=79&lodgesearch[village_id]=&lodgesearch[relevance]=cheap', fragment='')
# 2018-05-12 - 2018-05-19
# pagePath    /de/lodge-catalog/lodge?id=67
# Name: 40, dtype: object
# pagePath    /de/lodge-catalog/lodge?id=78
# Name: 41, dtype: object
# pagePath    /de/lodge-catalog/lodge?id=79&lodgesearch[date...
# Name: 42, dtype: object
# SplitResult(scheme='', netloc='', path='/de/lodge-catalog/lodge', query='id=79&lodgesearch[date_start]=2018-08-01&lodgesearch[date_end]=2018-08-13&lodgesearch[num_adults]=5&lodgesearch[num_children]=0&lodgesearch[price_low]=0&lodgesearch[price_high]=9999', fragment='')
# 2018-08-01 - 2018-08-13
# pagePath    /de/lodge-catalog/lodge?id=80&lodgesearch[date...
# Name: 43, dtype: object
# SplitResult(scheme='', netloc='', path='/de/lodge-catalog/lodge', query='id=80&lodgesearch[date_start]=2018-06-22&lodgesearch[date_end]=2018-06-24&lodgesearch[num_adults]=6', fragment='')
# 2018-06-22 - 2018-06-24
# pagePath    /de/lodge-catalog/lodge?id=87&lodgesearch[date...
# Name: 44, dtype: object
# SplitResult(scheme='', netloc='', path='/de/lodge-catalog/lodge', query='id=87&lodgesearch[date_start]=2018-06-29&lodgesearch[date_end]=2018-07-04', fragment='')
# 2018-06-29 - 2018-07-04
# pagePath    /de/lodge-catalog/lodge?id=87&lodgesearch[date...
# Name: 45, dtype: object
# SplitResult(scheme='', netloc='', path='/de/lodge-catalog/lodge', query='id=87&lodgesearch[date_start]=2018-07-05&lodgesearch[date_end]=2018-07-10', fragment='')
# 2018-07-05 - 2018-07-10
# pagePath    /de/lodge-catalog/lodge?id=87&lodgesearch[date...
# Name: 46, dtype: object
# SplitResult(scheme='', netloc='', path='/de/lodge-catalog/lodge', query='id=87&lodgesearch[date_start]=2018-08-21&lodgesearch[date_end]=2018-08-26', fragment='')
# 2018-08-21 - 2018-08-26
# pagePath    /de/lodge-catalog/lodge?id=87&lodgesearch[date...
# Name: 47, dtype: object
# SplitResult(scheme='', netloc='', path='/de/lodge-catalog/lodge', query='id=87&lodgesearch[date_start]=2018-09-13&lodgesearch[date_end]=2018-09-18', fragment='')
# 2018-09-13 - 2018-09-18
# pagePath    /de/lodge-catalog/lodge?lodgesearch[num_adults...
# Name: 48, dtype: object
# SplitResult(scheme='', netloc='', path='/de/lodge-catalog/lodge', query='lodgesearch[num_adults]=2&lodgesearch[num_children]=1&lodgesearch[date_start]=2018-08-07&lodgesearch[date_end]=2018-08-08&id=37', fragment='')
# 2018-08-07 - 2018-08-08
# pagePath    /en/experience-catalog/experience?id=140
# Name: 49, dtype: object
# pagePath    /en/experience-catalog/experience?id=140&exper...
# Name: 50, dtype: object
# 2018-02-21 - 2018-02-26
# pagePath    /en/experience-catalog/experience?id=140&exper...
# Name: 51, dtype: object
# 2018-02-24 - 2018-03-01
# pagePath    /en/experience-catalog/experience?id=140&exper...
# Name: 52, dtype: object
# 2018-02-28 - 2018-03-05
# pagePath    /en/experience-catalog/experience?id=144
# Name: 53, dtype: object
# pagePath    /en/experience-catalog/experience?id=144&exper...
# Name: 54, dtype: object
# 2018-01-30 - 2018-02-04
# pagePath    /en/experience-catalog/experience?id=144&exper...
# Name: 55, dtype: object
# 2018-02-18 - 2018-02-23
# pagePath    /en/experience-catalog/experience?id=146
# Name: 56, dtype: object
# pagePath    /en/experience-catalog/experience?id=146&exper...
# Name: 57, dtype: object
# 2017-12-29 - 2018-01-03
# pagePath    /en/experience-catalog/experience?id=146&exper...
# Name: 58, dtype: object
# 2018-01-11 - 2018-01-16
# pagePath    /en/experience-catalog/experience?id=147
# Name: 59, dtype: object
# pagePath    /en/experience-catalog/experience?id=147&exper...
# Name: 60, dtype: object
# 2018-07-29 - 2018-08-03
# pagePath    /en/experience-catalog/experience?id=149&exper...
# Name: 61, dtype: object
# 2018-02-27 - 2018-03-04
# pagePath    /en/experience-catalog/experience?id=150
# Name: 62, dtype: object
# pagePath    /en/experience-catalog/experience?id=150
# Name: 63, dtype: object
# pagePath    /en/experience-catalog/experience?id=150
# Name: 64, dtype: object
# pagePath    /en/experience-catalog/experience?id=150&exper...
# Name: 65, dtype: object
# 2018-02-12 - 2018-02-17
# pagePath    /en/experience-catalog/experience?id=150&exper...
# Name: 66, dtype: object
# 2018-02-25 - 2018-03-02
# pagePath    /en/experience-catalog/experience?id=151
# Name: 67, dtype: object
# pagePath    /en/experience-catalog/experience?id=154
# Name: 68, dtype: object
# pagePath    /en/experience-catalog/experience?id=154&exper...
# Name: 69, dtype: object
# 2018-02-22 - 2018-02-27
# pagePath    /en/experience-catalog/experience?id=154&exper...
# Name: 70, dtype: object
# 2018-07-29 - 2018-08-03
# pagePath    /en/experience-catalog/experience?id=155
# Name: 71, dtype: object
# pagePath    /en/experience-catalog/experience?id=156
# Name: 72, dtype: object
# pagePath    /en/experience-catalog/experience?id=157
# Name: 73, dtype: object
# pagePath    /en/experience-catalog/experience?id=157&exper...
# Name: 74, dtype: object
# 2018-07-02 - 2018-07-07
# pagePath    /en/experience-catalog/experience?id=157&exper...
# Name: 75, dtype: object
# 2018-07-20 - 2018-07-25
# pagePath    /en/experience-catalog/experience?id=157&exper...
# Name: 76, dtype: object
# 2018-07-22 - 2018-07-27
# pagePath    /en/experience-catalog/experience?id=157&exper...
# Name: 77, dtype: object
# 2018-07-23 - 2018-07-28
# pagePath    /en/experience-catalog/experience?id=206&exper...
# Name: 78, dtype: object
# 2017-12-23 - 2017-12-28
# pagePath    /en/experience-catalog/experience?id=214&exper...
# Name: 79, dtype: object
# 2018-02-20 - 2018-02-25
# pagePath    /en/experience-catalog/experience?id=215&exper...
# Name: 80, dtype: object
# 2017-12-22 - 2017-12-27
# pagePath    /en/experience-catalog/experience?id=241&exper...
# Name: 81, dtype: object
# 2018-05-11 - 2018-05-16
# pagePath    /en/experience-catalog/experience?id=241&exper...
# Name: 82, dtype: object
# 2018-07-17 - 2018-07-22
# pagePath    /en/experience-catalog/experience?id=246&exper...
# Name: 83, dtype: object
# 2018-03-04 - 2018-03-09
# pagePath    /en/experience-catalog/experience?id=247&exper...
# Name: 84, dtype: object
# 2018-02-01 - 2018-02-06
# pagePath    /en/experience-catalog/experience?id=247&exper...
# Name: 85, dtype: object
# 2018-06-30 - 2018-07-05
# pagePath    /en/experience-catalog/experience?id=251&exper...
# Name: 86, dtype: object
# 2018-02-06 - 2018-02-11
# pagePath    /en/experience-catalog/experience?id=251&exper...
# Name: 87, dtype: object
# 2018-02-08 - 2018-02-13
# pagePath    /en/experience-catalog/experience?id=252&exper...
# Name: 88, dtype: object
# 2018-09-14 - 2018-09-19
# pagePath    /en/experience-catalog/experience?id=254&exper...
# Name: 89, dtype: object
# 2018-02-03 - 2018-02-08
# pagePath    /en/experience-catalog/experience?id=31&experi...
# Name: 90, dtype: object
# 2018-01-27 - 2018-02-01
# pagePath    /en/experience-catalog/experience?id=4
# Name: 91, dtype: object
# pagePath    /en/lodge-catalog/index?lodgesearch[type_id]=&...
# Name: 92, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/index', query='lodgesearch[type_id]=&lodgesearch[fulltext]=&lodgesearch[village_id]=14&lodgesearch[relevance]=&lodgesearch[price_low]=0&lodgesearch[price_high]=9999&lodgesearch[date_start]=2018-3-3&lodgesearch[date_end]=2018-3-4&lodgesearch[num_adults]=2&lodgesearch[num_children]=1', fragment='')
# 2018-3-3 - 2018-3-4
# pagePath    /en/lodge-catalog/index?lodgesearch[type_id]=&...
# Name: 93, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/index', query='lodgesearch[type_id]=&lodgesearch[fulltext]=&lodgesearch[village_id]=36&lodgesearch[relevance]=&lodgesearch[price_low]=0&lodgesearch[price_high]=9999&lodgesearch[date_start]=2018-09-30&lodgesearch[date_end]=2018-10-05&lodgesearch[num_adults]=2&lodgesearch[num_children]=0', fragment='')
# 2018-09-30 - 2018-10-05
# pagePath    /en/lodge-catalog/index?lodgesearch[type_id]=&...
# Name: 94, dtype: object
# pagePath    /en/lodge-catalog/index?lodgesearch[type_id]=&...
# Name: 95, dtype: object
# pagePath    /en/lodge-catalog/index?lodgesearch[type_id]=&...
# Name: 96, dtype: object
# pagePath    /en/lodge-catalog/lodge?id=1
# Name: 97, dtype: object
# pagePath    /en/lodge-catalog/lodge?id=1&lodgesearch[date_...
# Name: 98, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=1&lodgesearch[date_start]=2018-04-06&lodgesearch[date_end]=2018-04-09&lodgesearch[num_adults]=2&lodgesearch[num_children]=0&lodgesearch[price_low]=0&lodgesearch[price_high]=9999', fragment='')
# 2018-04-06 - 2018-04-09
# pagePath    /en/lodge-catalog/lodge?id=1&lodgesearch[date_...
# Name: 99, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=1&lodgesearch[date_start]=2018-07-17&lodgesearch[date_end]=2018-07-22', fragment='')
# 2018-07-17 - 2018-07-22
# pagePath    /en/lodge-catalog/lodge?id=1&lodgesearch[date_...
# Name: 100, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=1&lodgesearch[date_start]=2018-08-11&lodgesearch[date_end]=2018-08-12&lodgesearch[num_adults]=2&lodgesearch[num_children]=2&lodgesearch[price_low]=0&lodgesearch[price_high]=9999', fragment='')
# 2018-08-11 - 2018-08-12
# pagePath    /en/lodge-catalog/lodge?id=10&lodgesearch[date...
# Name: 101, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=10&lodgesearch[date_start]=2018-05-29&lodgesearch[date_end]=2018-05-31&lodgesearch[num_adults]=2&lodgesearch[num_children]=1&lodgesearch[price_low]=0&lodgesearch[price_high]=9999', fragment='')
# 2018-05-29 - 2018-05-31
# pagePath    /en/lodge-catalog/lodge?id=10&lodgesearch[date...
# Name: 102, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=10&lodgesearch[date_start]=2018-09-21&lodgesearch[date_end]=2018-09-25&lodgesearch[num_adults]=2&lodgesearch[num_children]=0&lodgesearch[price_low]=0&lodgesearch[price_high]=9999&lodgesearch[village_id]=&lodgesearch[relevance]=', fragment='')
# 2018-09-21 - 2018-09-25
# pagePath    /en/lodge-catalog/lodge?id=11&lodgesearch[date...
# Name: 103, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=11&lodgesearch[date_start]=2018-06-06&lodgesearch[date_end]=2018-06-11', fragment='')
# 2018-06-06 - 2018-06-11
# pagePath    /en/lodge-catalog/lodge?id=11&lodgesearch[date...
# Name: 104, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=11&lodgesearch[date_start]=2018-06-27&lodgesearch[date_end]=2018-07-02', fragment='')
# 2018-06-27 - 2018-07-02
# pagePath    /en/lodge-catalog/lodge?id=12&lodgesearch[date...
# Name: 105, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=12&lodgesearch[date_start]=2018-07-17&lodgesearch[date_end]=2018-07-22', fragment='')
# 2018-07-17 - 2018-07-22
# pagePath    /en/lodge-catalog/lodge?id=13&lodgesearch[date...
# Name: 106, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=13&lodgesearch[date_start]=2018-07-25&lodgesearch[date_end]=2018-07-30', fragment='')
# 2018-07-25 - 2018-07-30
# pagePath    /en/lodge-catalog/lodge?id=13&lodgesearch[date...
# Name: 107, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=13&lodgesearch[date_start]=2018-07-25&lodgesearch[date_end]=2018-07-30', fragment='')
# 2018-07-25 - 2018-07-30
# pagePath    /en/lodge-catalog/lodge?id=13&lodgesearch[date...
# Name: 108, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=13&lodgesearch[date_start]=2018-07-25&lodgesearch[date_end]=2018-07-30', fragment='')
# 2018-07-25 - 2018-07-30
# pagePath    /en/lodge-catalog/lodge?id=13&lodgesearch[date...
# Name: 109, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=13&lodgesearch[date_start]=2018-07-25&lodgesearch[date_end]=2018-07-30', fragment='')
# 2018-07-25 - 2018-07-30
# pagePath    /en/lodge-catalog/lodge?id=13&lodgesearch[date...
# Name: 110, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=13&lodgesearch[date_start]=2018-07-25&lodgesearch[date_end]=2018-07-30', fragment='')
# 2018-07-25 - 2018-07-30
# pagePath    /en/lodge-catalog/lodge?id=13&lodgesearch[date...
# Name: 111, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=13&lodgesearch[date_start]=2018-07-25&lodgesearch[date_end]=2018-07-30', fragment='')
# 2018-07-25 - 2018-07-30
# pagePath    /en/lodge-catalog/lodge?id=13&lodgesearch[date...
# Name: 112, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=13&lodgesearch[date_start]=2018-08-02&lodgesearch[date_end]=2018-08-07', fragment='')
# 2018-08-02 - 2018-08-07
# pagePath    /en/lodge-catalog/lodge?id=14&lodgesearch[date...
# Name: 113, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=14&lodgesearch[date_start]=2018-01-25&lodgesearch[date_end]=2018-01-30', fragment='')
# 2018-01-25 - 2018-01-30
# pagePath    /en/lodge-catalog/lodge?id=14&lodgesearch[date...
# Name: 114, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=14&lodgesearch[date_start]=2018-02-24&lodgesearch[date_end]=2018-03-01', fragment='')
# 2018-02-24 - 2018-03-01
# pagePath    /en/lodge-catalog/lodge?id=14&lodgesearch[date...
# Name: 115, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=14&lodgesearch[date_start]=2018-09-01&lodgesearch[date_end]=2018-09-06', fragment='')
# 2018-09-01 - 2018-09-06
# pagePath    /en/lodge-catalog/lodge?id=16&lodgesearch[date...
# Name: 116, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=16&lodgesearch[date_start]=2018-07-17&lodgesearch[date_end]=2018-07-22', fragment='')
# 2018-07-17 - 2018-07-22
# pagePath    /en/lodge-catalog/lodge?id=16&lodgesearch[date...
# Name: 117, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=16&lodgesearch[date_start]=2018-08-17&lodgesearch[date_end]=2018-08-22', fragment='')
# 2018-08-17 - 2018-08-22
# pagePath    /en/lodge-catalog/lodge?id=17
# Name: 118, dtype: object
# pagePath    /en/lodge-catalog/lodge?id=17&lodgesearch[date...
# Name: 119, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=17&lodgesearch[date_start]=2017-12-22&lodgesearch[date_end]=2017-12-27', fragment='')
# 2017-12-22 - 2017-12-27
# pagePath    /en/lodge-catalog/lodge?id=17&lodgesearch[date...
# Name: 120, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=17&lodgesearch[date_start]=2018-03-16&lodgesearch[date_end]=2018-03-21', fragment='')
# 2018-03-16 - 2018-03-21
# pagePath    /en/lodge-catalog/lodge?id=18&lodgesearch[date...
# Name: 121, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=18&lodgesearch[date_start]=2018-02-27&lodgesearch[date_end]=2018-03-04', fragment='')
# 2018-02-27 - 2018-03-04
# pagePath    /en/lodge-catalog/lodge?id=19
# Name: 122, dtype: object
# pagePath    /en/lodge-catalog/lodge?id=19&lodgesearch[date...
# Name: 123, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=19&lodgesearch[date_start]=2018-02-24&lodgesearch[date_end]=2018-03-01', fragment='')
# 2018-02-24 - 2018-03-01
# pagePath    /en/lodge-catalog/lodge?id=19&lodgesearch[date...
# Name: 124, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=19&lodgesearch[date_start]=2018-02-27&lodgesearch[date_end]=2018-03-04', fragment='')
# 2018-02-27 - 2018-03-04
# pagePath    /en/lodge-catalog/lodge?id=19&lodgesearch[date...
# Name: 125, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=19&lodgesearch[date_start]=2018-07-17&lodgesearch[date_end]=2018-07-22', fragment='')
# 2018-07-17 - 2018-07-22
# pagePath    /en/lodge-catalog/lodge?id=2
# Name: 126, dtype: object
# pagePath    /en/lodge-catalog/lodge?id=2
# Name: 127, dtype: object
# pagePath    /en/lodge-catalog/lodge?id=2&lodgesearch[date_...
# Name: 128, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=2&lodgesearch[date_start]=2018-01-05&lodgesearch[date_end]=2018-01-10', fragment='')
# 2018-01-05 - 2018-01-10
# pagePath    /en/lodge-catalog/lodge?id=2&lodgesearch[date_...
# Name: 129, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=2&lodgesearch[date_start]=2018-01-25&lodgesearch[date_end]=2018-01-30&lodgesearch[num_adults]=2&lodgesearch[num_children]=0&lodgesearch[price_low]=0&lodgesearch[price_high]=9999&lodgesearch[village_id]=&lodgesearch[relevance]=', fragment='')
# 2018-01-25 - 2018-01-30
# pagePath    /en/lodge-catalog/lodge?id=2&lodgesearch[date_...
# Name: 130, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=2&lodgesearch[date_start]=2018-03-01&lodgesearch[date_end]=2018-03-06', fragment='')
# 2018-03-01 - 2018-03-06
# pagePath    /en/lodge-catalog/lodge?id=2&lodgesearch[date_...
# Name: 131, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=2&lodgesearch[date_start]=2018-10-22&lodgesearch[date_end]=2018-10-24&lodgesearch[num_adults]=2&lodgesearch[num_children]=1&lodgesearch[price_low]=0&lodgesearch[price_high]=9999&lodgesearch[village_id]=&lodgesearch[relevance]=', fragment='')
# 2018-10-22 - 2018-10-24
# pagePath    /en/lodge-catalog/lodge?id=20&lodgesearch[date...
# Name: 132, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=20&lodgesearch[date_start]=2018-03-05&lodgesearch[date_end]=2018-03-10', fragment='')
# 2018-03-05 - 2018-03-10
# pagePath    /en/lodge-catalog/lodge?id=20&lodgesearch[date...
# Name: 133, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=20&lodgesearch[date_start]=2018-07-17&lodgesearch[date_end]=2018-07-22', fragment='')
# 2018-07-17 - 2018-07-22
# pagePath    /en/lodge-catalog/lodge?id=22
# Name: 134, dtype: object
# pagePath    /en/lodge-catalog/lodge?id=22
# Name: 135, dtype: object
# pagePath    /en/lodge-catalog/lodge?id=22&lodgesearch[date...
# Name: 136, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=22&lodgesearch[date_start]=2018-02-27&lodgesearch[date_end]=2018-03-04', fragment='')
# 2018-02-27 - 2018-03-04
# pagePath    /en/lodge-catalog/lodge?id=23
# Name: 137, dtype: object
# pagePath    /en/lodge-catalog/lodge?id=23&lodgesearch[date...
# Name: 138, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=23&lodgesearch[date_start]=2018-02-24&lodgesearch[date_end]=2018-03-01', fragment='')
# 2018-02-24 - 2018-03-01
# pagePath    /en/lodge-catalog/lodge?id=24
# Name: 139, dtype: object
# pagePath    /en/lodge-catalog/lodge?id=24
# Name: 140, dtype: object
# pagePath    /en/lodge-catalog/lodge?id=24&lodgesearch[date...
# Name: 141, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=24&lodgesearch[date_start]=2018-08-26&lodgesearch[date_end]=2018-08-31', fragment='')
# 2018-08-26 - 2018-08-31
# pagePath    /en/lodge-catalog/lodge?id=25
# Name: 142, dtype: object
# pagePath    /en/lodge-catalog/lodge?id=25
# Name: 143, dtype: object
# pagePath    /en/lodge-catalog/lodge?id=25&lodgesearch[date...
# Name: 144, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=25&lodgesearch[date_start]=2018-02-12&lodgesearch[date_end]=2018-02-17', fragment='')
# 2018-02-12 - 2018-02-17
# pagePath    /en/lodge-catalog/lodge?id=26
# Name: 145, dtype: object
# pagePath    /en/lodge-catalog/lodge?id=27&lodgesearch[date...
# Name: 146, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=27&lodgesearch[date_start]=2018-04-24&lodgesearch[date_end]=2018-04-29&lodgesearch[num_adults]=2&lodgesearch[num_children]=2&lodgesearch[price_low]=0&lodgesearch[price_high]=9999&lodgesearch[village_id]=31&lodgesearch[relevance]=', fragment='')
# 2018-04-24 - 2018-04-29
# pagePath    /en/lodge-catalog/lodge?id=27&lodgesearch[date...
# Name: 147, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=27&lodgesearch[date_start]=2018-08-02&lodgesearch[date_end]=2018-08-07', fragment='')
# 2018-08-02 - 2018-08-07
# pagePath    /en/lodge-catalog/lodge?id=28&lodgesearch[date...
# Name: 148, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=28&lodgesearch[date_start]=2017-12-22&lodgesearch[date_end]=2017-12-27', fragment='')
# 2017-12-22 - 2017-12-27
# pagePath    /en/lodge-catalog/lodge?id=28&lodgesearch[date...
# Name: 149, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=28&lodgesearch[date_start]=2018-02-08&lodgesearch[date_end]=2018-02-13', fragment='')
# 2018-02-08 - 2018-02-13
# pagePath    /en/lodge-catalog/lodge?id=29&lodgesearch[date...
# Name: 150, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=29&lodgesearch[date_start]=2018-03-03&lodgesearch[date_end]=2018-03-08', fragment='')
# 2018-03-03 - 2018-03-08
# pagePath    /en/lodge-catalog/lodge?id=31&lodgesearch[date...
# Name: 151, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=31&lodgesearch[date_start]=2018-08-16&lodgesearch[date_end]=2018-08-21', fragment='')
# 2018-08-16 - 2018-08-21
# pagePath    /en/lodge-catalog/lodge?id=31&lodgesearch[date...
# Name: 152, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=31&lodgesearch[date_start]=2018-08-17&lodgesearch[date_end]=2018-08-22', fragment='')
# 2018-08-17 - 2018-08-22
# pagePath    /en/lodge-catalog/lodge?id=32&lodgesearch[date...
# Name: 153, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=32&lodgesearch[date_start]=2018-07-17&lodgesearch[date_end]=2018-07-22', fragment='')
# 2018-07-17 - 2018-07-22
# pagePath    /en/lodge-catalog/lodge?id=34&lodgesearch[date...
# Name: 154, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=34&lodgesearch[date_start]=2018-01-13&lodgesearch[date_end]=2018-12-31&lodgesearch[num_adults]=2&lodgesearch[num_children]=0&lodgesearch[price_low]=0&lodgesearch[price_high]=9999', fragment='')
# 2018-01-13 - 2018-12-31
# pagePath    /en/lodge-catalog/lodge?id=34&lodgesearch[date...
# Name: 155, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=34&lodgesearch[date_start]=2018-10-05&lodgesearch[date_end]=2018-10-07&lodgesearch[num_adults]=2&lodgesearch[num_children]=2&lodgesearch[price_low]=0&lodgesearch[price_high]=9999&lodgesearch[village_id]=12&lodgesearch[relevance]=cheap', fragment='')
# 2018-10-05 - 2018-10-07
# pagePath    /en/lodge-catalog/lodge?id=35
# Name: 156, dtype: object
# pagePath    /en/lodge-catalog/lodge?id=35
# Name: 157, dtype: object
# pagePath    /en/lodge-catalog/lodge?id=35&lodgesearch[date...
# Name: 158, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=35&lodgesearch[date_start]=2018-07-02&lodgesearch[date_end]=2018-07-07', fragment='')
# 2018-07-02 - 2018-07-07
# pagePath    /en/lodge-catalog/lodge?id=35&lodgesearch[date...
# Name: 159, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=35&lodgesearch[date_start]=2018-07-02&lodgesearch[date_end]=2018-07-07', fragment='')
# 2018-07-02 - 2018-07-07
# pagePath    /en/lodge-catalog/lodge?id=36
# Name: 160, dtype: object
# pagePath    /en/lodge-catalog/lodge?id=37
# Name: 161, dtype: object
# pagePath    /en/lodge-catalog/lodge?id=37&lodgesearch[date...
# Name: 162, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=37&lodgesearch[date_start]=2018-02-03&lodgesearch[date_end]=2018-02-08', fragment='')
# 2018-02-03 - 2018-02-08
# pagePath    /en/lodge-catalog/lodge?id=37&lodgesearch[date...
# Name: 163, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=37&lodgesearch[date_start]=2018-02-24&lodgesearch[date_end]=2018-03-01', fragment='')
# 2018-02-24 - 2018-03-01
# pagePath    /en/lodge-catalog/lodge?id=37&lodgesearch[date...
# Name: 164, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=37&lodgesearch[date_start]=2018-08-17&lodgesearch[date_end]=2018-08-22', fragment='')
# 2018-08-17 - 2018-08-22
# pagePath    /en/lodge-catalog/lodge?id=37&lodgesearch[date...
# Name: 165, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=37&lodgesearch[date_start]=2018-09-22&lodgesearch[date_end]=2018-09-23&lodgesearch[num_adults]=2&lodgesearch[num_children]=0&lodgesearch[price_low]=0&lodgesearch[price_high]=85&lodgesearch[village_id]=&lodgesearch[relevance]=', fragment='')
# 2018-09-22 - 2018-09-23
# pagePath    /en/lodge-catalog/lodge?id=37&lodgesearch[date...
# Name: 166, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=37&lodgesearch[date_start]=2018-09-27&lodgesearch[date_end]=2018-10-02', fragment='')
# 2018-09-27 - 2018-10-02
# pagePath    /en/lodge-catalog/lodge?id=38
# Name: 167, dtype: object
# pagePath    /en/lodge-catalog/lodge?id=38&lodgesearch[date...
# Name: 168, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=38&lodgesearch[date_start]=2018-02-03&lodgesearch[date_end]=2018-02-08', fragment='')
# 2018-02-03 - 2018-02-08
# pagePath    /en/lodge-catalog/lodge?id=39&lodgesearch[date...
# Name: 169, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=39&lodgesearch[date_start]=2018-03-01&lodgesearch[date_end]=2018-03-06', fragment='')
# 2018-03-01 - 2018-03-06
# pagePath    /en/lodge-catalog/lodge?id=39&lodgesearch[date...
# Name: 170, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=39&lodgesearch[date_start]=2018-08-17&lodgesearch[date_end]=2018-08-22', fragment='')
# 2018-08-17 - 2018-08-22
# pagePath    /en/lodge-catalog/lodge?id=39&lodgesearch[date...
# Name: 171, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=39&lodgesearch[date_start]=2018-09-24&lodgesearch[date_end]=2018-09-29', fragment='')
# 2018-09-24 - 2018-09-29
# pagePath    /en/lodge-catalog/lodge?id=4
# Name: 172, dtype: object
# pagePath    /en/lodge-catalog/lodge?id=4&lodgesearch[date_...
# Name: 173, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=4&lodgesearch[date_start]=2018-09-22&lodgesearch[date_end]=2018-09-23&lodgesearch[num_adults]=2&lodgesearch[num_children]=0&lodgesearch[price_low]=0&lodgesearch[price_high]=85&lodgesearch[village_id]=&lodgesearch[relevance]=', fragment='')
# 2018-09-22 - 2018-09-23
# pagePath    /en/lodge-catalog/lodge?id=40
# Name: 174, dtype: object
# pagePath    /en/lodge-catalog/lodge?id=40
# Name: 175, dtype: object
# pagePath    /en/lodge-catalog/lodge?id=40&lodgesearch[date...
# Name: 176, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=40&lodgesearch[date_start]=2018-01-15&lodgesearch[date_end]=2018-01-17&lodgesearch[num_adults]=2&lodgesearch[num_children]=0&lodgesearch[price_low]=0&lodgesearch[price_high]=9999', fragment='')
# 2018-01-15 - 2018-01-17
# pagePath    /en/lodge-catalog/lodge?id=40&lodgesearch[date...
# Name: 177, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=40&lodgesearch[date_start]=2018-01-26&lodgesearch[date_end]=2018-01-31', fragment='')
# 2018-01-26 - 2018-01-31
# pagePath    /en/lodge-catalog/lodge?id=40&lodgesearch[date...
# Name: 178, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=40&lodgesearch[date_start]=2018-01-28&lodgesearch[date_end]=2018-02-02', fragment='')
# 2018-01-28 - 2018-02-02
# pagePath    /en/lodge-catalog/lodge?id=40&lodgesearch[date...
# Name: 179, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=40&lodgesearch[date_start]=2018-01-28&lodgesearch[date_end]=2018-02-02', fragment='')
# 2018-01-28 - 2018-02-02
# pagePath    /en/lodge-catalog/lodge?id=40&lodgesearch[date...
# Name: 180, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=40&lodgesearch[date_start]=2018-01-28&lodgesearch[date_end]=2018-02-02', fragment='')
# 2018-01-28 - 2018-02-02
# pagePath    /en/lodge-catalog/lodge?id=40&lodgesearch[date...
# Name: 181, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=40&lodgesearch[date_start]=2018-01-30&lodgesearch[date_end]=2018-02-04', fragment='')
# 2018-01-30 - 2018-02-04
# pagePath    /en/lodge-catalog/lodge?id=40&lodgesearch[date...
# Name: 182, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=40&lodgesearch[date_start]=2018-01-30&lodgesearch[date_end]=2018-02-04', fragment='')
# 2018-01-30 - 2018-02-04
# pagePath    /en/lodge-catalog/lodge?id=40&lodgesearch[date...
# Name: 183, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=40&lodgesearch[date_start]=2018-06-12&lodgesearch[date_end]=2018-06-17', fragment='')
# 2018-06-12 - 2018-06-17
# pagePath    /en/lodge-catalog/lodge?id=43
# Name: 184, dtype: object
# pagePath    /en/lodge-catalog/lodge?id=43&lodgesearch[date...
# Name: 185, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=43&lodgesearch[date_start]=2018-08-17&lodgesearch[date_end]=2018-08-22', fragment='')
# 2018-08-17 - 2018-08-22
# pagePath    /en/lodge-catalog/lodge?id=44&lodgesearch[date...
# Name: 186, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=44&lodgesearch[date_start]=2018-03-22&lodgesearch[date_end]=2018-04-21&lodgesearch[num_adults]=2&lodgesearch[num_children]=0&lodgesearch[price_low]=0&lodgesearch[price_high]=9999', fragment='')
# 2018-03-22 - 2018-04-21
# pagePath    /en/lodge-catalog/lodge?id=45&lodgesearch[date...
# Name: 187, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=45&lodgesearch[date_start]=2018-01-15&lodgesearch[date_end]=2018-01-17&lodgesearch[num_adults]=2&lodgesearch[num_children]=0&lodgesearch[price_low]=0&lodgesearch[price_high]=9999', fragment='')
# 2018-01-15 - 2018-01-17
# pagePath    /en/lodge-catalog/lodge?id=45&lodgesearch[date...
# Name: 188, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=45&lodgesearch[date_start]=2018-02-01&lodgesearch[date_end]=2018-02-06', fragment='')
# 2018-02-01 - 2018-02-06
# pagePath    /en/lodge-catalog/lodge?id=45&lodgesearch[date...
# Name: 189, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=45&lodgesearch[date_start]=2018-05-13&lodgesearch[date_end]=2018-05-16&lodgesearch[num_adults]=2&lodgesearch[num_children]=0&lodgesearch[price_low]=0&lodgesearch[price_high]=60&lodgesearch[village_id]=&lodgesearch[relevance]=', fragment='')
# 2018-05-13 - 2018-05-16
# pagePath    /en/lodge-catalog/lodge?id=47
# Name: 190, dtype: object
# pagePath    /en/lodge-catalog/lodge?id=47&lodgesearch[date...
# Name: 191, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=47&lodgesearch[date_start]=2018-03-09&lodgesearch[date_end]=2018-03-14', fragment='')
# 2018-03-09 - 2018-03-14
# pagePath    /en/lodge-catalog/lodge?id=48&lodgesearch[date...
# Name: 192, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=48&lodgesearch[date_start]=2018-10-05&lodgesearch[date_end]=2018-10-07&lodgesearch[num_adults]=2&lodgesearch[num_children]=0&lodgesearch[price_low]=0&lodgesearch[price_high]=9999&lodgesearch[village_id]=&lodgesearch[relevance]=cheap', fragment='')
# 2018-10-05 - 2018-10-07
# pagePath    /en/lodge-catalog/lodge?id=49
# Name: 193, dtype: object
# pagePath    /en/lodge-catalog/lodge?id=49&lodgesearch[date...
# Name: 194, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=49&lodgesearch[date_start]=2018-02-12&lodgesearch[date_end]=2018-02-17', fragment='')
# 2018-02-12 - 2018-02-17
# pagePath    /en/lodge-catalog/lodge?id=49&lodgesearch[date...
# Name: 195, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=49&lodgesearch[date_start]=2018-02-24&lodgesearch[date_end]=2018-03-01', fragment='')
# 2018-02-24 - 2018-03-01
# pagePath    /en/lodge-catalog/lodge?id=5
# Name: 196, dtype: object
# pagePath    /en/lodge-catalog/lodge?id=5&lodgesearch[date_...
# Name: 197, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=5&lodgesearch[date_start]=2017-12-15&lodgesearch[date_end]=2017-12-20', fragment='')
# 2017-12-15 - 2017-12-20
# pagePath    /en/lodge-catalog/lodge?id=5&lodgesearch[date_...
# Name: 198, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=5&lodgesearch[date_start]=2018-03-11&lodgesearch[date_end]=2018-03-16', fragment='')
# 2018-03-11 - 2018-03-16
# pagePath    /en/lodge-catalog/lodge?id=5&lodgesearch[date_...
# Name: 199, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=5&lodgesearch[date_start]=2018-08-07&lodgesearch[date_end]=2018-08-09&lodgesearch[num_adults]=2&lodgesearch[num_children]=0&lodgesearch[price_low]=0&lodgesearch[price_high]=86&lodgesearch[village_id]=&lodgesearch[relevance]=best', fragment='')
# 2018-08-07 - 2018-08-09
# pagePath    /en/lodge-catalog/lodge?id=50
# Name: 200, dtype: object
# pagePath    /en/lodge-catalog/lodge?id=51
# Name: 201, dtype: object
# pagePath    /en/lodge-catalog/lodge?id=51
# Name: 202, dtype: object
# pagePath    /en/lodge-catalog/lodge?id=51&lodgesearch[date...
# Name: 203, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=51&lodgesearch[date_start]=2018-01-30&lodgesearch[date_end]=2018-02-04', fragment='')
# 2018-01-30 - 2018-02-04
# pagePath    /en/lodge-catalog/lodge?id=52
# Name: 204, dtype: object
# pagePath    /en/lodge-catalog/lodge?id=52&lodgesearch[date...
# Name: 205, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=52&lodgesearch[date_start]=2018-05-11&lodgesearch[date_end]=2018-05-13&lodgesearch[num_adults]=2&lodgesearch[num_children]=0&lodgesearch[price_low]=0&lodgesearch[price_high]=80&lodgesearch[village_id]=&lodgesearch[relevance]=cheap', fragment='')
# 2018-05-11 - 2018-05-13
# pagePath    /en/lodge-catalog/lodge?id=52&lodgesearch[date...
# Name: 206, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=52&lodgesearch[date_start]=2018-05-11&lodgesearch[date_end]=2018-05-13&lodgesearch[num_adults]=2&lodgesearch[num_children]=0&lodgesearch[price_low]=0&lodgesearch[price_high]=80&lodgesearch[village_id]=&lodgesearch[relevance]=cheap', fragment='')
# 2018-05-11 - 2018-05-13
# pagePath    /en/lodge-catalog/lodge?id=53
# Name: 207, dtype: object
# pagePath    /en/lodge-catalog/lodge?id=53&lodgesearch[date...
# Name: 208, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=53&lodgesearch[date_start]=2018-02-24&lodgesearch[date_end]=2018-03-01', fragment='')
# 2018-02-24 - 2018-03-01
# pagePath    /en/lodge-catalog/lodge?id=55
# Name: 209, dtype: object
# pagePath    /en/lodge-catalog/lodge?id=55
# Name: 210, dtype: object
# pagePath    /en/lodge-catalog/lodge?id=55&lodgesearch[date...
# Name: 211, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=55&lodgesearch[date_start]=2018-02-02&lodgesearch[date_end]=2018-02-07&lodgesearch[num_adults]=2&lodgesearch[num_children]=0&lodgesearch[price_low]=0&lodgesearch[price_high]=9999', fragment='')
# 2018-02-02 - 2018-02-07
# pagePath    /en/lodge-catalog/lodge?id=55&lodgesearch[date...
# Name: 212, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=55&lodgesearch[date_start]=2018-02-02&lodgesearch[date_end]=2018-02-07&lodgesearch[num_adults]=2&lodgesearch[num_children]=0&lodgesearch[price_low]=0&lodgesearch[price_high]=9999', fragment='')
# 2018-02-02 - 2018-02-07
# pagePath    /en/lodge-catalog/lodge?id=55&lodgesearch[date...
# Name: 213, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=55&lodgesearch[date_start]=2018-02-02&lodgesearch[date_end]=2018-02-07&lodgesearch[num_adults]=2&lodgesearch[num_children]=0&lodgesearch[price_low]=0&lodgesearch[price_high]=9999', fragment='')
# 2018-02-02 - 2018-02-07
# pagePath    /en/lodge-catalog/lodge?id=55&lodgesearch[date...
# Name: 214, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=55&lodgesearch[date_start]=2018-02-02&lodgesearch[date_end]=2018-02-07&lodgesearch[num_adults]=2&lodgesearch[num_children]=0&lodgesearch[price_low]=0&lodgesearch[price_high]=9999', fragment='')
# 2018-02-02 - 2018-02-07
# pagePath    /en/lodge-catalog/lodge?id=57
# Name: 215, dtype: object
# pagePath    /en/lodge-catalog/lodge?id=57
# Name: 216, dtype: object
# pagePath    /en/lodge-catalog/lodge?id=57
# Name: 217, dtype: object
# pagePath    /en/lodge-catalog/lodge?id=57&lodgesearch[date...
# Name: 218, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=57&lodgesearch[date_start]=2018-01-09&lodgesearch[date_end]=2018-01-14', fragment='')
# 2018-01-09 - 2018-01-14
# pagePath    /en/lodge-catalog/lodge?id=57&lodgesearch[date...
# Name: 219, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=57&lodgesearch[date_start]=2018-03-13&lodgesearch[date_end]=2018-03-16&lodgesearch[num_adults]=2&lodgesearch[num_children]=0&lodgesearch[price_low]=0&lodgesearch[price_high]=70&lodgesearch[village_id]=&lodgesearch[relevance]=', fragment='')
# 2018-03-13 - 2018-03-16
# pagePath    /en/lodge-catalog/lodge?id=57&lodgesearch[date...
# Name: 220, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=57&lodgesearch[date_start]=2018-06-16&lodgesearch[date_end]=2018-06-17&lodgesearch[num_adults]=2&lodgesearch[num_children]=0&lodgesearch[price_low]=0&lodgesearch[price_high]=9999', fragment='')
# 2018-06-16 - 2018-06-17
# pagePath    /en/lodge-catalog/lodge?id=57&lodgesearch[date...
# Name: 221, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=57&lodgesearch[date_start]=2018-10-22&lodgesearch[date_end]=2018-10-24&lodgesearch[num_adults]=2&lodgesearch[num_children]=1&lodgesearch[price_low]=0&lodgesearch[price_high]=9999&lodgesearch[village_id]=&lodgesearch[relevance]=', fragment='')
# 2018-10-22 - 2018-10-24
# pagePath    /en/lodge-catalog/lodge?id=58
# Name: 222, dtype: object
# pagePath    /en/lodge-catalog/lodge?id=59&lodgesearch[date...
# Name: 223, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=59&lodgesearch[date_start]=2018-07-21&lodgesearch[date_end]=2018-07-28&lodgesearch[num_adults]=2&lodgesearch[num_children]=2&lodgesearch[price_low]=0&lodgesearch[price_high]=9999', fragment='')
# 2018-07-21 - 2018-07-28
# pagePath    /en/lodge-catalog/lodge?id=59&lodgesearch[date...
# Name: 224, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=59&lodgesearch[date_start]=2018-10-22&lodgesearch[date_end]=2018-10-24&lodgesearch[num_adults]=2&lodgesearch[num_children]=1&lodgesearch[price_low]=0&lodgesearch[price_high]=9999&lodgesearch[village_id]=&lodgesearch[relevance]=', fragment='')
# 2018-10-22 - 2018-10-24
# pagePath    /en/lodge-catalog/lodge?id=60
# Name: 225, dtype: object
# pagePath    /en/lodge-catalog/lodge?id=60&lodgesearch[date...
# Name: 226, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=60&lodgesearch[date_start]=2018-01-16&lodgesearch[date_end]=2018-01-21', fragment='')
# 2018-01-16 - 2018-01-21
# pagePath    /en/lodge-catalog/lodge?id=60&lodgesearch[date...
# Name: 227, dtype: object
# SplitResult(scheme='', netloc='', path='/en/lodge-catalog/lodge', query='id=60&lodgesearch[date_start]=2018-02-17&lodgesearch[date_end]=2018-02-22', fragment='')
# 2018-02-17 - 2018-02-22
# pagePath    /en/lodge-catalog/lodge?id=61
# Name: 228, dtype: object
# pagePath    /en/lodge-catalog/lodge?id=61&lodgesearch[date...
# Name: 229, dtype: object
# ...
# SplitResult(scheme='', netloc='', path='/pt/lodge-catalog/lodge', query='lodgesearch[num_adults]=5&lodgesearch[num_children]=3&lodgesearch[date_start]=2018-06-14&lodgesearch[date_end]=2018-06-19&id=59', fragment='')
# 2018-06-14 - 2018-06-19
# pagePath    /pt/lodge-catalog/lodge?lodgesearch[num_adults...
# Name: 3710, dtype: object
# SplitResult(scheme='', netloc='', path='/pt/lodge-catalog/lodge', query='lodgesearch[num_adults]=5&lodgesearch[num_children]=3&lodgesearch[date_start]=2018-06-19&lodgesearch[date_end]=2018-07-11&id=39', fragment='')
# 2018-06-19 - 2018-07-11
# pagePath    /pt/lodge-catalog/lodge?lodgesearch[num_adults...
# Name: 3711, dtype: object
# SplitResult(scheme='', netloc='', path='/pt/lodge-catalog/lodge', query='lodgesearch[num_adults]=5&lodgesearch[num_children]=4&lodgesearch[date_start]=2018-06-14&lodgesearch[date_end]=2018-06-19&id=98', fragment='')
# 2018-06-14 - 2018-06-19
# pagePath    /pt/lodge-catalog/lodge?lodgesearch[num_adults...
# Name: 3712, dtype: object
# SplitResult(scheme='', netloc='', path='/pt/lodge-catalog/lodge', query='lodgesearch[num_adults]=5&lodgesearch[num_children]=4&lodgesearch[date_start]=2018-06-16&lodgesearch[date_end]=2018-06-17&id=27', fragment='')
# 2018-06-16 - 2018-06-17
# pagePath    /pt/lodge-catalog/lodge?lodgesearch[num_adults...
# Name: 3713, dtype: object
# SplitResult(scheme='', netloc='', path='/pt/lodge-catalog/lodge', query='lodgesearch[num_adults]=6&lodgesearch[num_children]=0&lodgesearch[date_start]=2018-06-08&lodgesearch[date_end]=2018-06-13&id=80', fragment='')
# 2018-06-08 - 2018-06-13
# pagePath    /pt/lodge-catalog/lodge?lodgesearch[num_adults...
# Name: 3714, dtype: object
# SplitResult(scheme='', netloc='', path='/pt/lodge-catalog/lodge', query='lodgesearch[num_adults]=6&lodgesearch[num_children]=0&lodgesearch[date_start]=2018-06-16&lodgesearch[date_end]=2018-06-17&id=66', fragment='')
# 2018-06-16 - 2018-06-17
# pagePath    /pt/lodge-catalog/lodge?lodgesearch[num_adults...
# Name: 3715, dtype: object
# SplitResult(scheme='', netloc='', path='/pt/lodge-catalog/lodge', query='lodgesearch[num_adults]=6&lodgesearch[num_children]=1&lodgesearch[date_start]=2018-02-24&lodgesearch[date_end]=2018-02-25&id=2', fragment='')
# 2018-02-24 - 2018-02-25
# pagePath    /pt/lodge-catalog/lodge?lodgesearch[num_adults...
# Name: 3716, dtype: object
# SplitResult(scheme='', netloc='', path='/pt/lodge-catalog/lodge', query='lodgesearch[num_adults]=6&lodgesearch[num_children]=1&lodgesearch[date_start]=2018-02-24&lodgesearch[date_end]=2018-02-25&id=2', fragment='')
# 2018-02-24 - 2018-02-25
# pagePath    /pt/lodge-catalog/lodge?lodgesearch[num_adults...
# Name: 3717, dtype: object
# SplitResult(scheme='', netloc='', path='/pt/lodge-catalog/lodge', query='lodgesearch[num_adults]=6&lodgesearch[num_children]=1&lodgesearch[date_start]=2018-05-26&lodgesearch[date_end]=2018-05-27&id=66', fragment='')
# 2018-05-26 - 2018-05-27
# pagePath    /pt/lodge-catalog/lodge?lodgesearch[num_adults...
# Name: 3718, dtype: object
# SplitResult(scheme='', netloc='', path='/pt/lodge-catalog/lodge', query='lodgesearch[num_adults]=6&lodgesearch[num_children]=1&lodgesearch[date_start]=2019-1-4&lodgesearch[date_end]=2019-1-6&id=66', fragment='')
# 2019-1-4 - 2019-1-6
# pagePath    /pt/lodge-catalog/lodge?lodgesearch[num_adults...
# Name: 3719, dtype: object
# SplitResult(scheme='', netloc='', path='/pt/lodge-catalog/lodge', query='lodgesearch[num_adults]=6&lodgesearch[num_children]=2&lodgesearch[date_start]=2018-3-30&lodgesearch[date_end]=2018-4-1&id=93', fragment='')
# 2018-3-30 - 2018-4-1
# pagePath    /pt/lodge-catalog/lodge?lodgesearch[num_adults...
# Name: 3720, dtype: object
# SplitResult(scheme='', netloc='', path='/pt/lodge-catalog/lodge', query='lodgesearch[num_adults]=6&lodgesearch[num_children]=2&lodgesearch[date_start]=2018-4-14&lodgesearch[date_end]=2018-4-15&id=51', fragment='')
# 2018-4-14 - 2018-4-15
# pagePath    /pt/lodge-catalog/lodge?lodgesearch[num_adults...
# Name: 3721, dtype: object
# SplitResult(scheme='', netloc='', path='/pt/lodge-catalog/lodge', query='lodgesearch[num_adults]=6&lodgesearch[num_children]=2&lodgesearch[date_start]=2018-4-14&lodgesearch[date_end]=2018-4-15&id=51', fragment='')
# 2018-4-14 - 2018-4-15
# pagePath    /pt/lodge-catalog/lodge?lodgesearch[num_adults...
# Name: 3722, dtype: object
# SplitResult(scheme='', netloc='', path='/pt/lodge-catalog/lodge', query='lodgesearch[num_adults]=6&lodgesearch[num_children]=3&lodgesearch[date_start]=2018-8-1&lodgesearch[date_end]=2018-8-4&id=61', fragment='')
# 2018-8-1 - 2018-8-4
# pagePath    /pt/lodge-catalog/lodge?lodgesearch[num_adults...
# Name: 3723, dtype: object
# SplitResult(scheme='', netloc='', path='/pt/lodge-catalog/lodge', query='lodgesearch[num_adults]=6&lodgesearch[num_children]=3&lodgesearch[date_start]=2018-8-1&lodgesearch[date_end]=2018-8-4&id=61', fragment='')
# 2018-8-1 - 2018-8-4
# pagePath    /pt/lodge-catalog/lodge?lodgesearch[num_adults...
# Name: 3724, dtype: object
# SplitResult(scheme='', netloc='', path='/pt/lodge-catalog/lodge', query='lodgesearch[num_adults]=6&lodgesearch[num_children]=4&lodgesearch[date_start]=2018-06-15&lodgesearch[date_end]=2018-06-19&id=90', fragment='')
# 2018-06-15 - 2018-06-19
# pagePath    /pt/lodge-catalog/lodge?lodgesearch[num_adults...
# Name: 3725, dtype: object
# SplitResult(scheme='', netloc='', path='/pt/lodge-catalog/lodge', query='lodgesearch[num_adults]=6&lodgesearch[num_children]=7&lodgesearch[date_start]=2018-06-15&lodgesearch[date_end]=2018-06-20&id=61', fragment='')
# 2018-06-15 - 2018-06-20
# pagePath    /pt/lodge-catalog/lodge?lodgesearch[num_adults...
# Name: 3726, dtype: object
# SplitResult(scheme='', netloc='', path='/pt/lodge-catalog/lodge', query='lodgesearch[num_adults]=8&lodgesearch[num_children]=3&lodgesearch[date_start]=2018-06-07&lodgesearch[date_end]=2018-06-08&id=36', fragment='')
# 2018-06-07 - 2018-06-08
# pagePath    /pt/lodge-catalog/lodge?lodgesearch[num_adults...
# Name: 3727, dtype: object
# SplitResult(scheme='', netloc='', path='/pt/lodge-catalog/lodge', query='lodgesearch[num_adults]=8&lodgesearch[num_children]=4&lodgesearch[date_start]=2018-06-13&lodgesearch[date_end]=2018-06-18&id=61', fragment='')
# 2018-06-13 - 2018-06-18
# pagePath    /pt/lodge-catalog/lodge?lodgesearch[num_adults...
# Name: 3728, dtype: object
# SplitResult(scheme='', netloc='', path='/pt/lodge-catalog/lodge', query='lodgesearch[num_adults]=9&lodgesearch[num_children]=7&lodgesearch[date_start]=2018-06-16&lodgesearch[date_end]=2018-07-04&id=81', fragment='')
# 2018-06-16 - 2018-07-04
# pagePath    /pt/lodge-catalog/lodge?lodgesearch[num_adults...
# Name: 3729, dtype: object
# SplitResult(scheme='', netloc='', path='/pt/lodge-catalog/lodge', query='lodgesearch[num_adults]=9&lodgesearch[num_children]=8&lodgesearch[date_start]=2018-06-09&lodgesearch[date_end]=2018-06-11&id=93', fragment='')
# 2018-06-09 - 2018-06-11
# pagePath    /pt/lodge-catalog/lodge?lodgesearch[num_childr...
# Name: 3730, dtype: object
# SplitResult(scheme='', netloc='', path='/pt/lodge-catalog/lodge', query='lodgesearch[num_children]=0&lodgesearch[date_start]=2018-06-09&lodgesearch[date_end]=2018-06-14&id=35', fragment='')
# 2018-06-09 - 2018-06-14
# pagePath    /pt/lodge-catalog/lodge?lodgesearch[num_childr...
# Name: 3731, dtype: object
# SplitResult(scheme='', netloc='', path='/pt/lodge-catalog/lodge', query='lodgesearch[num_children]=0&lodgesearch[date_start]=2018-1-15&lodgesearch[date_end]=2018-1-18&id=38', fragment='')
# 2018-1-15 - 2018-1-18
# pagePath    /pt/lodge-catalog/lodge?lodgesearch[num_childr...
# Name: 3732, dtype: object
# SplitResult(scheme='', netloc='', path='/pt/lodge-catalog/lodge', query='lodgesearch[num_children]=0&lodgesearch[date_start]=2018-1-15&lodgesearch[date_end]=2018-1-18&id=38', fragment='')
# 2018-1-15 - 2018-1-18
# pagePath    /pt/lodge-catalog/lodge?lodgesearch[num_childr...
# Name: 3733, dtype: object
# SplitResult(scheme='', netloc='', path='/pt/lodge-catalog/lodge', query='lodgesearch[num_children]=0&lodgesearch[date_start]=2018-1-15&lodgesearch[date_end]=2018-1-18&id=38', fragment='')
# 2018-1-15 - 2018-1-18
# pagePath    /pt/lodge-catalog/lodge?lodgesearch[num_childr...
# Name: 3734, dtype: object
# SplitResult(scheme='', netloc='', path='/pt/lodge-catalog/lodge', query='lodgesearch[num_children]=0&lodgesearch[date_start]=2018-1-15&lodgesearch[date_end]=2018-1-18&id=38', fragment='')
# 2018-1-15 - 2018-1-18
# pagePath    /pt/lodge-catalog/lodge?lodgesearch[num_childr...
# Name: 3735, dtype: object
# SplitResult(scheme='', netloc='', path='/pt/lodge-catalog/lodge', query='lodgesearch[num_children]=0&lodgesearch[date_start]=2018-1-15&lodgesearch[date_end]=2018-1-18&id=38', fragment='')
# 2018-1-15 - 2018-1-18
# pagePath    /pt/lodge-catalog/lodge?lodgesearch[num_childr...
# Name: 3736, dtype: object
# SplitResult(scheme='', netloc='', path='/pt/lodge-catalog/lodge', query='lodgesearch[num_children]=0&lodgesearch[date_start]=2018-1-15&lodgesearch[date_end]=2018-1-18&id=38', fragment='')
# 2018-1-15 - 2018-1-18
# pagePath    /pt/lodge-catalog/lodge?lodgesearch[num_childr...
# Name: 3737, dtype: object
# SplitResult(scheme='', netloc='', path='/pt/lodge-catalog/lodge', query='lodgesearch[num_children]=0&lodgesearch[date_start]=2018-1-15&lodgesearch[date_end]=2018-1-18&id=38', fragment='')
# 2018-1-15 - 2018-1-18
# pagePath    /pt/lodge-catalog/lodge?lodgesearch[num_childr...
# Name: 3738, dtype: object
# SplitResult(scheme='', netloc='', path='/pt/lodge-catalog/lodge', query='lodgesearch[num_children]=0&lodgesearch[date_start]=2018-1-15&lodgesearch[date_end]=2018-1-18&id=38', fragment='')
# 2018-1-15 - 2018-1-18
# pagePath    /pt/lodge-catalog/lodge?lodgesearch[num_childr...
# Name: 3739, dtype: object
# SplitResult(scheme='', netloc='', path='/pt/lodge-catalog/lodge', query='lodgesearch[num_children]=0&lodgesearch[date_start]=2018-1-15&lodgesearch[date_end]=2018-1-18&id=38', fragment='')
# 2018-1-15 - 2018-1-18
# pagePath    /pt/lodge-catalog/lodge?lodgesearch[num_childr...
# Name: 3740, dtype: object
# SplitResult(scheme='', netloc='', path='/pt/lodge-catalog/lodge', query='lodgesearch[num_children]=0&lodgesearch[date_start]=2018-1-15&lodgesearch[date_end]=2018-1-18&id=38', fragment='')
# 2018-1-15 - 2018-1-18
# pagePath    /pt/lodge-catalog/lodge?lodgesearch[num_childr...
# Name: 3741, dtype: object
# SplitResult(scheme='', netloc='', path='/pt/lodge-catalog/lodge', query='lodgesearch[num_children]=0&lodgesearch[date_start]=2018-1-15&lodgesearch[date_end]=2018-1-18&id=38', fragment='')
# 2018-1-15 - 2018-1-18
# pagePath    /pt/lodge-catalog/lodge?lodgesearch[num_childr...
# Name: 3742, dtype: object
# SplitResult(scheme='', netloc='', path='/pt/lodge-catalog/lodge', query='lodgesearch[num_children]=0&lodgesearch[date_start]=2018-1-15&lodgesearch[date_end]=2018-1-18&id=38', fragment='')
# 2018-1-15 - 2018-1-18
# pagePath    /pt/lodge-catalog/lodge?lodgesearch[num_childr...
# Name: 3743, dtype: object
# SplitResult(scheme='', netloc='', path='/pt/lodge-catalog/lodge', query='lodgesearch[num_children]=0&lodgesearch[date_start]=2018-1-15&lodgesearch[date_end]=2018-1-18&id=38', fragment='')
# 2018-1-15 - 2018-1-18
# pagePath    /pt/lodge-catalog/lodge?lodgesearch[num_childr...
# Name: 3744, dtype: object
# SplitResult(scheme='', netloc='', path='/pt/lodge-catalog/lodge', query='lodgesearch[num_children]=0&lodgesearch[date_start]=2018-1-15&lodgesearch[date_end]=2018-1-18&id=38', fragment='')
# 2018-1-15 - 2018-1-18
# pagePath    /pt/lodge-catalog/lodge?lodgesearch[num_childr...
# Name: 3745, dtype: object
# SplitResult(scheme='', netloc='', path='/pt/lodge-catalog/lodge', query='lodgesearch[num_children]=0&lodgesearch[date_start]=2018-1-15&lodgesearch[date_end]=2018-1-18&id=38', fragment='')
# 2018-1-15 - 2018-1-18
# pagePath    /pt/lodge-catalog/lodge?lodgesearch[num_childr...
# Name: 3746, dtype: object
# SplitResult(scheme='', netloc='', path='/pt/lodge-catalog/lodge', query='lodgesearch[num_children]=0&lodgesearch[date_start]=2018-10-27&lodgesearch[date_end]=2018-10-28&id=18', fragment='')
# 2018-10-27 - 2018-10-28
# pagePath    /pt/lodge-catalog/lodge?lodgesearch[num_childr...
# Name: 3747, dtype: object
# SplitResult(scheme='', netloc='', path='/pt/lodge-catalog/lodge', query='lodgesearch[num_children]=0&lodgesearch[date_start]=2018-10-8&lodgesearch[date_end]=2018-10-10&id=53', fragment='')
# 2018-10-8 - 2018-10-10
# pagePath    /pt/lodge-catalog/lodge?lodgesearch[num_childr...
# Name: 3748, dtype: object
# SplitResult(scheme='', netloc='', path='/pt/lodge-catalog/lodge', query='lodgesearch[num_children]=0&lodgesearch[date_start]=2018-2-2&lodgesearch[date_end]=2018-2-4&id=37', fragment='')
# 2018-2-2 - 2018-2-4
# pagePath    /pt/lodge-catalog/lodge?lodgesearch[num_childr...
# Name: 3749, dtype: object
# SplitResult(scheme='', netloc='', path='/pt/lodge-catalog/lodge', query='lodgesearch[num_children]=0&lodgesearch[date_start]=2018-3-3&lodgesearch[date_end]=2018-3-4&id=59', fragment='')
# 2018-3-3 - 2018-3-4
# pagePath    /pt/lodge-catalog/lodge?lodgesearch[num_childr...
# Name: 3750, dtype: object
# SplitResult(scheme='', netloc='', path='/pt/lodge-catalog/lodge', query='lodgesearch[num_children]=0&lodgesearch[date_start]=2018-3-31&lodgesearch[date_end]=2018-4-1&id=42', fragment='')
# 2018-3-31 - 2018-4-1
# pagePath    /pt/lodge-catalog/lodge?lodgesearch[num_childr...
# Name: 3751, dtype: object
# SplitResult(scheme='', netloc='', path='/pt/lodge-catalog/lodge', query='lodgesearch[num_children]=0&lodgesearch[date_start]=2018-3-31&lodgesearch[date_end]=2018-4-2&id=72', fragment='')
# 2018-3-31 - 2018-4-2
# pagePath    /pt/lodge-catalog/lodge?lodgesearch[num_childr...
# Name: 3752, dtype: object
# SplitResult(scheme='', netloc='', path='/pt/lodge-catalog/lodge', query='lodgesearch[num_children]=0&lodgesearch[date_start]=2018-4-30&lodgesearch[date_end]=2018-5-1&id=29', fragment='')
# 2018-4-30 - 2018-5-1
# pagePath    /pt/lodge-catalog/lodge?lodgesearch[num_childr...
# Name: 3753, dtype: object
# SplitResult(scheme='', netloc='', path='/pt/lodge-catalog/lodge', query='lodgesearch[num_children]=0&lodgesearch[date_start]=2018-4-6&lodgesearch[date_end]=2018-4-10&id=16', fragment='')
# 2018-4-6 - 2018-4-10
# pagePath    /pt/lodge-catalog/lodge?lodgesearch[num_childr...
# Name: 3754, dtype: object
# SplitResult(scheme='', netloc='', path='/pt/lodge-catalog/lodge', query='lodgesearch[num_children]=0&lodgesearch[date_start]=2018-4-6&lodgesearch[date_end]=2018-4-9&id=71', fragment='')
# 2018-4-6 - 2018-4-9
# pagePath    /pt/lodge-catalog/lodge?lodgesearch[num_childr...
# Name: 3755, dtype: object
# SplitResult(scheme='', netloc='', path='/pt/lodge-catalog/lodge', query='lodgesearch[num_children]=0&lodgesearch[date_start]=2018-5-25&lodgesearch[date_end]=2018-5-27&id=2', fragment='')
# 2018-5-25 - 2018-5-27
# pagePath    /pt/lodge-catalog/lodge?lodgesearch[num_childr...
# Name: 3756, dtype: object
# SplitResult(scheme='', netloc='', path='/pt/lodge-catalog/lodge', query='lodgesearch[num_children]=0&lodgesearch[date_start]=2018-5-31&lodgesearch[date_end]=2018-6-2&id=47', fragment='')
# 2018-5-31 - 2018-6-2
# pagePath    /pt/lodge-catalog/lodge?lodgesearch[num_childr...
# Name: 3757, dtype: object
# SplitResult(scheme='', netloc='', path='/pt/lodge-catalog/lodge', query='lodgesearch[num_children]=0&lodgesearch[date_start]=2018-5-9&lodgesearch[date_end]=2018-5-10&id=13', fragment='')
# 2018-5-9 - 2018-5-10
# pagePath    /pt/lodge-catalog/lodge?lodgesearch[num_childr...
# Name: 3758, dtype: object
# SplitResult(scheme='', netloc='', path='/pt/lodge-catalog/lodge', query='lodgesearch[num_children]=0&lodgesearch[date_start]=2018-8-15&lodgesearch[date_end]=2018-8-16&id=68', fragment='')
# 2018-8-15 - 2018-8-16
# pagePath    /pt/lodge-catalog/lodge?lodgesearch[num_childr...
# Name: 3759, dtype: object
# SplitResult(scheme='', netloc='', path='/pt/lodge-catalog/lodge', query='lodgesearch[num_children]=0&lodgesearch[date_start]=2018-9-27&lodgesearch[date_end]=2018-9-28&id=26', fragment='')
# 2018-9-27 - 2018-9-28
# pagePath    /pt/lodge-catalog/lodge?lodgesearch[num_childr...
# Name: 3760, dtype: object
# SplitResult(scheme='', netloc='', path='/pt/lodge-catalog/lodge', query='lodgesearch[num_children]=0&lodgesearch[date_start]=2018-9-8&lodgesearch[date_end]=2018-9-9&id=72', fragment='')
# 2018-9-8 - 2018-9-9

# %%
hash_map
# Out:
# {'id': {},
#  'lodgesearch[type_id]': {},
#  'lodgesearch[fulltext]': {},
#  'lodgesearch[num_adults]': {},
#  'lodgesearch[num_children]': {},
#  'lodgesearch[price_low]': {},
#  'lodgesearch[price_high]': {},
#  'lodgesearch[village_id]': {},
#  'lodgesearch[relevance]': {},
#  'experiencesearch[participants]': {},
#  'experiencesearch': {},
#  'amp': {},
#  'experiencesearch[fulltext]': {},
#  'experiencesearch[type_id]': {},
#  'tab': {},
#  'experiencesearch[village_id]': {},
#  'experiencesearch[relevance]': {},
#  'experiencesearch[price_low]': {},
#  'experiencesearch[price_high]': {},
#  'page': {},
#  'per-page': {},
#  'utm': {},
#  'lodgesearch[relev': {},
#  'lodgesearch': {},
#  '[date_start]': {},
#  '[date_end]': {},
#  '[num_adults]': {},
#  '[num_children]': {},
#  '[price_low]': {},
#  '[price_high]': {},
#  '[village_id]': {},
#  '[relevance]': {},
#  'lodgesearch{75adcb48f8b3e57af40f0d1fc6667c2f2c59e3b16b98654074f8f41091879777}5bdate_start{75adcb48f8b3e57af40f0d1fc6667c2f2c59e3b16b98654074f8f41091879777}5d': {},
#  'lodgesearch{75adcb48f8b3e57af40f0d1fc6667c2f2c59e3b16b98654074f8f41091879777}5bdate_end{75adcb48f8b3e57af40f0d1fc6667c2f2c59e3b16b98654074f8f41091879777}5d': {},
#  'lodgesearch{75adcb48f8b3e57af40f0d1fc6667c2f2c59e3b16b98654074f8f41091879777}5bnum_adults{75adcb48f8b3e57af40f0d1fc6667c2f2c59e3b16b98654074f8f41091879777}5d': {},
#  'lodgesearch{75adcb48f8b3e57af40f0d1fc6667c2f2c59e3b16b98654074f8f41091879777}5bnum_children{75adcb48f8b3e57af40f0d1fc6667c2f2c59e3b16b98654074f8f41091879777}5d': {},
#  'lodgesearch{75adcb48f8b3e57af40f0d1fc6667c2f2c59e3b16b98654074f8f41091879777}5bprice_low{75adcb48f8b3e57af40f0d1fc6667c2f2c59e3b16b98654074f8f41091879777}5d': {},
#  'lodgesearch{75adcb48f8b3e57af40f0d1fc6667c2f2c59e3b16b98654074f8f41091879777}5bprice_high{75adcb48f8b3e57af40f0d1fc6667c2f2c59e3b16b98654074f8f41091879777}5d': {},
#  'lodgesearch{75adcb48f8b3e57af40f0d1fc6667c2f2c59e3b16b98654074f8f41091879777}5bvillage_id{75adcb48f8b3e57af40f0d1fc6667c2f2c59e3b16b98654074f8f41091879777}5d': {},
#  'lodgesearch{75adcb48f8b3e57af40f0d1fc6667c2f2c59e3b16b98654074f8f41091879777}5brelevance{75adcb48f8b3e57af40f0d1fc6667c2f2c59e3b16b98654074f8f41091879777}5d': {},
#  'LodgeSearch_duration': {30: 100,
#   5: 3573,
#   2: 697,
#   7: 22,
#   337: 5,
#   340: 1,
#   12: 2,
#   1: 455,
#   3: 272,
#   4: 114,
#   352: 1,
#   328: 3,
#   318: 2,
#   305: 2,
#   6: 34,
#   332: 1,
#   302: 6,
#   336: 3,
#   310: 1,
#   0: 2,
#   303: 14,
#   8: 10,
#   20: 6,
#   316: 5,
#   351: 3,
#   308: 2,
#   304: 5,
#   9: 21,
#   346: 2,
#   11: 6,
#   29: 23,
#   312: 2,
#   338: 1,
#   314: 1,
#   26: 1,
#   341: 1,
#   331: 1,
#   329: 1,
#   333: 2,
#   326: 1,
#   317: 1,
#   313: 1,
#   311: 7,
#   348: 2,
#   322: 1,
#   321: 5,
#   347: 2,
#   349: 2,
#   306: 1,
#   356: 1,
#   345: 1,
#   301: 3,
#   22: 1,
#   18: 1},
#  'ExperienceSearch_duration': {5: 724,
#   192: 1,
#   1: 151,
#   0: 1,
#   2: 34,
#   311: 1,
#   135: 1,
#   118: 1,
#   365: 23,
#   4: 26,
#   292: 2,
#   7: 44,
#   29: 2},
#  'Index_duration': {},
#  'id_LodgeSearch': {'1': 458,
#   '11': 64,
#   '14': 79,
#   '17': 37,
#   '19': 145,
#   '2': 1004,
#   '22': 1263,
#   '29': 1521,
#   '35': 764,
#   '40': 517,
#   '45': 51,
#   '47': 3992,
#   '51': 385,
#   '52': 345,
#   '53': 58,
#   '55': 265,
#   '57': 2086,
#   '6': 803,
#   '62': 27,
#   '67': 258,
#   '78': 13,
#   '79': 336,
#   '80': 1561,
#   '87': 29,
#   '37': 501,
#   '10': 17,
#   '12': 466,
#   '13': 97,
#   '16': 286,
#   '18': 43,
#   '20': 26,
#   '23': 50,
#   '24': 168,
#   '25': 112,
#   '26': 770,
#   '27': 127,
#   '28': 1092,
#   '31': 279,
#   '32': 209,
#   '34': 585,
#   '36': 366,
#   '38': 763,
#   '39': 27,
#   '4': 38,
#   '43': 159,
#   '44': 87,
#   '48': 49,
#   '49': 70,
#   '5': 430,
#   '50': 48,
#   '58': 357,
#   '59': 2778,
#   '60': 154,
#   '61': 235,
#   '63': 99,
#   '64': 700,
#   '66': 248,
#   '68': 2549,
#   '71': 275,
#   '72': 1023,
#   '73': 13,
#   '74': 38,
#   '75': 10,
#   '81': 391,
#   '82': 390,
#   '89': 83,
#   '93': 252,
#   '95': 49,
#   '96': 517,
#   '98': 152,
#   '99': 84,
#   '108': 38,
#   '30': 157,
#   '42': 235,
#   '54': 214,
#   '77': 5,
#   '91': 99,
#   '92': 34,
#   '15': 50,
#   '107': 96,
#   '19 d': 1,
#   '46': 118,
#   '65': 163,
#   '76': 9,
#   '9': 5,
#   '90': 12},
#  'id_ExperienceSearch': {'140': 114,
#   '144': 41,
#   '155': 78,
#   '157': 185,
#   '22': 132,
#   '235': 34,
#   '246': 11,
#   '252': 4,
#   '282': 24,
#   '31': 15,
#   '32': 19,
#   '146': 22,
#   '147': 129,
#   '149': 246,
#   '150': 87,
#   '151': 108,
#   '154': 69,
#   '156': 2,
#   '206': 218,
#   '214': 4,
#   '215': 16,
#   '241': 46,
#   '247': 171,
#   '251': 264,
#   '254': 21,
#   '4': 40,
#   '286': 50,
#   '297': 1,
#   '158': 16,
#   '205': 10,
#   '249': 6,
#   '250': 8,
#   '284': 7,
#   '290': 3,
#   '294': 7,
#   '292': 7,
#   '293': 22,
#   '295': 1,
#   '296': 1,
#   '33': 24},
#  'id_Index': {'n': 905}}

# %%
for param in listOfParams:
    for item in param:
        currentSearch = str(param[item][0]).lower()
        if item not in denayDateParams:
            if(currentSearch in hash_map[item.lower()]):
                hash_map[item.lower()][currentSearch] = hash_map[item.lower()][currentSearch] + 1
            else:
                hash_map[item.lower()][currentSearch] = 1
#         print(param)
#         hash_map[item][] = param[item][0]

# %%
hash_map.keys()
aNewHope = {}
aNewHope['id_LodgeSearch'] = hash_map['id_LodgeSearch']
aNewHope['id_ExperienceSearch'] = hash_map['id_ExperienceSearch']
aNewHope['id_Index'] = hash_map['id_Index']
aNewHope['Index_duration'] = hash_map['Index_duration']
aNewHope['LodgeSearch_duration'] = hash_map['LodgeSearch_duration']
aNewHope['ExperienceSearch_duration'] = hash_map['ExperienceSearch_duration']

# %%
# json.dumps(aNewHope, ensure_ascii=False)
hash_map
# Out:
# {'id': {'140': 28,
#   '144': 19,
#   '155': 16,
#   '157': 30,
#   '22': 72,
#   '235': 15,
#   '246': 9,
#   '252': 4,
#   '282': 5,
#   '31': 30,
#   '32': 42,
#   '1': 85,
#   '11': 14,
#   '14': 24,
#   '17': 17,
#   '19': 40,
#   '2': 98,
#   '29': 40,
#   '35': 87,
#   '40': 53,
#   '45': 25,
#   '47': 66,
#   '51': 41,
#   '52': 50,
#   '53': 21,
#   '55': 47,
#   '57': 74,
#   '6': 42,
#   '62': 18,
#   '67': 30,
#   '78': 9,
#   '79': 41,
#   '80': 101,
#   '87': 13,
#   '37': 84,
#   '146': 13,
#   '147': 16,
#   '149': 18,
#   '150': 21,
#   '151': 14,
#   '154': 12,
#   '156': 1,
#   '206': 27,
#   '214': 2,
#   '215': 10,
#   '241': 22,
#   '247': 22,
#   '251': 30,
#   '254': 12,
#   '4': 35,
#   '10': 11,
#   '12': 16,
#   '13': 28,
#   '16': 12,
#   '18': 13,
#   '20': 12,
#   '23': 28,
#   '24': 29,
#   '25': 21,
#   '26': 64,
#   '27': 46,
#   '28': 25,
#   '34': 48,
#   '36': 22,
#   '38': 46,
#   '39': 25,
#   '43': 29,
#   '44': 35,
#   '48': 20,
#   '49': 40,
#   '5': 64,
#   '50': 16,
#   '58': 70,
#   '59': 48,
#   '60': 32,
#   '61': 57,
#   '63': 44,
#   '64': 25,
#   '66': 48,
#   '68': 142,
#   '71': 44,
#   '72': 92,
#   '73': 11,
#   '74': 14,
#   '75': 7,
#   '81': 40,
#   '82': 60,
#   '89': 25,
#   '93': 43,
#   '95': 14,
#   '96': 66,
#   '98': 19,
#   '99': 21,
#   '286': 11,
#   '297': 1,
#   '108': 18,
#   '30': 29,
#   '42': 42,
#   '54': 57,
#   '77': 3,
#   '91': 8,
#   '92': 11,
#   '158': 6,
#   '205': 8,
#   '249': 5,
#   '250': 6,
#   '284': 4,
#   '290': 3,
#   '294': 5,
#   '15': 30,
#   '292': 5,
#   '293': 5,
#   '295': 1,
#   '296': 1,
#   '33': 7,
#   '107': 43,
#   '19 d': 1,
#   '46': 13,
#   '65': 9,
#   '76': 4,
#   '9': 5,
#   '90': 4},
#  'lodgesearch[type_id]': {'': 138, '1': 15, '3': 2, '4': 2},
#  'lodgesearch[fulltext]': {'valedoninho': 5,
#   '': 48,
#   'cerdeiravillage': 10,
#   'oliveiras': 8,
#   'vale do ninho': 5,
#   'água formosa': 3,
#   'aldeias do xisto': 1,
#   'antão': 1,
#   'camelo': 1,
#   'camping': 5,
#   'camping oleiros': 1,
#   'cancela': 1,
#   'carregais': 3,
#   'casa do olival': 2,
#   'casa do terreiro': 1,
#   'casasdorio': 2,
#   'cerdeira': 1,
#   'cerdeira village': 2,
#   'comareira': 14,
#   'condes': 1,
#   'dão': 2,
#   'eira de cima': 1,
#   'fajao': 1,
#   'favacal': 3,
#   'ferraria': 3,
#   'figueiró dos vinhos': 1,
#   'formosa': 8,
#   'frias': 1,
#   'margarida': 1,
#   'oleiros': 7,
#   'piscina': 3,
#   'sapateiro': 1,
#   'sentido': 1,
#   'vilar dos condes': 1,
#   'xisto sentido': 7,
#   'animais domesticos': 1},
#  'lodgesearch[num_adults]': {'2': 1447,
#   '5': 30,
#   '6': 63,
#   '7': 12,
#   '12': 5,
#   '1': 17,
#   '3': 34,
#   '4': 109,
#   '8': 15,
#   '10': 6,
#   '11': 6,
#   '9': 2},
#  'lodgesearch[num_children]': {'0': 1490,
#   '1': 83,
#   '2': 92,
#   '3': 14,
#   '4': 14,
#   '8': 2,
#   '5': 2,
#   '6': 3,
#   '7': 3,
#   '53': 1,
#   '44': 1,
#   '13': 1},
#  'lodgesearch[price_low]': {'0': 1433, '39': 1},
#  'lodgesearch[price_high]': {'9999': 1260,
#   '79': 3,
#   '85': 2,
#   '60': 2,
#   '86': 1,
#   '80': 4,
#   '70': 3,
#   '2500': 114,
#   '76': 1,
#   '100': 1,
#   '81': 5,
#   '228': 1,
#   '9999?utm_source=e-konomista.pt': 9,
#   '99': 2,
#   '61': 1,
#   '131': 1,
#   '141': 1,
#   '164': 2,
#   '50': 2,
#   '57': 1,
#   '103': 1,
#   '66': 1,
#   '75': 1,
#   '54': 1,
#   '78': 2,
#   '150': 1,
#   '110': 2,
#   '211': 2,
#   '176': 2,
#   '89': 2,
#   '156': 1,
#   '148': 1,
#   '109': 1},
#  'lodgesearch[village_id]': {'1': 89,
#   '': 410,
#   '14': 2,
#   '36': 3,
#   '31': 66,
#   '12': 7,
#   '41': 29,
#   '11': 4,
#   '10': 8,
#   '27': 7,
#   '4': 6,
#   '46': 4,
#   '51': 5,
#   '6': 13,
#   '7': 28,
#   '8': 29,
#   '3': 1,
#   '50': 4,
#   '39': 1,
#   '15': 4,
#   '58': 2,
#   '22': 1,
#   '23': 8,
#   '28': 1,
#   '29': 3,
#   '13': 1,
#   '20': 3,
#   '9': 3,
#   '25': 1,
#   '34': 3,
#   '49': 1,
#   '30': 5,
#   '21': 4},
#  'lodgesearch[relevance]': {'': 557,
#   'cheap': 178,
#   'best': 17,
#   'expensive': 3,
#   'https://bookinxisto.com/pt/lodge-catalog/lodge?id=71': 8},
#  'experiencesearch[participants]': {'2': 121,
#   '8': 4,
#   '1': 1,
#   '4': 6,
#   '6': 2,
#   '2?utm_source=e-konomista.pt': 8},
#  'experiencesearch': {'': 2},
#  'amp': {'': 3},
#  'experiencesearch[fulltext]': {'avent_lousa': 4,
#   'bem': 2,
#   'brandão': 3,
#   'buke': 3,
#   'experiencia_vida': 3,
#   'fiado': 3,
#   'museu': 3,
#   'sabores': 6,
#   'ti augusta': 1,
#   'varanda': 3,
#   'velha': 1,
#   '': 2,
#   'jazz': 5,
#   'lagarada': 1,
#   'viagem': 1},
#  'experiencesearch[type_id]': {'1': 25, '': 8, '4': 1},
#  'tab': {'restaurants': 25},
#  'experiencesearch[village_id]': {'': 10, '49': 1, '45': 1},
#  'experiencesearch[relevance]': {'': 12},
#  'experiencesearch[price_low]': {'0': 11},
#  'experiencesearch[price_high]': {'2500': 11},
#  'page': {'1': 1},
#  'per-page': {'15': 1},
#  'utm': {'': 2},
#  'lodgesearch[relev': {'': 1},
#  'lodgesearch': {'': 8},
#  '[date_start]': {'2017-12-29': 1},
#  '[date_end]': {'2018-01-01': 1},
#  '[num_adults]': {'2': 1},
#  '[num_children]': {'0': 1},
#  '[price_low]': {'0': 1},
#  '[price_high]': {'9999': 1},
#  '[village_id]': {'41': 1},
#  '[relevance]': {'': 1},
#  'lodgesearch{75adcb48f8b3e57af40f0d1fc6667c2f2c59e3b16b98654074f8f41091879777}5bdate_start{75adcb48f8b3e57af40f0d1fc6667c2f2c59e3b16b98654074f8f41091879777}5d': {'2017-12-29': 2},
#  'lodgesearch{75adcb48f8b3e57af40f0d1fc6667c2f2c59e3b16b98654074f8f41091879777}5bdate_end{75adcb48f8b3e57af40f0d1fc6667c2f2c59e3b16b98654074f8f41091879777}5d': {'2018-01-01': 2},
#  'lodgesearch{75adcb48f8b3e57af40f0d1fc6667c2f2c59e3b16b98654074f8f41091879777}5bnum_adults{75adcb48f8b3e57af40f0d1fc6667c2f2c59e3b16b98654074f8f41091879777}5d': {'2': 2},
#  'lodgesearch{75adcb48f8b3e57af40f0d1fc6667c2f2c59e3b16b98654074f8f41091879777}5bnum_children{75adcb48f8b3e57af40f0d1fc6667c2f2c59e3b16b98654074f8f41091879777}5d': {'0': 2},
#  'lodgesearch{75adcb48f8b3e57af40f0d1fc6667c2f2c59e3b16b98654074f8f41091879777}5bprice_low{75adcb48f8b3e57af40f0d1fc6667c2f2c59e3b16b98654074f8f41091879777}5d': {'0': 2},
#  'lodgesearch{75adcb48f8b3e57af40f0d1fc6667c2f2c59e3b16b98654074f8f41091879777}5bprice_high{75adcb48f8b3e57af40f0d1fc6667c2f2c59e3b16b98654074f8f41091879777}5d': {'9999': 2},
#  'lodgesearch{75adcb48f8b3e57af40f0d1fc6667c2f2c59e3b16b98654074f8f41091879777}5bvillage_id{75adcb48f8b3e57af40f0d1fc6667c2f2c59e3b16b98654074f8f41091879777}5d': {'41': 2},
#  'lodgesearch{75adcb48f8b3e57af40f0d1fc6667c2f2c59e3b16b98654074f8f41091879777}5brelevance{75adcb48f8b3e57af40f0d1fc6667c2f2c59e3b16b98654074f8f41091879777}5d': {'': 2},
#  'LodgeSearch_duration': {30: 100,
#   5: 3573,
#   2: 697,
#   7: 22,
#   337: 5,
#   340: 1,
#   12: 2,
#   1: 455,
#   3: 272,
#   4: 114,
#   352: 1,
#   328: 3,
#   318: 2,
#   305: 2,
#   6: 34,
#   332: 1,
#   302: 6,
#   336: 3,
#   310: 1,
#   0: 2,
#   303: 14,
#   8: 10,
#   20: 6,
#   316: 5,
#   351: 3,
#   308: 2,
#   304: 5,
#   9: 21,
#   346: 2,
#   11: 6,
#   29: 23,
#   312: 2,
#   338: 1,
#   314: 1,
#   26: 1,
#   341: 1,
#   331: 1,
#   329: 1,
#   333: 2,
#   326: 1,
#   317: 1,
#   313: 1,
#   311: 7,
#   348: 2,
#   322: 1,
#   321: 5,
#   347: 2,
#   349: 2,
#   306: 1,
#   356: 1,
#   345: 1,
#   301: 3,
#   22: 1,
#   18: 1},
#  'ExperienceSearch_duration': {5: 724,
#   192: 1,
#   1: 151,
#   0: 1,
#   2: 34,
#   311: 1,
#   135: 1,
#   118: 1,
#   365: 23,
#   4: 26,
#   292: 2,
#   7: 44,
#   29: 2},
#  'Index_duration': {},
#  'id_LodgeSearch': {'1': 458,
#   '11': 64,
#   '14': 79,
#   '17': 37,
#   '19': 145,
#   '2': 1004,
#   '22': 1263,
#   '29': 1521,
#   '35': 764,
#   '40': 517,
#   '45': 51,
#   '47': 3992,
#   '51': 385,
#   '52': 345,
#   '53': 58,
#   '55': 265,
#   '57': 2086,
#   '6': 803,
#   '62': 27,
#   '67': 258,
#   '78': 13,
#   '79': 336,
#   '80': 1561,
#   '87': 29,
#   '37': 501,
#   '10': 17,
#   '12': 466,
#   '13': 97,
#   '16': 286,
#   '18': 43,
#   '20': 26,
#   '23': 50,
#   '24': 168,
#   '25': 112,
#   '26': 770,
#   '27': 127,
#   '28': 1092,
#   '31': 279,
#   '32': 209,
#   '34': 585,
#   '36': 366,
#   '38': 763,
#   '39': 27,
#   '4': 38,
#   '43': 159,
#   '44': 87,
#   '48': 49,
#   '49': 70,
#   '5': 430,
#   '50': 48,
#   '58': 357,
#   '59': 2778,
#   '60': 154,
#   '61': 235,
#   '63': 99,
#   '64': 700,
#   '66': 248,
#   '68': 2549,
#   '71': 275,
#   '72': 1023,
#   '73': 13,
#   '74': 38,
#   '75': 10,
#   '81': 391,
#   '82': 390,
#   '89': 83,
#   '93': 252,
#   '95': 49,
#   '96': 517,
#   '98': 152,
#   '99': 84,
#   '108': 38,
#   '30': 157,
#   '42': 235,
#   '54': 214,
#   '77': 5,
#   '91': 99,
#   '92': 34,
#   '15': 50,
#   '107': 96,
#   '19 d': 1,
#   '46': 118,
#   '65': 163,
#   '76': 9,
#   '9': 5,
#   '90': 12},
#  'id_ExperienceSearch': {'140': 114,
#   '144': 41,
#   '155': 78,
#   '157': 185,
#   '22': 132,
#   '235': 34,
#   '246': 11,
#   '252': 4,
#   '282': 24,
#   '31': 15,
#   '32': 19,
#   '146': 22,
#   '147': 129,
#   '149': 246,
#   '150': 87,
#   '151': 108,
#   '154': 69,
#   '156': 2,
#   '206': 218,
#   '214': 4,
#   '215': 16,
#   '241': 46,
#   '247': 171,
#   '251': 264,
#   '254': 21,
#   '4': 40,
#   '286': 50,
#   '297': 1,
#   '158': 16,
#   '205': 10,
#   '249': 6,
#   '250': 8,
#   '284': 7,
#   '290': 3,
#   '294': 7,
#   '292': 7,
#   '293': 22,
#   '295': 1,
#   '296': 1,
#   '33': 24},
#  'id_Index': {'n': 905}}

# %%
aNewHope
# Out:
# {'id_LodgeSearch': {'1': 458,
#   '11': 64,
#   '14': 79,
#   '17': 37,
#   '19': 145,
#   '2': 1004,
#   '22': 1263,
#   '29': 1521,
#   '35': 764,
#   '40': 517,
#   '45': 51,
#   '47': 3992,
#   '51': 385,
#   '52': 345,
#   '53': 58,
#   '55': 265,
#   '57': 2086,
#   '6': 803,
#   '62': 27,
#   '67': 258,
#   '78': 13,
#   '79': 336,
#   '80': 1561,
#   '87': 29,
#   '37': 501,
#   '10': 17,
#   '12': 466,
#   '13': 97,
#   '16': 286,
#   '18': 43,
#   '20': 26,
#   '23': 50,
#   '24': 168,
#   '25': 112,
#   '26': 770,
#   '27': 127,
#   '28': 1092,
#   '31': 279,
#   '32': 209,
#   '34': 585,
#   '36': 366,
#   '38': 763,
#   '39': 27,
#   '4': 38,
#   '43': 159,
#   '44': 87,
#   '48': 49,
#   '49': 70,
#   '5': 430,
#   '50': 48,
#   '58': 357,
#   '59': 2778,
#   '60': 154,
#   '61': 235,
#   '63': 99,
#   '64': 700,
#   '66': 248,
#   '68': 2549,
#   '71': 275,
#   '72': 1023,
#   '73': 13,
#   '74': 38,
#   '75': 10,
#   '81': 391,
#   '82': 390,
#   '89': 83,
#   '93': 252,
#   '95': 49,
#   '96': 517,
#   '98': 152,
#   '99': 84,
#   '108': 38,
#   '30': 157,
#   '42': 235,
#   '54': 214,
#   '77': 5,
#   '91': 99,
#   '92': 34,
#   '15': 50,
#   '107': 96,
#   '19 d': 1,
#   '46': 118,
#   '65': 163,
#   '76': 9,
#   '9': 5,
#   '90': 12},
#  'id_ExperienceSearch': {'140': 114,
#   '144': 41,
#   '155': 78,
#   '157': 185,
#   '22': 132,
#   '235': 34,
#   '246': 11,
#   '252': 4,
#   '282': 24,
#   '31': 15,
#   '32': 19,
#   '146': 22,
#   '147': 129,
#   '149': 246,
#   '150': 87,
#   '151': 108,
#   '154': 69,
#   '156': 2,
#   '206': 218,
#   '214': 4,
#   '215': 16,
#   '241': 46,
#   '247': 171,
#   '251': 264,
#   '254': 21,
#   '4': 40,
#   '286': 50,
#   '297': 1,
#   '158': 16,
#   '205': 10,
#   '249': 6,
#   '250': 8,
#   '284': 7,
#   '290': 3,
#   '294': 7,
#   '292': 7,
#   '293': 22,
#   '295': 1,
#   '296': 1,
#   '33': 24},
#  'id_Index': {'n': 905},
#  'Index_duration': {},
#  'LodgeSearch_duration': {30: 100,
#   5: 3573,
#   2: 697,
#   7: 22,
#   337: 5,
#   340: 1,
#   12: 2,
#   1: 455,
#   3: 272,
#   4: 114,
#   352: 1,
#   328: 3,
#   318: 2,
#   305: 2,
#   6: 34,
#   332: 1,
#   302: 6,
#   336: 3,
#   310: 1,
#   0: 2,
#   303: 14,
#   8: 10,
#   20: 6,
#   316: 5,
#   351: 3,
#   308: 2,
#   304: 5,
#   9: 21,
#   346: 2,
#   11: 6,
#   29: 23,
#   312: 2,
#   338: 1,
#   314: 1,
#   26: 1,
#   341: 1,
#   331: 1,
#   329: 1,
#   333: 2,
#   326: 1,
#   317: 1,
#   313: 1,
#   311: 7,
#   348: 2,
#   322: 1,
#   321: 5,
#   347: 2,
#   349: 2,
#   306: 1,
#   356: 1,
#   345: 1,
#   301: 3,
#   22: 1,
#   18: 1},
#  'ExperienceSearch_duration': {5: 724,
#   192: 1,
#   1: 151,
#   0: 1,
#   2: 34,
#   311: 1,
#   135: 1,
#   118: 1,
#   365: 23,
#   4: 26,
#   292: 2,
#   7: 44,
#   29: 2}}

# %%
listOfParams
# Out:
# [{'id': ['140'],
#   'ExperienceSearch[date_start]': ['2018-02-15'],
#   'ExperienceSearch[date_end]': ['2018-02-20']},
#  {'id': ['144'],
#   'ExperienceSearch[date_start]': ['2018-01-28'],
#   'ExperienceSearch[date_end]': ['2018-02-02']},
#  {'id': ['155'],
#   'ExperienceSearch[date_start]': ['2017-12-11'],
#   'ExperienceSearch[date_end]': ['2017-12-16']},
#  {'id': ['157']},
#  {'id': ['157'],
#   'ExperienceSearch[date_start]': ['2018-02-10'],
#   'ExperienceSearch[date_end]': ['2018-02-15']},
#  {'id': ['22']},
#  {'id': ['22'],
#   'ExperienceSearch[date_start]': ['2018-07-26'],
#   'ExperienceSearch[date_end]': ['2018-07-31']},
#  {'id': ['235'],
#   'ExperienceSearch[date_start]': ['2018-08-03'],
#   'ExperienceSearch[date_end]': ['2018-08-08']},
#  {'id': ['246'],
#   'ExperienceSearch[date_start]': ['2018-02-02'],
#   'ExperienceSearch[date_end]': ['2018-02-07']},
#  {'id': ['252'],
#   'ExperienceSearch[date_start]': ['2018-02-02'],
#   'ExperienceSearch[date_end]': ['2018-02-07']},
#  {'id': ['282'],
#   'ExperienceSearch[date_start]': ['2018-07-29'],
#   'ExperienceSearch[date_end]': ['2018-08-03']},
#  {'id': ['31'],
#   'ExperienceSearch[date_start]': ['2018-02-16'],
#   'ExperienceSearch[date_end]': ['2018-02-21']},
#  {'id': ['32'],
#   'ExperienceSearch[date_start]': ['2018-02-24'],
#   'ExperienceSearch[date_end]': ['2018-03-01']},
#  {'LodgeSearch[type_id]': [''], 'LodgeSearch[fulltext]': ['valedoninho']},
#  {'id': ['1'],
#   'LodgeSearch[date_start]': ['2018-07-20'],
#   'LodgeSearch[date_end]': ['2018-08-19'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0'],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['9999']},
#  {'id': ['11'],
#   'LodgeSearch[date_start]': ['2018-08-20'],
#   'LodgeSearch[date_end]': ['2018-08-25']},
#  {'id': ['14'],
#   'LodgeSearch[date_start]': ['2018-01-25'],
#   'LodgeSearch[date_end]': ['2018-01-30']},
#  {'id': ['17'],
#   'LodgeSearch[date_start]': ['2018-01-09'],
#   'LodgeSearch[date_end]': ['2018-01-14']},
#  {'id': ['19'],
#   'LodgeSearch[date_start]': ['2018-03-05'],
#   'LodgeSearch[date_end]': ['2018-03-10']},
#  {'id': ['19'],
#   'LodgeSearch[date_start]': ['2018-07-09'],
#   'LodgeSearch[date_end]': ['2018-07-14']},
#  {'id': ['2'],
#   'LodgeSearch[date_start]': ['2017-12-22'],
#   'LodgeSearch[date_end]': ['2017-12-27']},
#  {'id': ['22']},
#  {'id': ['29'],
#   'LodgeSearch[date_start]': ['2018-03-03'],
#   'LodgeSearch[date_end]': ['2018-03-08']},
#  {'id': ['35'],
#   'LodgeSearch[date_start]': ['2018-09-10'],
#   'LodgeSearch[date_end]': ['2018-09-12'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0'],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['9999'],
#   'LodgeSearch[village_id]': ['1'],
#   'LodgeSearch[relevance]': ['']},
#  {'id': ['40']},
#  {'id': ['40'],
#   'LodgeSearch[date_start]': ['2018-06-19'],
#   'LodgeSearch[date_end]': ['2018-06-24']},
#  {'id': ['45'],
#   'LodgeSearch[date_start]': ['2018-05-12'],
#   'LodgeSearch[date_end]': ['2018-05-19'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0'],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['79'],
#   'LodgeSearch[village_id]': [''],
#   'LodgeSearch[relevance]': ['cheap']},
#  {'id': ['47'],
#   'LodgeSearch[date_start]': ['2018-02-15'],
#   'LodgeSearch[date_end]': ['2018-02-20']},
#  {'id': ['51']},
#  {'id': ['51'],
#   'LodgeSearch[date_start]': ['2018-01-28'],
#   'LodgeSearch[date_end]': ['2018-12-31'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0'],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['9999']},
#  {'id': ['52']},
#  {'id': ['52'],
#   'LodgeSearch[date_start]': ['2018-02-11'],
#   'LodgeSearch[date_end]': ['2018-02-16']},
#  {'id': ['53'],
#   'LodgeSearch[date_start]': ['2018-01-10'],
#   'LodgeSearch[date_end]': ['2018-01-15']},
#  {'id': ['53'],
#   'LodgeSearch[date_start]': ['2018-01-25'],
#   'LodgeSearch[date_end]': ['2018-12-31'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0'],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['9999']},
#  {'id': ['53'],
#   'LodgeSearch[date_start]': ['2018-02-27'],
#   'LodgeSearch[date_end]': ['2018-03-04']},
#  {'id': ['55']},
#  {'id': ['57']},
#  {'id': ['57'],
#   'LodgeSearch[date_start]': ['2017-12-24'],
#   'LodgeSearch[date_end]': ['2017-12-29']},
#  {'id': ['6'],
#   'LodgeSearch[date_start]': ['2018-08-19'],
#   'LodgeSearch[date_end]': ['2018-08-24']},
#  {'id': ['62'],
#   'LodgeSearch[date_start]': ['2018-05-12'],
#   'LodgeSearch[date_end]': ['2018-05-19'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0'],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['79'],
#   'LodgeSearch[village_id]': [''],
#   'LodgeSearch[relevance]': ['cheap']},
#  {'id': ['67']},
#  {'id': ['78']},
#  {'id': ['79'],
#   'LodgeSearch[date_start]': ['2018-08-01'],
#   'LodgeSearch[date_end]': ['2018-08-13'],
#   'LodgeSearch[num_adults]': ['5'],
#   'LodgeSearch[num_children]': ['0'],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['9999']},
#  {'id': ['80'],
#   'LodgeSearch[date_start]': ['2018-06-22'],
#   'LodgeSearch[date_end]': ['2018-06-24'],
#   'LodgeSearch[num_adults]': ['6']},
#  {'id': ['87'],
#   'LodgeSearch[date_start]': ['2018-06-29'],
#   'LodgeSearch[date_end]': ['2018-07-04']},
#  {'id': ['87'],
#   'LodgeSearch[date_start]': ['2018-07-05'],
#   'LodgeSearch[date_end]': ['2018-07-10']},
#  {'id': ['87'],
#   'LodgeSearch[date_start]': ['2018-08-21'],
#   'LodgeSearch[date_end]': ['2018-08-26']},
#  {'id': ['87'],
#   'LodgeSearch[date_start]': ['2018-09-13'],
#   'LodgeSearch[date_end]': ['2018-09-18']},
#  {'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['1'],
#   'LodgeSearch[date_start]': ['2018-08-07'],
#   'LodgeSearch[date_end]': ['2018-08-08'],
#   'id': ['37']},
#  {'id': ['140']},
#  {'id': ['140'],
#   'ExperienceSearch[date_start]': ['2018-02-21'],
#   'ExperienceSearch[date_end]': ['2018-02-26'],
#   'ExperienceSearch[participants]': ['2']},
#  {'id': ['140'],
#   'ExperienceSearch[date_start]': ['2018-02-24'],
#   'ExperienceSearch[date_end]': ['2018-03-01'],
#   'ExperienceSearch[participants]': ['2']},
#  {'id': ['140'],
#   'ExperienceSearch[date_start]': ['2018-02-28'],
#   'ExperienceSearch[date_end]': ['2018-03-05']},
#  {'id': ['144']},
#  {'id': ['144'],
#   'ExperienceSearch[date_start]': ['2018-01-30'],
#   'ExperienceSearch[date_end]': ['2018-02-04']},
#  {'id': ['144'],
#   'ExperienceSearch[date_start]': ['2018-02-18'],
#   'ExperienceSearch[date_end]': ['2018-02-23']},
#  {'id': ['146']},
#  {'id': ['146'],
#   'ExperienceSearch[date_start]': ['2017-12-29'],
#   'ExperienceSearch[date_end]': ['2018-01-03']},
#  {'id': ['146'],
#   'ExperienceSearch[date_start]': ['2018-01-11'],
#   'ExperienceSearch[date_end]': ['2018-01-16']},
#  {'id': ['147']},
#  {'id': ['147'],
#   'ExperienceSearch[date_start]': ['2018-07-29'],
#   'ExperienceSearch[date_end]': ['2018-08-03']},
#  {'id': ['149'],
#   'ExperienceSearch[date_start]': ['2018-02-27'],
#   'ExperienceSearch[date_end]': ['2018-03-04']},
#  {'id': ['150']},
#  {'id': ['150']},
#  {'id': ['150']},
#  {'id': ['150'],
#   'ExperienceSearch[date_start]': ['2018-02-12'],
#   'ExperienceSearch[date_end]': ['2018-02-17']},
#  {'id': ['150'],
#   'ExperienceSearch[date_start]': ['2018-02-25'],
#   'ExperienceSearch[date_end]': ['2018-03-02']},
#  {'id': ['151']},
#  {'id': ['154']},
#  {'id': ['154'],
#   'ExperienceSearch[date_start]': ['2018-02-22'],
#   'ExperienceSearch[date_end]': ['2018-02-27']},
#  {'id': ['154'],
#   'ExperienceSearch[date_start]': ['2018-07-29'],
#   'ExperienceSearch[date_end]': ['2018-08-03']},
#  {'id': ['155']},
#  {'id': ['156']},
#  {'id': ['157']},
#  {'id': ['157'],
#   'ExperienceSearch[date_start]': ['2018-07-02'],
#   'ExperienceSearch[date_end]': ['2018-07-07']},
#  {'id': ['157'],
#   'ExperienceSearch[date_start]': ['2018-07-20'],
#   'ExperienceSearch[date_end]': ['2018-07-25']},
#  {'id': ['157'],
#   'ExperienceSearch[date_start]': ['2018-07-22'],
#   'ExperienceSearch[date_end]': ['2018-07-27']},
#  {'id': ['157'],
#   'ExperienceSearch[date_start]': ['2018-07-23'],
#   'ExperienceSearch[date_end]': ['2018-07-28']},
#  {'id': ['206'],
#   'ExperienceSearch[date_start]': ['2017-12-23'],
#   'ExperienceSearch[date_end]': ['2017-12-28']},
#  {'id': ['214'],
#   'ExperienceSearch[date_start]': ['2018-02-20'],
#   'ExperienceSearch[date_end]': ['2018-02-25']},
#  {'id': ['215'],
#   'ExperienceSearch[date_start]': ['2017-12-22'],
#   'ExperienceSearch[date_end]': ['2017-12-27']},
#  {'id': ['241'],
#   'ExperienceSearch[date_start]': ['2018-05-11'],
#   'ExperienceSearch[date_end]': ['2018-05-16']},
#  {'id': ['241'],
#   'ExperienceSearch[date_start]': ['2018-07-17'],
#   'ExperienceSearch[date_end]': ['2018-07-22']},
#  {'id': ['246'],
#   'ExperienceSearch[date_start]': ['2018-03-04'],
#   'ExperienceSearch[date_end]': ['2018-03-09']},
#  {'id': ['247'],
#   'ExperienceSearch[date_start]': ['2018-02-01'],
#   'ExperienceSearch[date_end]': ['2018-02-06']},
#  {'id': ['247'],
#   'ExperienceSearch[date_start]': ['2018-06-30'],
#   'ExperienceSearch[date_end]': ['2018-07-05']},
#  {'id': ['251'],
#   'ExperienceSearch[date_start]': ['2018-02-06'],
#   'ExperienceSearch[date_end]': ['2018-02-11']},
#  {'id': ['251'],
#   'ExperienceSearch[date_start]': ['2018-02-08'],
#   'ExperienceSearch[date_end]': ['2018-02-13']},
#  {'id': ['252'],
#   'ExperienceSearch[date_start]': ['2018-09-14'],
#   'ExperienceSearch[date_end]': ['2018-09-19'],
#   'ExperienceSearch[participants]': ['2']},
#  {'id': ['254'],
#   'ExperienceSearch[date_start]': ['2018-02-03'],
#   'ExperienceSearch[date_end]': ['2018-02-08']},
#  {'id': ['31'],
#   'ExperienceSearch[date_start]': ['2018-01-27'],
#   'ExperienceSearch[date_end]': ['2018-02-01']},
#  {'id': ['4']},
#  {'LodgeSearch[type_id]': [''],
#   'LodgeSearch[fulltext]': [''],
#   'LodgeSearch[village_id]': ['14'],
#   'LodgeSearch[relevance]': [''],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['9999'],
#   'LodgeSearch[date_start]': ['2018-3-3'],
#   'LodgeSearch[date_end]': ['2018-3-4'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['1']},
#  {'LodgeSearch[type_id]': [''],
#   'LodgeSearch[fulltext]': [''],
#   'LodgeSearch[village_id]': ['36'],
#   'LodgeSearch[relevance]': [''],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['9999'],
#   'LodgeSearch[date_start]': ['2018-09-30'],
#   'LodgeSearch[date_end]': ['2018-10-05'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0']},
#  {'LodgeSearch[type_id]': [''], 'LodgeSearch[fulltext]': ['cerdeiravillage']},
#  {'LodgeSearch[type_id]': [''], 'LodgeSearch[fulltext]': ['oliveiras']},
#  {'LodgeSearch[type_id]': [''], 'LodgeSearch[fulltext]': ['valedoninho']},
#  {'id': ['1']},
#  {'id': ['1'],
#   'LodgeSearch[date_start]': ['2018-04-06'],
#   'LodgeSearch[date_end]': ['2018-04-09'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0'],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['9999']},
#  {'id': ['1'],
#   'lodgesearch[date_start]': ['2018-07-17'],
#   'lodgesearch[date_end]': ['2018-07-22']},
#  {'id': ['1'],
#   'LodgeSearch[date_start]': ['2018-08-11'],
#   'LodgeSearch[date_end]': ['2018-08-12'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['2'],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['9999']},
#  {'id': ['10'],
#   'LodgeSearch[date_start]': ['2018-05-29'],
#   'LodgeSearch[date_end]': ['2018-05-31'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['1'],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['9999']},
#  {'id': ['10'],
#   'LodgeSearch[date_start]': ['2018-09-21'],
#   'LodgeSearch[date_end]': ['2018-09-25'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0'],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['9999'],
#   'LodgeSearch[village_id]': [''],
#   'LodgeSearch[relevance]': ['']},
#  {'id': ['11'],
#   'LodgeSearch[date_start]': ['2018-06-06'],
#   'LodgeSearch[date_end]': ['2018-06-11']},
#  {'id': ['11'],
#   'LodgeSearch[date_start]': ['2018-06-27'],
#   'LodgeSearch[date_end]': ['2018-07-02']},
#  {'id': ['12'],
#   'lodgesearch[date_start]': ['2018-07-17'],
#   'lodgesearch[date_end]': ['2018-07-22']},
#  {'id': ['13'],
#   'LodgeSearch[date_start]': ['2018-07-25'],
#   'LodgeSearch[date_end]': ['2018-07-30']},
#  {'id': ['13'],
#   'LodgeSearch[date_start]': ['2018-07-25'],
#   'LodgeSearch[date_end]': ['2018-07-30']},
#  {'id': ['13'],
#   'LodgeSearch[date_start]': ['2018-07-25'],
#   'LodgeSearch[date_end]': ['2018-07-30']},
#  {'id': ['13'],
#   'LodgeSearch[date_start]': ['2018-07-25'],
#   'LodgeSearch[date_end]': ['2018-07-30']},
#  {'id': ['13'],
#   'LodgeSearch[date_start]': ['2018-07-25'],
#   'LodgeSearch[date_end]': ['2018-07-30']},
#  {'id': ['13'],
#   'LodgeSearch[date_start]': ['2018-07-25'],
#   'LodgeSearch[date_end]': ['2018-07-30']},
#  {'id': ['13'],
#   'lodgesearch[date_start]': ['2018-08-02'],
#   'lodgesearch[date_end]': ['2018-08-07']},
#  {'id': ['14'],
#   'LodgeSearch[date_start]': ['2018-01-25'],
#   'LodgeSearch[date_end]': ['2018-01-30']},
#  {'id': ['14'],
#   'lodgesearch[date_start]': ['2018-02-24'],
#   'lodgesearch[date_end]': ['2018-03-01']},
#  {'id': ['14'],
#   'LodgeSearch[date_start]': ['2018-09-01'],
#   'LodgeSearch[date_end]': ['2018-09-06']},
#  {'id': ['16'],
#   'lodgesearch[date_start]': ['2018-07-17'],
#   'lodgesearch[date_end]': ['2018-07-22']},
#  {'id': ['16'],
#   'lodgesearch[date_start]': ['2018-08-17'],
#   'lodgesearch[date_end]': ['2018-08-22']},
#  {'id': ['17']},
#  {'id': ['17'],
#   'LodgeSearch[date_start]': ['2017-12-22'],
#   'LodgeSearch[date_end]': ['2017-12-27']},
#  {'id': ['17'],
#   'lodgesearch[date_start]': ['2018-03-16'],
#   'lodgesearch[date_end]': ['2018-03-21']},
#  {'id': ['18'],
#   'LodgeSearch[date_start]': ['2018-02-27'],
#   'LodgeSearch[date_end]': ['2018-03-04']},
#  {'id': ['19']},
#  {'id': ['19'],
#   'lodgesearch[date_start]': ['2018-02-24'],
#   'lodgesearch[date_end]': ['2018-03-01']},
#  {'id': ['19'],
#   'LodgeSearch[date_start]': ['2018-02-27'],
#   'LodgeSearch[date_end]': ['2018-03-04']},
#  {'id': ['19'],
#   'lodgesearch[date_start]': ['2018-07-17'],
#   'lodgesearch[date_end]': ['2018-07-22']},
#  {'id': ['2']},
#  {'id': ['2']},
#  {'id': ['2'],
#   'LodgeSearch[date_start]': ['2018-01-05'],
#   'LodgeSearch[date_end]': ['2018-01-10']},
#  {'id': ['2'],
#   'LodgeSearch[date_start]': ['2018-01-25'],
#   'LodgeSearch[date_end]': ['2018-01-30'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0'],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['9999'],
#   'LodgeSearch[village_id]': [''],
#   'LodgeSearch[relevance]': ['']},
#  {'id': ['2'],
#   'LodgeSearch[date_start]': ['2018-03-01'],
#   'LodgeSearch[date_end]': ['2018-03-06']},
#  {'id': ['2'],
#   'LodgeSearch[date_start]': ['2018-10-22'],
#   'LodgeSearch[date_end]': ['2018-10-24'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['1'],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['9999'],
#   'LodgeSearch[village_id]': [''],
#   'LodgeSearch[relevance]': ['']},
#  {'id': ['20'],
#   'LodgeSearch[date_start]': ['2018-03-05'],
#   'LodgeSearch[date_end]': ['2018-03-10']},
#  {'id': ['20'],
#   'lodgesearch[date_start]': ['2018-07-17'],
#   'lodgesearch[date_end]': ['2018-07-22']},
#  {'id': ['22']},
#  {'id': ['22']},
#  {'id': ['22'],
#   'LodgeSearch[date_start]': ['2018-02-27'],
#   'LodgeSearch[date_end]': ['2018-03-04']},
#  {'id': ['23']},
#  {'id': ['23'],
#   'lodgesearch[date_start]': ['2018-02-24'],
#   'lodgesearch[date_end]': ['2018-03-01']},
#  {'id': ['24']},
#  {'id': ['24']},
#  {'id': ['24'],
#   'LodgeSearch[date_start]': ['2018-08-26'],
#   'LodgeSearch[date_end]': ['2018-08-31']},
#  {'id': ['25']},
#  {'id': ['25']},
#  {'id': ['25'],
#   'LodgeSearch[date_start]': ['2018-02-12'],
#   'LodgeSearch[date_end]': ['2018-02-17']},
#  {'id': ['26']},
#  {'id': ['27'],
#   'LodgeSearch[date_start]': ['2018-04-24'],
#   'LodgeSearch[date_end]': ['2018-04-29'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['2'],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['9999'],
#   'LodgeSearch[village_id]': ['31'],
#   'LodgeSearch[relevance]': ['']},
#  {'id': ['27'],
#   'lodgesearch[date_start]': ['2018-08-02'],
#   'lodgesearch[date_end]': ['2018-08-07']},
#  {'id': ['28'],
#   'LodgeSearch[date_start]': ['2017-12-22'],
#   'LodgeSearch[date_end]': ['2017-12-27']},
#  {'id': ['28'],
#   'LodgeSearch[date_start]': ['2018-02-08'],
#   'LodgeSearch[date_end]': ['2018-02-13']},
#  {'id': ['29'],
#   'LodgeSearch[date_start]': ['2018-03-03'],
#   'LodgeSearch[date_end]': ['2018-03-08']},
#  {'id': ['31'],
#   'LodgeSearch[date_start]': ['2018-08-16'],
#   'LodgeSearch[date_end]': ['2018-08-21']},
#  {'id': ['31'],
#   'lodgesearch[date_start]': ['2018-08-17'],
#   'lodgesearch[date_end]': ['2018-08-22']},
#  {'id': ['32'],
#   'lodgesearch[date_start]': ['2018-07-17'],
#   'lodgesearch[date_end]': ['2018-07-22']},
#  {'id': ['34'],
#   'LodgeSearch[date_start]': ['2018-01-13'],
#   'LodgeSearch[date_end]': ['2018-12-31'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0'],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['9999']},
#  {'id': ['34'],
#   'LodgeSearch[date_start]': ['2018-10-05'],
#   'LodgeSearch[date_end]': ['2018-10-07'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['2'],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['9999'],
#   'LodgeSearch[village_id]': ['12'],
#   'LodgeSearch[relevance]': ['cheap']},
#  {'id': ['35']},
#  {'id': ['35']},
#  {'id': ['35'],
#   'LodgeSearch[date_start]': ['2018-07-02'],
#   'LodgeSearch[date_end]': ['2018-07-07']},
#  {'id': ['35'],
#   'LodgeSearch[date_start]': ['2018-07-02'],
#   'LodgeSearch[date_end]': ['2018-07-07']},
#  {'id': ['36']},
#  {'id': ['37']},
#  {'id': ['37'],
#   'LodgeSearch[date_start]': ['2018-02-03'],
#   'LodgeSearch[date_end]': ['2018-02-08']},
#  {'id': ['37'],
#   'lodgesearch[date_start]': ['2018-02-24'],
#   'lodgesearch[date_end]': ['2018-03-01']},
#  {'id': ['37'],
#   'lodgesearch[date_start]': ['2018-08-17'],
#   'lodgesearch[date_end]': ['2018-08-22']},
#  {'id': ['37'],
#   'LodgeSearch[date_start]': ['2018-09-22'],
#   'LodgeSearch[date_end]': ['2018-09-23'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0'],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['85'],
#   'LodgeSearch[village_id]': [''],
#   'LodgeSearch[relevance]': ['']},
#  {'id': ['37'],
#   'LodgeSearch[date_start]': ['2018-09-27'],
#   'LodgeSearch[date_end]': ['2018-10-02']},
#  {'id': ['38']},
#  {'id': ['38'],
#   'LodgeSearch[date_start]': ['2018-02-03'],
#   'LodgeSearch[date_end]': ['2018-02-08']},
#  {'id': ['39'],
#   'LodgeSearch[date_start]': ['2018-03-01'],
#   'LodgeSearch[date_end]': ['2018-03-06']},
#  {'id': ['39'],
#   'lodgesearch[date_start]': ['2018-08-17'],
#   'lodgesearch[date_end]': ['2018-08-22']},
#  {'id': ['39'],
#   'LodgeSearch[date_start]': ['2018-09-24'],
#   'LodgeSearch[date_end]': ['2018-09-29']},
#  {'id': ['4']},
#  {'id': ['4'],
#   'LodgeSearch[date_start]': ['2018-09-22'],
#   'LodgeSearch[date_end]': ['2018-09-23'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0'],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['85'],
#   'LodgeSearch[village_id]': [''],
#   'LodgeSearch[relevance]': ['']},
#  {'id': ['40']},
#  {'id': ['40']},
#  {'id': ['40'],
#   'LodgeSearch[date_start]': ['2018-01-15'],
#   'LodgeSearch[date_end]': ['2018-01-17'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0'],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['9999']},
#  {'id': ['40'],
#   'LodgeSearch[date_start]': ['2018-01-26'],
#   'LodgeSearch[date_end]': ['2018-01-31']},
#  {'id': ['40'],
#   'LodgeSearch[date_start]': ['2018-01-28'],
#   'LodgeSearch[date_end]': ['2018-02-02']},
#  {'id': ['40'],
#   'LodgeSearch[date_start]': ['2018-01-28'],
#   'LodgeSearch[date_end]': ['2018-02-02']},
#  {'id': ['40'],
#   'LodgeSearch[date_start]': ['2018-01-28'],
#   'LodgeSearch[date_end]': ['2018-02-02']},
#  {'id': ['40'],
#   'LodgeSearch[date_start]': ['2018-01-30'],
#   'LodgeSearch[date_end]': ['2018-02-04']},
#  {'id': ['40'],
#   'LodgeSearch[date_start]': ['2018-01-30'],
#   'LodgeSearch[date_end]': ['2018-02-04']},
#  {'id': ['40'],
#   'LodgeSearch[date_start]': ['2018-06-12'],
#   'LodgeSearch[date_end]': ['2018-06-17']},
#  {'id': ['43']},
#  {'id': ['43'],
#   'lodgesearch[date_start]': ['2018-08-17'],
#   'lodgesearch[date_end]': ['2018-08-22']},
#  {'id': ['44'],
#   'LodgeSearch[date_start]': ['2018-03-22'],
#   'LodgeSearch[date_end]': ['2018-04-21'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0'],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['9999']},
#  {'id': ['45'],
#   'LodgeSearch[date_start]': ['2018-01-15'],
#   'LodgeSearch[date_end]': ['2018-01-17'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0'],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['9999']},
#  {'id': ['45'],
#   'LodgeSearch[date_start]': ['2018-02-01'],
#   'LodgeSearch[date_end]': ['2018-02-06']},
#  {'id': ['45'],
#   'LodgeSearch[date_start]': ['2018-05-13'],
#   'LodgeSearch[date_end]': ['2018-05-16'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0'],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['60'],
#   'LodgeSearch[village_id]': [''],
#   'LodgeSearch[relevance]': ['']},
#  {'id': ['47']},
#  {'id': ['47'],
#   'LodgeSearch[date_start]': ['2018-03-09'],
#   'LodgeSearch[date_end]': ['2018-03-14']},
#  {'id': ['48'],
#   'LodgeSearch[date_start]': ['2018-10-05'],
#   'LodgeSearch[date_end]': ['2018-10-07'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0'],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['9999'],
#   'LodgeSearch[village_id]': [''],
#   'LodgeSearch[relevance]': ['cheap']},
#  {'id': ['49']},
#  {'id': ['49'],
#   'LodgeSearch[date_start]': ['2018-02-12'],
#   'LodgeSearch[date_end]': ['2018-02-17']},
#  {'id': ['49'],
#   'lodgesearch[date_start]': ['2018-02-24'],
#   'lodgesearch[date_end]': ['2018-03-01']},
#  {'id': ['5']},
#  {'id': ['5'],
#   'LodgeSearch[date_start]': ['2017-12-15'],
#   'LodgeSearch[date_end]': ['2017-12-20']},
#  {'id': ['5'],
#   'LodgeSearch[date_start]': ['2018-03-11'],
#   'LodgeSearch[date_end]': ['2018-03-16']},
#  {'id': ['5'],
#   'LodgeSearch[date_start]': ['2018-08-07'],
#   'LodgeSearch[date_end]': ['2018-08-09'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0'],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['86'],
#   'LodgeSearch[village_id]': [''],
#   'LodgeSearch[relevance]': ['best']},
#  {'id': ['50']},
#  {'id': ['51']},
#  {'id': ['51']},
#  {'id': ['51'],
#   'LodgeSearch[date_start]': ['2018-01-30'],
#   'LodgeSearch[date_end]': ['2018-02-04']},
#  {'id': ['52']},
#  {'id': ['52'],
#   'LodgeSearch[date_start]': ['2018-05-11'],
#   'LodgeSearch[date_end]': ['2018-05-13'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0'],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['80'],
#   'LodgeSearch[village_id]': [''],
#   'LodgeSearch[relevance]': ['cheap']},
#  {'id': ['52'],
#   'LodgeSearch[date_start]': ['2018-05-11'],
#   'LodgeSearch[date_end]': ['2018-05-13'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0'],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['80'],
#   'LodgeSearch[village_id]': [''],
#   'LodgeSearch[relevance]': ['cheap']},
#  {'id': ['53']},
#  {'id': ['53'],
#   'lodgesearch[date_start]': ['2018-02-24'],
#   'lodgesearch[date_end]': ['2018-03-01']},
#  {'id': ['55']},
#  {'id': ['55']},
#  {'id': ['55'],
#   'LodgeSearch[date_start]': ['2018-02-02'],
#   'LodgeSearch[date_end]': ['2018-02-07'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0'],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['9999']},
#  {'id': ['55'],
#   'LodgeSearch[date_start]': ['2018-02-02'],
#   'LodgeSearch[date_end]': ['2018-02-07'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0'],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['9999']},
#  {'id': ['55'],
#   'LodgeSearch[date_start]': ['2018-02-02'],
#   'LodgeSearch[date_end]': ['2018-02-07'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0'],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['9999']},
#  {'id': ['55'],
#   'LodgeSearch[date_start]': ['2018-02-02'],
#   'LodgeSearch[date_end]': ['2018-02-07'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0'],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['9999']},
#  {'id': ['57']},
#  {'id': ['57']},
#  {'id': ['57']},
#  {'id': ['57'],
#   'LodgeSearch[date_start]': ['2018-01-09'],
#   'LodgeSearch[date_end]': ['2018-01-14']},
#  {'id': ['57'],
#   'LodgeSearch[date_start]': ['2018-03-13'],
#   'LodgeSearch[date_end]': ['2018-03-16'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0'],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['70'],
#   'LodgeSearch[village_id]': [''],
#   'LodgeSearch[relevance]': ['']},
#  {'id': ['57'],
#   'LodgeSearch[date_start]': ['2018-06-16'],
#   'LodgeSearch[date_end]': ['2018-06-17'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0'],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['9999']},
#  {'id': ['57'],
#   'LodgeSearch[date_start]': ['2018-10-22'],
#   'LodgeSearch[date_end]': ['2018-10-24'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['1'],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['9999'],
#   'LodgeSearch[village_id]': [''],
#   'LodgeSearch[relevance]': ['']},
#  {'id': ['58']},
#  {'id': ['59'],
#   'LodgeSearch[date_start]': ['2018-07-21'],
#   'LodgeSearch[date_end]': ['2018-07-28'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['2'],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['9999']},
#  {'id': ['59'],
#   'LodgeSearch[date_start]': ['2018-10-22'],
#   'LodgeSearch[date_end]': ['2018-10-24'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['1'],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['9999'],
#   'LodgeSearch[village_id]': [''],
#   'LodgeSearch[relevance]': ['']},
#  {'id': ['60']},
#  {'id': ['60'],
#   'LodgeSearch[date_start]': ['2018-01-16'],
#   'LodgeSearch[date_end]': ['2018-01-21']},
#  {'id': ['60'],
#   'lodgesearch[date_start]': ['2018-02-17'],
#   'lodgesearch[date_end]': ['2018-02-22']},
#  {'id': ['61']},
#  {'id': ['61'],
#   'LodgeSearch[date_start]': ['2017-12-09'],
#   'LodgeSearch[date_end]': ['2017-12-14'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0'],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['2500']},
#  {'id': ['61'],
#   'LodgeSearch[date_start]': ['2017-12-09'],
#   'LodgeSearch[date_end]': ['2017-12-14'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0'],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['2500']},
#  {'id': ['62']},
#  {'id': ['62'],
#   'LodgeSearch[date_start]': ['2017-12-13'],
#   'LodgeSearch[date_end]': ['2017-12-18']},
#  {'id': ['63']},
#  {'id': ['63'],
#   'LodgeSearch[date_start]': ['2018-02-26'],
#   'LodgeSearch[date_end]': ['2018-03-03']},
#  {'id': ['63'],
#   'LodgeSearch[date_start]': ['2018-03-05'],
#   'LodgeSearch[date_end]': ['2018-03-07'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0'],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['9999']},
#  {'id': ['64'],
#   'LodgeSearch[date_start]': ['2018-02-06'],
#   'LodgeSearch[date_end]': ['2018-12-31'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0'],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['9999']},
#  {'id': ['64'],
#   'LodgeSearch[date_start]': ['2018-02-16'],
#   'LodgeSearch[date_end]': ['2018-12-31'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0'],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['9999']},
#  {'id': ['64'],
#   'LodgeSearch[date_start]': ['2018-06-27'],
#   'LodgeSearch[date_end]': ['2018-07-27'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0'],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['9999']},
#  {'id': ['66']},
#  {'id': ['66'],
#   'LodgeSearch[date_start]': ['2018-04-28'],
#   'LodgeSearch[date_end]': ['2018-04-29'],
#   'LodgeSearch[num_adults]': ['7']},
#  {'id': ['66'],
#   'LodgeSearch[date_start]': ['2018-04-28'],
#   'LodgeSearch[date_end]': ['2018-04-29'],
#   'LodgeSearch[num_adults]': ['7'],
#   'LodgeSearch[num_children]': ['0'],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['9999']},
#  {'id': ['66'],
#   'LodgeSearch[date_start]': ['2018-04-28'],
#   'LodgeSearch[date_end]': ['2018-04-29'],
#   'LodgeSearch[num_adults]': ['7'],
#   'LodgeSearch[num_children]': ['0'],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['9999']},
#  {'id': ['67']},
#  {'id': ['67'],
#   'LodgeSearch[date_start]': ['2018-01-27'],
#   'LodgeSearch[date_end]': ['2018-02-01'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0'],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['9999']},
#  {'id': ['67'],
#   'LodgeSearch[date_start]': ['2018-02-26'],
#   'LodgeSearch[date_end]': ['2018-03-03']},
#  {'id': ['67'],
#   'lodgesearch[date_start]': ['2018-07-17'],
#   'lodgesearch[date_end]': ['2018-07-22']},
#  {'id': ['67'],
#   'lodgesearch[date_start]': ['2018-08-17'],
#   'lodgesearch[date_end]': ['2018-08-22']},
#  {'id': ['68']},
#  {'id': ['68'],
#   'LodgeSearch[date_start]': ['2017-12-09'],
#   'LodgeSearch[date_end]': ['2017-12-14']},
#  {'id': ['68'],
#   'LodgeSearch[date_start]': ['2018-01-29'],
#   'LodgeSearch[date_end]': ['2018-02-03'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0'],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['9999']},
#  {'id': ['71']},
#  {'id': ['72']},
#  {'id': ['73'],
#   'LodgeSearch[date_start]': ['2018-01-28'],
#   'LodgeSearch[date_end]': ['2018-02-02']},
#  {'id': ['74']},
#  {'id': ['75']},
#  {'id': ['79']},
#  {'id': ['79']},
#  {'id': ['79'],
#   'LodgeSearch[date_start]': ['2018-02-22'],
#   'LodgeSearch[date_end]': ['2018-02-27']},
#  {'id': ['80']},
#  {'id': ['80'],
#   'LodgeSearch[date_start]': ['2017-12-31'],
#   'LodgeSearch[date_end]': ['2018-01-02'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0'],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['2500'],
#   'LodgeSearch[village_id]': [''],
#   'LodgeSearch[relevance]': ['expensive']},
#  {'id': ['80'],
#   'lodgesearch[date_start]': ['2018-08-17'],
#   'lodgesearch[date_end]': ['2018-08-22']},
#  {'id': ['81']},
#  {'id': ['82']},
#  {'id': ['82']},
#  {'id': ['82']},
#  {'id': ['82'],
#   'LodgeSearch[date_start]': ['2018-06-21'],
#   'LodgeSearch[date_end]': ['2018-06-26'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0'],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['9999']},
#  {'id': ['82'],
#   'LodgeSearch[date_start]': ['2018-06-21'],
#   'LodgeSearch[date_end]': ['2018-06-26'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0'],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['9999']},
#  {'id': ['82'],
#   'LodgeSearch[date_start]': ['2018-07-27'],
#   'LodgeSearch[date_end]': ['2018-08-01'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0'],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['9999']},
#  {'id': ['89']},
#  {'id': ['89'],
#   'lodgesearch[date_start]': ['2018-02-24'],
#   'lodgesearch[date_end]': ['2018-03-01']},
#  {'id': ['89'],
#   'lodgesearch[date_start]': ['2018-07-17'],
#   'lodgesearch[date_end]': ['2018-07-22']},
#  {'id': ['93']},
#  {'id': ['95'],
#   'lodgesearch[date_start]': ['2018-02-24'],
#   'lodgesearch[date_end]': ['2018-03-01']},
#  {'id': ['95'],
#   'LodgeSearch[date_start]': ['2018-03-03'],
#   'LodgeSearch[date_end]': ['2018-03-08']},
#  {'id': ['96'],
#   'LodgeSearch[date_start]': ['2018-02-28'],
#   'LodgeSearch[date_end]': ['2018-03-05']},
#  {'id': ['96'],
#   'LodgeSearch[date_start]': ['2018-03-01'],
#   'LodgeSearch[date_end]': ['2018-12-31'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0'],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['9999']},
#  {'id': ['98']},
#  {'id': ['99'],
#   'lodgesearch[date_start]': ['2018-07-17'],
#   'lodgesearch[date_end]': ['2018-07-22']},
#  {'id': ['99'],
#   'LodgeSearch[date_start]': ['2018-08-08'],
#   'LodgeSearch[date_end]': ['2018-08-15'],
#   'LodgeSearch[num_adults]': ['12']},
#  {'LodgeSearch[num_adults]': ['1'],
#   'LodgeSearch[num_children]': ['0'],
#   'LodgeSearch[date_start]': ['2018-6-30'],
#   'LodgeSearch[date_end]': ['2018-7-3'],
#   'id': ['2']},
#  {'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0'],
#   'LodgeSearch[date_start]': ['2018-07-24'],
#   'LodgeSearch[date_end]': ['2018-07-29'],
#   'id': ['17']},
#  {'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0'],
#   'LodgeSearch[date_start]': ['2018-12-31'],
#   'LodgeSearch[date_end]': ['2019-1-2'],
#   'id': ['82']},
#  {'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0'],
#   'LodgeSearch[date_start]': ['2018-3-30'],
#   'LodgeSearch[date_end]': ['2018-4-2'],
#   'id': ['57']},
#  {'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0'],
#   'LodgeSearch[date_start]': ['2018-5-21'],
#   'LodgeSearch[date_end]': ['2018-5-23'],
#   'id': ['51']},
#  {'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0'],
#   'LodgeSearch[date_start]': ['2018-5-21'],
#   'LodgeSearch[date_end]': ['2018-5-23'],
#   'id': ['51']},
#  {'LodgeSearch[num_adults]': ['3'],
#   'LodgeSearch[num_children]': ['2'],
#   'LodgeSearch[date_start]': ['2018-6-1'],
#   'LodgeSearch[date_end]': ['2018-6-3'],
#   'id': ['95']},
#  {'LodgeSearch[num_adults]': ['5'],
#   'LodgeSearch[num_children]': ['0'],
#   'LodgeSearch[date_start]': ['2018-08-07'],
#   'LodgeSearch[date_end]': ['2018-08-12'],
#   'id': ['40']},
#  {'LodgeSearch[num_adults]': ['5'],
#   'LodgeSearch[num_children]': ['0'],
#   'LodgeSearch[date_start]': ['2018-08-07'],
#   'LodgeSearch[date_end]': ['2018-08-12'],
#   'id': ['40']},
#  {'LodgeSearch[num_adults]': ['5'],
#   'LodgeSearch[num_children]': ['3'],
#   'LodgeSearch[date_start]': ['2018-06-10'],
#   'LodgeSearch[date_end]': ['2018-06-15'],
#   'id': ['11']},
#  {'LodgeSearch[num_adults]': ['6'],
#   'LodgeSearch[num_children]': ['0'],
#   'LodgeSearch[date_start]': ['2018-05-25'],
#   'LodgeSearch[date_end]': ['2018-05-27'],
#   'id': ['2']},
#  {'LodgeSearch[num_adults]': ['6'],
#   'LodgeSearch[num_children]': ['0'],
#   'LodgeSearch[date_start]': ['2018-05-25'],
#   'LodgeSearch[date_end]': ['2018-05-27'],
#   'id': ['2']},
#  {'LodgeSearch[num_children]': ['0'],
#   'LodgeSearch[date_start]': ['2018-4-6'],
#   'LodgeSearch[date_end]': ['2018-4-13'],
#   'id': ['19']},
#  {'id': ['6']},
#  {'id': ['140']},
#  {'id': ['144'],
#   'ExperienceSearch[date_start]': ['2018-02-15'],
#   'ExperienceSearch[date_end]': ['2018-02-20']},
#  {'id': ['144'],
#   'ExperienceSearch[date_start]': ['2018-02-26'],
#   'ExperienceSearch[date_end]': ['2018-03-03']},
#  {'id': ['144'],
#   'ExperienceSearch[date_start]': ['2018-02-26'],
#   'ExperienceSearch[date_end]': ['2018-03-03']},
#  {'id': ['144'],
#   'ExperienceSearch[date_start]': ['2018-03-04'],
#   'ExperienceSearch[date_end]': ['2018-03-09']},
#  {'id': ['144'],
#   'ExperienceSearch[date_start]': ['2018-06-06'],
#   'ExperienceSearch[date_end]': ['2018-06-11']},
#  {'id': ['146'],
#   'ExperienceSearch[date_start]': ['2018-03-03'],
#   'ExperienceSearch[date_end]': ['2018-03-08']},
#  {'id': ['147']},
#  {'id': ['149']},
#  {'id': ['149'],
#   'ExperienceSearch[date_start]': ['2018-01-26'],
#   'ExperienceSearch[date_end]': ['2018-01-31'],
#   'ExperienceSearch[participants]': ['2']},
#  {'id': ['149'],
#   'ExperienceSearch[date_start]': ['2018-01-31'],
#   'ExperienceSearch[date_end]': ['2018-02-05']},
#  {'id': ['149'],
#   'ExperienceSearch[date_start]': ['2018-03-01'],
#   'ExperienceSearch[date_end]': ['2018-03-06']},
#  {'id': ['149'],
#   'ExperienceSearch[date_start]': ['2018-03-05'],
#   'ExperienceSearch[date_end]': ['2018-03-10']},
#  {'id': ['150'],
#   'ExperienceSearch[date_start]': ['2018-03-04'],
#   'ExperienceSearch[date_end]': ['2018-03-09']},
#  {'id': ['151']},
#  {'id': ['151'],
#   'ExperienceSearch[date_start]': ['2018-03-01'],
#   'ExperienceSearch[date_end]': ['2018-03-06']},
#  {'id': ['151'],
#   'ExperienceSearch[date_start]': ['2018-03-05'],
#   'ExperienceSearch[date_end]': ['2018-03-10']},
#  {'id': ['155'],
#   'ExperienceSearch[date_start]': ['2018-02-02'],
#   'ExperienceSearch[date_end]': ['2018-02-07']},
#  {'id': ['155'],
#   'ExperienceSearch[date_start]': ['2018-03-03'],
#   'ExperienceSearch[date_end]': ['2018-03-08']},
#  {'id': ['157'],
#   'ExperienceSearch[date_start]': ['2018-01-12'],
#   'ExperienceSearch[date_end]': ['2018-01-17']},
#  {'id': ['157'],
#   'ExperienceSearch[date_start]': ['2018-02-21'],
#   'ExperienceSearch[date_end]': ['2018-02-26']},
#  {'id': ['206'],
#   'ExperienceSearch[date_start]': ['2017-12-29'],
#   'ExperienceSearch[date_end]': ['2018-01-03']},
#  {'id': ['215'],
#   'ExperienceSearch[date_start]': ['2018-02-03'],
#   'ExperienceSearch[date_end]': ['2018-02-08']},
#  {'id': ['235'],
#   'ExperienceSearch[date_start]': ['2018-02-14'],
#   'ExperienceSearch[date_end]': ['2018-02-19']},
#  {'id': ['235'],
#   'ExperienceSearch[date_start]': ['2018-02-14'],
#   'ExperienceSearch[date_end]': ['2018-02-19']},
#  {'id': ['235'],
#   'ExperienceSearch[date_start]': ['2018-03-03'],
#   'ExperienceSearch[date_end]': ['2018-03-08']},
#  {'id': ['246']},
#  {'id': ['247'],
#   'ExperienceSearch[date_start]': ['2018-03-04'],
#   'ExperienceSearch[date_end]': ['2018-03-09']},
#  {'id': ['251'],
#   'ExperienceSearch[date_start]': ['2018-02-14'],
#   'ExperienceSearch[date_end]': ['2018-02-19']},
#  {'id': ['251'],
#   'ExperienceSearch[date_start]': ['2018-03-05'],
#   'ExperienceSearch[date_end]': ['2018-03-10']},
#  {'id': ['286'],
#   'ExperienceSearch[date_start]': ['2018-06-13'],
#   'ExperienceSearch[date_end]': ['2018-06-18']},
#  {'id': ['297'],
#   'ExperienceSearch[date_start]': ['2018-09-28'],
#   'ExperienceSearch[date_end]': ['2018-10-03']},
#  {'id': ['32'],
#   'ExperienceSearch[date_start]': ['2018-02-11'],
#   'ExperienceSearch[date_end]': ['2018-02-16']},
#  {'id': ['1']},
#  {'id': ['108'],
#   'LodgeSearch[date_start]': ['2018-08-24'],
#   'LodgeSearch[date_end]': ['2018-08-29']},
#  {'id': ['12'],
#   'LodgeSearch[date_start]': ['2018-08-20'],
#   'LodgeSearch[date_end]': ['2018-08-25']},
#  {'id': ['13'],
#   'LodgeSearch[date_start]': ['2018-03-01'],
#   'LodgeSearch[date_end]': ['2018-03-06']},
#  {'id': ['13'],
#   'LodgeSearch[date_start]': ['2018-03-01'],
#   'LodgeSearch[date_end]': ['2018-03-06']},
#  {'id': ['14'],
#   'LodgeSearch[date_start]': ['2018-07-26'],
#   'LodgeSearch[date_end]': ['2018-07-31']},
#  {'id': ['16']},
#  {'id': ['17'],
#   'LodgeSearch[date_start]': ['2018-02-14'],
#   'LodgeSearch[date_end]': ['2018-02-19']},
#  {'id': ['17'],
#   'LodgeSearch[date_start]': ['2018-03-02'],
#   'LodgeSearch[date_end]': ['2018-03-07']},
#  {'id': ['17'],
#   'LodgeSearch[date_start]': ['2018-06-07'],
#   'LodgeSearch[date_end]': ['2018-06-12']},
#  {'id': ['17'],
#   'LodgeSearch[date_start]': ['2018-09-08'],
#   'LodgeSearch[date_end]': ['2018-09-13']},
#  {'id': ['19']},
#  {'id': ['19'],
#   'LodgeSearch[date_start]': ['2018-01-27'],
#   'LodgeSearch[date_end]': ['2018-02-01']},
#  {'id': ['2']},
#  {'id': ['2'],
#   'LodgeSearch[date_start]': ['2017-12-22'],
#   'LodgeSearch[date_end]': ['2017-12-27']},
#  {'id': ['2'],
#   'LodgeSearch[date_start]': ['2018-03-28'],
#   'LodgeSearch[date_end]': ['2018-04-01'],
#   'LodgeSearch[num_adults]': ['6'],
#   'LodgeSearch[num_children]': ['0'],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['9999']},
#  {'id': ['2'],
#   'LodgeSearch[date_start]': ['2018-06-18'],
#   'LodgeSearch[date_end]': ['2018-06-23']},
#  {'id': ['2'],
#   'LodgeSearch[date_start]': ['2018-06-18'],
#   'LodgeSearch[date_end]': ['2018-06-23']},
#  {'id': ['2'],
#   'LodgeSearch[date_start]': ['2018-08-20'],
#   'LodgeSearch[date_end]': ['2018-08-26'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['1'],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['9999'],
#   'LodgeSearch[village_id]': [''],
#   'LodgeSearch[relevance]': ['cheap']},
#  {'id': ['20'],
#   'LodgeSearch[date_start]': ['2018-07-19'],
#   'LodgeSearch[date_end]': ['2018-07-24']},
#  {'id': ['22']},
#  {'id': ['22']},
#  {'id': ['22'],
#   'LodgeSearch[date_start]': ['2018-02-17'],
#   'LodgeSearch[date_end]': ['2018-02-22']},
#  {'id': ['22'],
#   'LodgeSearch[date_start]': ['2018-09-09'],
#   'LodgeSearch[date_end]': ['2018-09-14']},
#  {'id': ['23']},
#  {'id': ['23'],
#   'LodgeSearch[date_start]': ['2018-01-15'],
#   'LodgeSearch[date_end]': ['2018-01-20']},
#  {'id': ['23'],
#   'LodgeSearch[date_start]': ['2018-03-05'],
#   'LodgeSearch[date_end]': ['2018-03-10']},
#  {'id': ['23'],
#   'LodgeSearch[date_start]': ['2018-08-22'],
#   'LodgeSearch[date_end]': ['2018-08-27']},
#  {'id': ['23'],
#   'LodgeSearch[date_start]': ['2018-09-07'],
#   'LodgeSearch[date_end]': ['2018-09-12']},
#  {'id': ['24']},
#  {'id': ['24'],
#   'LodgeSearch[date_start]': ['2018-02-13'],
#   'LodgeSearch[date_end]': ['2018-02-18']},
#  {'id': ['25'],
#   'LodgeSearch[date_start]': ['2018-09-04'],
#   'LodgeSearch[date_end]': ['2018-09-09']},
#  {'id': ['26']},
#  {'id': ['26'],
#   'LodgeSearch[date_start]': ['2018-03-05'],
#   'LodgeSearch[date_end]': ['2018-03-10']},
#  {'id': ['27']},
#  {'id': ['29'],
#   'LodgeSearch[date_start]': ['2018-03-18'],
#   'LodgeSearch[date_end]': ['2018-03-23']},
#  {'id': ['30'],
#   'LodgeSearch[date_start]': ['2018-02-17'],
#   'LodgeSearch[date_end]': ['2018-02-22']},
#  {'id': ['31'],
#   'LodgeSearch[date_start]': ['2018-02-21'],
#   'LodgeSearch[date_end]': ['2018-02-26']},
#  {'id': ['31'],
#   'LodgeSearch[date_start]': ['2018-07-10'],
#   'LodgeSearch[date_end]': ['2018-07-15']},
#  {'id': ['31'],
#   'LodgeSearch[date_start]': ['2018-07-21'],
#   'LodgeSearch[date_end]': ['2018-07-26']},
#  {'id': ['31'],
#   'LodgeSearch[date_start]': ['2018-07-26'],
#   'LodgeSearch[date_end]': ['2018-07-31']},
#  {'id': ['31'],
#   'LodgeSearch[date_start]': ['2018-07-26'],
#   'LodgeSearch[date_end]': ['2018-07-31']},
#  {'id': ['32'],
#   'LodgeSearch[date_start]': ['2018-08-15'],
#   'LodgeSearch[date_end]': ['2018-08-20']},
#  {'id': ['34']},
#  {'id': ['34'],
#   'LodgeSearch[date_start]': ['2018-08-04'],
#   'LodgeSearch[date_end]': ['2018-08-11'],
#   'LodgeSearch[num_adults]': ['7']},
#  {'id': ['35']},
#  {'id': ['35'],
#   'LodgeSearch[date_start]': ['2018-02-17'],
#   'LodgeSearch[date_end]': ['2018-02-22']},
#  {'id': ['36']},
#  {'id': ['37']},
#  {'id': ['37'],
#   'LodgeSearch[date_start]': ['2018-02-08'],
#   'LodgeSearch[date_end]': ['2018-02-13']},
#  {'id': ['38'],
#   'LodgeSearch[date_start]': ['2017-12-18'],
#   'LodgeSearch[date_end]': ['2017-12-23']},
#  {'id': ['38'],
#   'LodgeSearch[date_start]': ['2018-02-03'],
#   'LodgeSearch[date_end]': ['2018-02-08']},
#  {'id': ['38'],
#   'LodgeSearch[date_start]': ['2018-07-15'],
#   'LodgeSearch[date_end]': ['2018-07-20']},
#  {'id': ['39'],
#   'LodgeSearch[date_start]': ['2018-03-03'],
#   'LodgeSearch[date_end]': ['2018-03-08']},
#  {'id': ['39'],
#   'LodgeSearch[date_start]': ['2018-08-24'],
#   'LodgeSearch[date_end]': ['2018-08-29']},
#  {'id': ['4'],
#   'LodgeSearch[date_start]': ['2018-02-28'],
#   'LodgeSearch[date_end]': ['2018-03-05']},
#  {'id': ['40']},
#  {'id': ['42']},
#  {'id': ['42'],
#   'LodgeSearch[date_start]': ['2018-02-28'],
#   'LodgeSearch[date_end]': ['2018-03-05']},
#  {'id': ['44'],
#   'LodgeSearch[date_start]': ['2018-02-03'],
#   'LodgeSearch[date_end]': ['2018-02-08']},
#  {'id': ['45'],
#   'LodgeSearch[date_start]': ['2018-01-28'],
#   'LodgeSearch[date_end]': ['2018-02-02']},
#  {'id': ['47'],
#   'LodgeSearch[date_start]': ['2018-07-24'],
#   'LodgeSearch[date_end]': ['2018-07-29']},
#  {'id': ['47'],
#   'LodgeSearch[date_start]': ['2018-07-30'],
#   'LodgeSearch[date_end]': ['2018-08-04']},
#  {'id': ['48'],
#   'LodgeSearch[date_start]': ['2018-03-01'],
#   'LodgeSearch[date_end]': ['2018-03-06']},
#  {'id': ['49'],
#   'LodgeSearch[date_start]': ['2018-02-02'],
#   'LodgeSearch[date_end]': ['2018-12-31'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0'],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['9999']},
#  {'id': ['49'],
#   'LodgeSearch[date_start]': ['2018-07-24'],
#   'LodgeSearch[date_end]': ['2018-07-29']},
#  {'id': ['5']},
#  {'id': ['5'],
#   'LodgeSearch[date_start]': ['2018-03-04'],
#   'LodgeSearch[date_end]': ['2018-12-31'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0'],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['9999']},
#  {'id': ['52'],
#   'LodgeSearch[date_start]': ['2018-02-16'],
#   'LodgeSearch[date_end]': ['2018-02-21']},
#  {'id': ['53']},
#  {'id': ['54']},
#  {'id': ['55']},
#  {'id': ['55'],
#   'LodgeSearch[date_start]': ['2018-02-27'],
#   'LodgeSearch[date_end]': ['2018-03-04']},
#  {'id': ['57']},
#  {'id': ['57'],
#   'LodgeSearch[date_start]': ['2018-02-07'],
#   'LodgeSearch[date_end]': ['2018-02-12']},
#  {'id': ['57'],
#   'LodgeSearch[date_start]': ['2018-09-14'],
#   'LodgeSearch[date_end]': ['2018-09-19'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0'],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['9999']},
#  {'id': ['59'],
#   'LodgeSearch[date_start]': ['2017-12-11'],
#   'LodgeSearch[date_end]': ['2017-12-16']},
#  {'id': ['59'],
#   'LodgeSearch[date_start]': ['2018-02-12'],
#   'LodgeSearch[date_end]': ['2018-02-13'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0'],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['9999']},
#  {'id': ['59'],
#   'LodgeSearch[date_start]': ['2018-02-26'],
#   'LodgeSearch[date_end]': ['2018-03-03']},
#  {'id': ['6'],
#   'LodgeSearch[date_start]': ['2017-12-30'],
#   'LodgeSearch[date_end]': ['2018-01-04']},
#  {'id': ['6'],
#   'LodgeSearch[date_start]': ['2018-06-23'],
#   'LodgeSearch[date_end]': ['2018-06-28']},
#  {'id': ['60'],
#   'LodgeSearch[date_start]': ['2017-12-09'],
#   'LodgeSearch[date_end]': ['2017-12-14'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0'],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['2500']},
#  {'id': ['60'],
#   'LodgeSearch[date_start]': ['2018-02-06'],
#   'LodgeSearch[date_end]': ['2018-12-31'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0'],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['9999']},
#  {'id': ['60'],
#   'LodgeSearch[date_start]': ['2018-02-21'],
#   'LodgeSearch[date_end]': ['2018-02-26']},
#  {'id': ['60'],
#   'LodgeSearch[date_start]': ['2018-02-22'],
#   'LodgeSearch[date_end]': ['2018-02-23'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0'],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['9999']},
#  {'id': ['60'],
#   'LodgeSearch[date_start]': ['2018-06-26'],
#   'LodgeSearch[date_end]': ['2018-07-01']},
#  {'id': ['61'],
#   'LodgeSearch[date_start]': ['2018-01-29'],
#   'LodgeSearch[date_end]': ['2018-12-31'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0'],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['9999']},
#  {'id': ['61'],
#   'LodgeSearch[date_start]': ['2018-07-10'],
#   'LodgeSearch[date_end]': ['2018-07-15']},
#  {'id': ['61'],
#   'LodgeSearch[date_start]': ['2018-09-11'],
#   'LodgeSearch[date_end]': ['2018-09-16']},
#  {'id': ['63'],
#   'LodgeSearch[date_start]': ['2018-02-15'],
#   'LodgeSearch[date_end]': ['2018-02-20']},
#  {'id': ['63'],
#   'LodgeSearch[date_start]': ['2018-03-05'],
#   'LodgeSearch[date_end]': ['2018-03-10']},
#  {'id': ['64'],
#   'LodgeSearch[date_start]': ['2017-12-05'],
#   'LodgeSearch[date_end]': ['2017-12-10'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0'],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['2500']},
#  {'id': ['64'],
#   'LodgeSearch[date_start]': ['2018-02-13'],
#   'LodgeSearch[date_end]': ['2018-02-18']},
#  {'id': ['66']},
#  {'id': ['66'],
#   'LodgeSearch[date_start]': ['2018-05-03'],
#   'LodgeSearch[date_end]': ['2018-05-08'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0'],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['9999'],
#   'LodgeSearch[village_id]': [''],
#   'LodgeSearch[relevance]': ['']},
#  {'id': ['66'],
#   'LodgeSearch[date_start]': ['2018-05-03'],
# ...
#   'LodgeSearch[village_id]': ['27'],
#   'LodgeSearch[relevance]': [''],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['9999'],
#   'LodgeSearch[date_start]': ['2018-01-03'],
#   'LodgeSearch[date_end]': ['2018-01-08'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0']},
#  {'LodgeSearch[type_id]': [''],
#   'LodgeSearch[fulltext]': [''],
#   'LodgeSearch[village_id]': ['27'],
#   'LodgeSearch[relevance]': [''],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['9999'],
#   'LodgeSearch[date_start]': ['2018-3-8'],
#   'LodgeSearch[date_end]': ['2018-3-11'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0']},
#  {'LodgeSearch[type_id]': [''],
#   'LodgeSearch[fulltext]': [''],
#   'LodgeSearch[village_id]': ['31'],
#   'LodgeSearch[relevance]': [''],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['2500'],
#   'LodgeSearch[date_start]': ['2017-12-05'],
#   'LodgeSearch[date_end]': ['2017-12-10'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0']},
#  {'LodgeSearch[type_id]': [''],
#   'LodgeSearch[fulltext]': [''],
#   'LodgeSearch[village_id]': ['31'],
#   'LodgeSearch[relevance]': [''],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['9999'],
#   'LodgeSearch[date_start]': ['2018-07-31'],
#   'LodgeSearch[date_end]': ['2018-08-05'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0']},
#  {'LodgeSearch[type_id]': [''],
#   'LodgeSearch[fulltext]': [''],
#   'LodgeSearch[village_id]': ['31'],
#   'LodgeSearch[relevance]': [''],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['9999'],
#   'LodgeSearch[date_start]': ['2018-07-31'],
#   'LodgeSearch[date_end]': ['2018-08-05'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0']},
#  {'LodgeSearch[type_id]': [''],
#   'LodgeSearch[fulltext]': [''],
#   'LodgeSearch[village_id]': ['31'],
#   'LodgeSearch[relevance]': [''],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['9999'],
#   'LodgeSearch[date_start]': ['2018-07-31'],
#   'LodgeSearch[date_end]': ['2018-08-05'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0']},
#  {'LodgeSearch[type_id]': [''],
#   'LodgeSearch[fulltext]': [''],
#   'LodgeSearch[village_id]': ['31'],
#   'LodgeSearch[relevance]': [''],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['9999'],
#   'LodgeSearch[date_start]': ['2018-8-2'],
#   'LodgeSearch[date_end]': ['2018-8-3'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0']},
#  {'LodgeSearch[type_id]': [''],
#   'LodgeSearch[fulltext]': [''],
#   'LodgeSearch[village_id]': ['31'],
#   'LodgeSearch[relevance]': [''],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['9999'],
#   'LodgeSearch[date_start]': ['2018-8-2'],
#   'LodgeSearch[date_end]': ['2018-8-3'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0']},
#  {'LodgeSearch[type_id]': [''],
#   'LodgeSearch[fulltext]': [''],
#   'LodgeSearch[village_id]': ['31'],
#   'LodgeSearch[relevance]': [''],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['9999'],
#   'LodgeSearch[date_start]': ['2018-8-2'],
#   'LodgeSearch[date_end]': ['2018-8-3'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0']},
#  {'LodgeSearch[type_id]': [''],
#   'LodgeSearch[fulltext]': [''],
#   'LodgeSearch[village_id]': ['36'],
#   'LodgeSearch[relevance]': [''],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['9999'],
#   'LodgeSearch[date_start]': ['2018-5-18'],
#   'LodgeSearch[date_end]': ['2018-5-18'],
#   'LodgeSearch[num_adults]': ['4'],
#   'LodgeSearch[num_children]': ['0']},
#  {'LodgeSearch[type_id]': [''],
#   'LodgeSearch[fulltext]': [''],
#   'LodgeSearch[village_id]': ['4'],
#   'LodgeSearch[relevance]': [''],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['9999'],
#   'LodgeSearch[date_start]': ['2018-01-03'],
#   'LodgeSearch[date_end]': ['2018-01-08'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0']},
#  {'LodgeSearch[type_id]': [''],
#   'LodgeSearch[fulltext]': [''],
#   'LodgeSearch[village_id]': ['4'],
#   'LodgeSearch[relevance]': [''],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['9999'],
#   'LodgeSearch[date_start]': ['2018-01-04'],
#   'LodgeSearch[date_end]': ['2018-01-09'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0']},
#  {'LodgeSearch[type_id]': [''],
#   'LodgeSearch[fulltext]': [''],
#   'LodgeSearch[village_id]': ['46'],
#   'LodgeSearch[relevance]': [''],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['9999'],
#   'LodgeSearch[date_start]': ['2018-03-06'],
#   'LodgeSearch[date_end]': ['2018-04-05'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0']},
#  {'LodgeSearch[type_id]': [''],
#   'LodgeSearch[fulltext]': [''],
#   'LodgeSearch[village_id]': ['51'],
#   'LodgeSearch[relevance]': [''],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['9999'],
#   'LodgeSearch[date_start]': ['2018-03-03'],
#   'LodgeSearch[date_end]': ['2018-12-31'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0']},
#  {'LodgeSearch[type_id]': [''],
#   'LodgeSearch[fulltext]': [''],
#   'LodgeSearch[village_id]': ['6'],
#   'LodgeSearch[relevance]': [''],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['9999'],
#   'LodgeSearch[date_start]': ['2018-01-05'],
#   'LodgeSearch[date_end]': ['2018-01-09'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0']},
#  {'LodgeSearch[type_id]': [''],
#   'LodgeSearch[fulltext]': [''],
#   'LodgeSearch[village_id]': ['6'],
#   'LodgeSearch[relevance]': [''],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['9999'],
#   'LodgeSearch[date_start]': ['2018-01-10'],
#   'LodgeSearch[date_end]': ['2018-01-15'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0']},
#  {'LodgeSearch[type_id]': [''],
#   'LodgeSearch[fulltext]': [''],
#   'LodgeSearch[village_id]': ['6'],
#   'LodgeSearch[relevance]': [''],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['9999'],
#   'LodgeSearch[date_start]': ['2018-01-16'],
#   'LodgeSearch[date_end]': ['2018-01-21'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0']},
#  {'LodgeSearch[type_id]': [''],
#   'LodgeSearch[fulltext]': [''],
#   'LodgeSearch[village_id]': ['6'],
#   'LodgeSearch[relevance]': ['cheap'],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['9999'],
#   'LodgeSearch[date_start]': ['2018-9-12'],
#   'LodgeSearch[date_end]': ['2018-9-14'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0']},
#  {'LodgeSearch[type_id]': [''],
#   'LodgeSearch[fulltext]': [''],
#   'LodgeSearch[village_id]': ['7'],
#   'LodgeSearch[relevance]': [''],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['9999'],
#   'LodgeSearch[date_start]': ['2018-01-03'],
#   'LodgeSearch[date_end]': ['2018-01-08'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0']},
#  {'LodgeSearch[type_id]': [''],
#   'LodgeSearch[fulltext]': [''],
#   'LodgeSearch[village_id]': ['7'],
#   'LodgeSearch[relevance]': [''],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['9999'],
#   'LodgeSearch[date_start]': ['2018-03-05'],
#   'LodgeSearch[date_end]': ['2018-03-10'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0']},
#  {'LodgeSearch[type_id]': [''],
#   'LodgeSearch[fulltext]': [''],
#   'LodgeSearch[village_id]': ['7'],
#   'LodgeSearch[relevance]': [''],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['9999'],
#   'LodgeSearch[date_start]': ['2018-03-05'],
#   'LodgeSearch[date_end]': ['2018-03-10'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0']},
#  {'LodgeSearch[type_id]': [''],
#   'LodgeSearch[fulltext]': [''],
#   'LodgeSearch[village_id]': ['7'],
#   'LodgeSearch[relevance]': [''],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['9999'],
#   'LodgeSearch[date_start]': ['2018-03-05'],
#   'LodgeSearch[date_end]': ['2018-03-10'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0']},
#  {'LodgeSearch[type_id]': [''],
#   'LodgeSearch[fulltext]': [''],
#   'LodgeSearch[village_id]': ['7'],
#   'LodgeSearch[relevance]': [''],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['9999'],
#   'LodgeSearch[date_start]': ['2018-03-05'],
#   'LodgeSearch[date_end]': ['2018-03-10'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0']},
#  {'LodgeSearch[type_id]': [''],
#   'LodgeSearch[fulltext]': [''],
#   'LodgeSearch[village_id]': ['7'],
#   'LodgeSearch[relevance]': [''],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['9999'],
#   'LodgeSearch[date_start]': ['2018-03-05'],
#   'LodgeSearch[date_end]': ['2018-03-10'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0']},
#  {'LodgeSearch[type_id]': [''],
#   'LodgeSearch[fulltext]': [''],
#   'LodgeSearch[village_id]': ['7'],
#   'LodgeSearch[relevance]': [''],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['9999'],
#   'LodgeSearch[date_start]': ['2018-08-31'],
#   'LodgeSearch[date_end]': ['2018-09-05'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0']},
#  {'LodgeSearch[type_id]': [''],
#   'LodgeSearch[fulltext]': [''],
#   'LodgeSearch[village_id]': ['7'],
#   'LodgeSearch[relevance]': [''],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['9999'],
#   'LodgeSearch[date_start]': ['2018-10-4'],
#   'LodgeSearch[date_end]': ['2018-10-7'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0']},
#  {'LodgeSearch[type_id]': [''],
#   'LodgeSearch[fulltext]': [''],
#   'LodgeSearch[village_id]': ['7'],
#   'LodgeSearch[relevance]': ['cheap'],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['9999'],
#   'LodgeSearch[date_start]': ['2018-04-15'],
#   'LodgeSearch[date_end]': ['2018-04-20'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0']},
#  {'LodgeSearch[type_id]': [''],
#   'LodgeSearch[fulltext]': [''],
#   'LodgeSearch[village_id]': ['8'],
#   'LodgeSearch[relevance]': [''],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['9999'],
#   'LodgeSearch[date_start]': ['2018-01-04'],
#   'LodgeSearch[date_end]': ['2018-01-09'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0']},
#  {'LodgeSearch[type_id]': [''],
#   'LodgeSearch[fulltext]': ['água formosa'],
#   'LodgeSearch[date_start]': ['2018-5-31'],
#   'LodgeSearch[date_end]': ['2018-6-3'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0']},
#  {'LodgeSearch[type_id]': [''],
#   'LodgeSearch[fulltext]': ['água formosa'],
#   'LodgeSearch[date_start]': ['2018-5-31'],
#   'LodgeSearch[date_end]': ['2018-6-3'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0']},
#  {'LodgeSearch[type_id]': [''],
#   'LodgeSearch[fulltext]': ['água formosa'],
#   'LodgeSearch[date_start]': ['2018-5-31'],
#   'LodgeSearch[date_end]': ['2018-6-3'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0']},
#  {'LodgeSearch[type_id]': [''],
#   'LodgeSearch[fulltext]': ['Aldeias do xisto'],
#   'LodgeSearch[date_start]': ['2018-3-17'],
#   'LodgeSearch[date_end]': ['2018-3-18'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0']},
#  {'LodgeSearch[type_id]': [''], 'LodgeSearch[fulltext]': ['antão']},
#  {'LodgeSearch[type_id]': [''], 'LodgeSearch[fulltext]': ['camelo']},
#  {'LodgeSearch[type_id]': [''], 'LodgeSearch[fulltext]': ['camping']},
#  {'LodgeSearch[type_id]': [''], 'LodgeSearch[fulltext]': ['camping']},
#  {'LodgeSearch[type_id]': [''],
#   'LodgeSearch[fulltext]': ['camping'],
#   'LodgeSearch[village_id]': [''],
#   'LodgeSearch[relevance]': [''],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['9999']},
#  {'LodgeSearch[type_id]': [''],
#   'LodgeSearch[fulltext]': ['camping'],
#   'LodgeSearch[village_id]': [''],
#   'LodgeSearch[relevance]': [''],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['9999'],
#   'LodgeSearch[date_start]': ['2018-8-10'],
#   'LodgeSearch[date_end]': ['2018-8-12'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0']},
#  {'LodgeSearch[type_id]': [''],
#   'LodgeSearch[fulltext]': ['camping'],
#   'LodgeSearch[village_id]': [''],
#   'LodgeSearch[relevance]': [''],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['9999'],
#   'LodgeSearch[date_start]': ['2018-8-10'],
#   'LodgeSearch[date_end]': ['2018-8-12'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0']},
#  {'LodgeSearch[type_id]': [''],
#   'LodgeSearch[fulltext]': ['Camping oleiros'],
#   'LodgeSearch[date_start]': ['2018-9-4'],
#   'LodgeSearch[date_end]': ['2018-9-7'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0']},
#  {'LodgeSearch[type_id]': [''],
#   'LodgeSearch[fulltext]': ['cancela'],
#   'LodgeSearch[date_start]': ['2018-8-20'],
#   'LodgeSearch[date_end]': ['2018-8-23'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0']},
#  {'LodgeSearch[type_id]': [''], 'LodgeSearch[fulltext]': ['carregais']},
#  {'LodgeSearch[type_id]': [''],
#   'LodgeSearch[fulltext]': ['carregais'],
#   'LodgeSearch[village_id]': [''],
#   'LodgeSearch[relevance]': [''],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['9999'],
#   'LodgeSearch[date_start]': ['2018-9-21'],
#   'LodgeSearch[date_end]': ['2018-9-23'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0']},
#  {'LodgeSearch[type_id]': [''],
#   'LodgeSearch[fulltext]': ['carregais'],
#   'LodgeSearch[village_id]': [''],
#   'LodgeSearch[relevance]': [''],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['9999'],
#   'LodgeSearch[date_start]': ['2018-9-21'],
#   'LodgeSearch[date_end]': ['2018-9-23'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0']},
#  {'LodgeSearch[type_id]': [''],
#   'LodgeSearch[fulltext]': ['casa do olival'],
#   'LodgeSearch[date_start]': ['2018-3-23'],
#   'LodgeSearch[date_end]': ['2018-3-24'],
#   'LodgeSearch[num_adults]': ['6'],
#   'LodgeSearch[num_children]': ['0']},
#  {'LodgeSearch[type_id]': [''],
#   'LodgeSearch[fulltext]': ['casa do olival'],
#   'LodgeSearch[date_start]': ['2018-3-23'],
#   'LodgeSearch[date_end]': ['2018-3-24'],
#   'LodgeSearch[num_adults]': ['6'],
#   'LodgeSearch[num_children]': ['0']},
#  {'LodgeSearch[type_id]': [''],
#   'LodgeSearch[fulltext]': ['Casa do terreiro'],
#   'LodgeSearch[date_start]': ['2018-4-26'],
#   'LodgeSearch[date_end]': ['2018-4-29'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0']},
#  {'LodgeSearch[type_id]': [''], 'LodgeSearch[fulltext]': ['casasdorio']},
#  {'LodgeSearch[type_id]': [''], 'LodgeSearch[fulltext]': ['casasdorio']},
#  {'LodgeSearch[type_id]': [''],
#   'LodgeSearch[fulltext]': ['cerdeira'],
#   'LodgeSearch[date_start]': ['2018-10-5'],
#   'LodgeSearch[date_end]': ['2018-10-7'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0']},
#  {'LodgeSearch[type_id]': [''],
#   'LodgeSearch[fulltext]': ['cerdeira village'],
#   'LodgeSearch[village_id]': ['7'],
#   'LodgeSearch[relevance]': [''],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['9999'],
#   'LodgeSearch[date_start]': ['2018-7-1'],
#   'LodgeSearch[date_end]': ['2018-7-31'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0']},
#  {'LodgeSearch[type_id]': [''],
#   'LodgeSearch[fulltext]': ['cerdeira village'],
#   'LodgeSearch[village_id]': ['7'],
#   'LodgeSearch[relevance]': [''],
#   'LodgeSearch[price_low]': ['0'],
#   'LodgeSearch[price_high]': ['9999'],
#   'LodgeSearch[date_start]': ['2018-7-1'],
#   'LodgeSearch[date_end]': ['2018-7-31'],
#   'LodgeSearch[num_adults]': ['2'],
#   'LodgeSearch[num_children]': ['0']},
#  {'LodgeSearch[type_id]': [''], 'LodgeSearch[fulltext]': ['cerdeiravillage']},
#  {'LodgeSearch[type_id]': [''], 'LodgeSearch[fulltext]': ['cerdeiravillage']},
#  {'LodgeSearch[type_id]': [''], 'LodgeSearch[fulltext]': ['cerdeiravillage']},
#  ...]
