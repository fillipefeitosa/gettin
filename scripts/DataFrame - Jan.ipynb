# %%
import pandas as pd 
import numpy as np 

df = pd.read_csv("../data_gettin/nascimentos 03 idade da mãe sexo concelho.csv",encoding="latin_1", engine='python', sep = ";", header = 0, dtype= {'Code': str}) 
df['code'], df['nome'] = df['Local de residência da mãe (NUTS - 2002) (2) '].str.split(':').str 
df.drop([0,2,4,5,6], inplace = True) 
df.drop(['Local de residência da mãe (NUTS - 2002) (2) ', 'Unnamed: 98'], inplace = True,axis=1) 

l =['ano'] 
for i in range (0,len(df.columns)-3): 
    if i < (len(df.columns)-3)/2: 
        l.append("H_") 
    else: 
        l.append("M_") 
l.append("") 
l.append("nome") 
df.loc[1] = l 


df.index = df ['code'] 
df.drop(['code'], inplace = True,axis=1) 
df 
lista =['ano'] 
for i in range (1,len(df.columns)-1): 
    lista.append(str(df.iloc[0,i]) + str(df.iloc[1,i])) 

lista.append('nome') 
df.columns = lista 
df.drop(df.index[[0,1]], inplace = True) 

anos2 = df.ano.unique() 
anos2 = np.delete (anos2,1) 
for i in range(int(len(df.index))): 
    df.iloc[i,0] = anos2[0] 

cols = df.columns.tolist() 
cols = cols[-1:] + cols[:-1] 
df = df[cols] 

cols1 = cols[2:(int(len(cols[2:])/2+2))] 
df_h = df[cols1]
df_h 

cols2 = cols[(int(len(cols[2:])/2+2)):] 
df_m = df[cols2] 
df_m 

# df_h['H_Total'] + df_m['M_Total'] 
# df_add = df1.iloc[0,] + df2.iloc[0,] 
# df_add 
# for i in range (1,len(df1)): 
# df_add = df1.iloc[i,] + df2.iloc[i,] 
# df_add 
# df_add = df1.add(df2, fill_value=0)
# Out:
#         M_Total M_10 anos M_11 anos M_12 anos M_13 anos M_14 anos M_15 anos  \
# code
# T         54343         0         0         0         8        31       128
# PT        54305         0         0         0         8        31       128
# 1         51198         0         0         0         8        27       117
# 11        19210         0         0         0         3         8        46
# 111        1073         0         0         0         0         0         1
# 1111601      88         0         0         0         0         0         0
# 1111602      60         0         0         0         0         0         0
# 1111603      28         0         0         0         0         0         0
# 1111604      61         0         0         0         0         0         0
# 1111605      35         0         0         0         0         0         0
# 1111606      41         0         0         0         0         0         0
# ...

# %%
# First Transform your values to numeric
df_m = df_m.apply(pd.to_numeric)
df_h = df_h.apply(pd.to_numeric)

# %%
# Then you change your collums
df_m.columns = df_h.columns

# %%
# Finally you sum. Both work...
df_r = (df_m.reindex_like(df_h).fillna(0) + df_h.fillna(0)).fillna(0)
df_r = df_h.add(df_m, fill_value=0)

# %%
df_m.loc["T"][0]+df_h.loc["T"][0]
# Out:
# 112589

# %%
df_r
# Out:
#          H_Total  H_10 anos  H_11 anos  H_12 anos  H_13 anos  H_14 anos  \
# code
# T         112589          0          0          0         15         61
# PT        112515          0          0          0         15         61
# 1         106232          0          0          0         15         52
# 11         39903          0          0          0          5         14
# 111         2215          0          0          0          0          1
# 1111601      186          0          0          0          0          0
# 1111602      120          0          0          0          0          0
# 1111603       55          0          0          0          0          0
# 1111604      139          0          0          0          0          1
# 1111605       75          0          0          0          0          0
# 1111606       90          0          0          0          0          0
# 1111607      473          0          0          0          0          0
# ...
