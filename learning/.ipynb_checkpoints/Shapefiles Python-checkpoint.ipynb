# %% [markdown]
# # Pyshp and Geo_Interface
# ## Fillipe Feitosa <fillipefeitosa@ua.pt>
# ---
#
# Objetive: Use pyshp (shapefile) to extract geojson data

# %% [markdown]
# ### List of imports

# %%
import shapefile as sh
from pprint import pprint
from geojsonio import display, embed
import json

# %% [markdown]
# ### Shapefile manipulation

# %%
# Read ShapeFile Folder to create a Reader Obj
# sf = sh.Reader("escolas_detim/equipamentos_escolares_novo")
sf = sh.Reader("escolas_wg8/Escolas_novo")

print("Lista de Tags -> Fields \n")
pprint(sf.fields)

print("\n Quantidade de Escolas -> Records: ", len(sf.records()))


# Print the first School Data
shapeRecords = sf.shapeRecords()
record1 = shapeRecords[0]
print("\n Record 1: ", record1.record)
print("\n Record 1 Points: ", record1.shape.points)
# Out:
# Lista de Tags -> Fields
#
# [('DeletionFlag', 'C', 1, 0),
#  ['OBJECTID', 'N', 10, 0],
#  ['ESTADO_EDI', 'N', 5, 0],
#  ['ALTURA', 'N', 5, 0],
#  ['N_PISOS', 'N', 5, 0],
#  ['IDADE', 'N', 5, 0],
#  ['TIPO', 'N', 10, 0],
#  ['CONT_CONTE', 'C', 254, 0],
#  ['DESC_TITUL', 'C', 200, 0],
#  ['DESC_DESCR', 'C', 250, 0],
#  ['DESC_PALAV', 'C', 250, 0],
#  ['N_ALUNOS', 'N', 5, 0],
#  ['HORARIO', 'C', 200, 0],
#  ['ORGANIZACA', 'N', 10, 0],
#  ['CONTACTO_I', 'N', 10, 0],
#  ['LOTACAO', 'N', 10, 0],
#  ['Legenda', 'N', 4, 0],
#  ['Publico', 'N', 4, 0],
#  ['2_CEB', 'N', 4, 0],
#  ['3_CEB', 'N', 4, 0]]
#
#  Quantidade de Escolas -> Records:  24
#
#  Record 1:  [834, 0, 0, 0, 0, 0, '', 'Colégio Diocesano de N. Sra. Apresentação (básico 2,3, secundário)', '', '', 0, '', 0, 0, 0, 0, 1, 1, 1]
#
#  Record 1 Points:  [[-8.705604482289335, 40.479016736280435]]

# %% [markdown]
# ### Iterate over ShapeRecords()

# %%
      
# Show Shapes and Records
for shapeRecord in sf.shapeRecords():
    print("Escola: ", shapeRecord.record[7]) 
    print("x: ", shapeRecord.shape.points[0][0])
    print("y: ", shapeRecord.shape.points[0][1])
    print("--------------")
# Out:
# Escola:  Colégio Diocesano de N. Sra. Apresentação (básico 2,3, secundário)
# x:  -8.705604482289335
# y:  40.479016736280435
# --------------
# Escola:  Escola do 1º Ciclo do Ensino Básico de Calvão
# x:  -8.69828323132238
# y:  40.47415595381745
# --------------
# Escola:  Escola do 1º Ciclo do Ensino Básico de Cabecinhas
# x:  -8.690559804343296
# y:  40.48895594351363
# --------------
# Escola:  Jardim de Infância da Lomba
# x:  -8.697142386076381
# y:  40.522986573712814
# --------------
# Escola:  Escola do 1º Ciclo do Ensino Básico de Lombomeão
# x:  -8.695838483393436
# y:  40.541452747338305
# --------------
# Escola:  Escola do 1º Ciclo do Ensino Básico de Ouca
# x:  -8.64896768796315
# y:  40.515210271716676
# --------------
# Escola:  Escola do 1º Ciclo do Ensino Básico de Quintã
# x:  -8.680048158641855
# y:  40.530128040977715
# --------------
# Escola:  Escola do 1º Ciclo do Ensino Básico de Salgueiro
# x:  -8.623770087696503
# y:  40.55792983843377
# --------------
# Escola:  Escola do 1º Ciclo do Ensino Básico de Sosa (Escola Básica de Sosa)
# x:  -8.661990347286466
# y:  40.543477650486494
# --------------
# Escola:  Jardim de Infância de Vagos
# x:  -8.683266309159986
# y:  40.55551527058609
# --------------
# Escola:  Escola do 1º Ciclo do Ensino Básico de Vigia
# x:  -8.688033326897399
# y:  40.51120250520209
# --------------
# Escola:  Jardim de Infância de Sto. André
# x:  -8.67698962132005
# y:  40.51282214863392
# --------------
# Escola:  Escola EB 2/3 João Rocha Pai
# x:  -8.682878548016454
# y:  40.545671242829485
# --------------
# Escola:  EPADRV (profissional)
# x:  -8.750613115526573
# y:  40.546099244669264
# --------------
# Escola:  Escola Secundária de Vagos
# x:  -8.684397910971102
# y:  40.54767825099862
# --------------
# Escola:  Jardim de Infância de Ouca
# x:  -8.652530598478105
# y:  40.51965075571783
# --------------
# Escola:  Jardim de Infância de Sosa
# x:  -8.661424396856658
# y:  40.54531522389101
# --------------
# Escola:  Jardim de Infância de Salgueiro
# x:  -8.62898213937148
# y:  40.554794544792685
# --------------
# Escola:  Jardim de Infância da Sta. Casa Misericórdia de Vagos
# x:  -8.685607739930303
# y:  40.55210523787586
# --------------
# Escola:  Associação BETEL (Creche e Pré-escolar)
# x:  -8.66488465799478
# y:  40.47572603365941
# --------------
# Escola:  Centro Escolar Gafanha Boa Hora 1/2
# x:  -8.752677612725849
# y:  40.54261165687378
# --------------
# Escola:  Centro Escolar Fonte de Angeão 1/2
# x:  -8.6696527509098
# y:  40.454154934091264
# --------------
# Escola:  Comissão de Apoio e Desenvolvimento Social de Santa Catarina (Creche e Pré-escolar)
# x:  -8.639882417257894
# y:  40.4665866164409
# --------------
# Escola:  Jardim de Infância de Calvão
# x:  -8.698788076221431
# y:  40.478319914979934
# --------------

# %% [markdown]
# ### Geo_Interface Manipulation - Tests with Records and Geo_Interface

# %%
# Tests with Records and Geo_Interface
print("----------- Geo_Interface Test ----------")
s = sf.shape(0)
print(s.__geo_interface__["coordinates"])

s2 = sf.shape(1)
print(s2.__geo_interface__["coordinates"])
# Out:
# ----------- Geo_Interface Test ----------
# (-8.705604482289335, 40.479016736280435)
# (-8.69828323132238, 40.47415595381745)

# %%
with open('schools.json') as f:
    contents = f.read();

embed(contents)
# display(contents)
    
# pprint(contents)
# Out:
# <iframe src=http://geojson.io/#data=data:application/json,%7B%22type%22%3A%20%22FeatureCollection%22%2C%20%22features%22%3A%20%5B%7B%22type%22%3A%20%22Feature%22%2C%20%22geometry%22%3A%20%7B%22type%22%3A%20%22Point%22%2C%20%22coordinates%22%3A%20%5B-8.705604482289335%2C%2040.479016736280435%5D%7D%2C%20%22properties%22%3A%20%7B%22OBJECTID%22%3A%20834%2C%20%22ESTADO_EDI%22%3A%200%2C%20%22ALTURA%22%3A%200%2C%20%22N_PISOS%22%3A%200%2C%20%22IDADE%22%3A%200%2C%20%22TIPO%22%3A%200%2C%20%22CONT_CONTE%22%3A%20%22%22%2C%20%22DESC_TITUL%22%3A%20%22Col%5Cu00e9gio%20Diocesano%20de%20N.%20Sra.%20Apresenta%5Cu00e7%5Cu00e3o%20%28b%5Cu00e1sico%202%2C3%2C%20secund%5Cu00e1rio%29%22%2C%20%22DESC_DESCR%22%3A%20%22%22%2C%20%22DESC_PALAV%22%3A%20%22%22%2C%20%22N_ALUNOS%22%3A%200%2C%20%22HORARIO%22%3A%20%22%22%2C%20%22ORGANIZACA%22%3A%200%2C%20%22CONTACTO_I%22%3A%200%2C%20%22LOTACAO%22%3A%200%2C%20%22Legenda%22%3A%200%2C%20%22Publico%22%3A%201%2C%20%222_CEB%22%3A%201%2C%20%223_CEB%22%3A%201%7D%7D%2C%20%7B%22type%22%3A%20%22Feature%22%2C%20%22geometry%22%3A%20%7B%22type%22%3A%20%22Point%22%2C%20%22coordinates%22%3A%20%5B-8.69828323132238%2C%2040.47415595381745%5D%7D%2C%20%22properties%22%3A%20%7B%22OBJECTID%22%3A%20837%2C%20%22ESTADO_EDI%22%3A%200%2C%20%22ALTURA%22%3A%200%2C%20%22N_PISOS%22%3A%200%2C%20%22IDADE%22%3A%200%2C%20%22TIPO%22%3A%200%2C%20%22CONT_CONTE%22%3A%20%22%22%2C%20%22DESC_TITUL%22%3A%20%22Escola%20do%201%5Cu00ba%20Ciclo%20do%20Ensino%20B%5Cu00e1sico%20de%20Calv%5Cu00e3o%22%2C%20%22DESC_DESCR%22%3A%20%22%22%2C%20%22DESC_PALAV%22%3A%20%22%22%2C%20%22N_ALUNOS%22%3A%200%2C%20%22HORARIO%22%3A%20%22%22%2C%20%22ORGANIZACA%22%3A%200%2C%20%22CONTACTO_I%22%3A%200%2C%20%22LOTACAO%22%3A%200%2C%20%22Legenda%22%3A%207%2C%20%22Publico%22%3A%200%2C%20%222_CEB%22%3A%200%2C%20%223_CEB%22%3A%200%7D%7D%2C%20%7B%22type%22%3A%20%22Feature%22%2C%20%22geometry%22%3A%20%7B%22type%22%3A%20%22Point%22%2C%20%22coordinates%22%3A%20%5B-8.690559804343296%2C%2040.48895594351363%5D%7D%2C%20%22properties%22%3A%20%7B%22OBJECTID%22%3A%20838%2C%20%22ESTADO_EDI%22%3A%200%2C%20%22ALTURA%22%3A%200%2C%20%22N_PISOS%22%3A%200%2C%20%22IDADE%22%3A%200%2C%20%22TIPO%22%3A%200%2C%20%22CONT_CONTE%22%3A%20%22%22%2C%20%22DESC_TITUL%22%3A%20%22Escola%20do%201%5Cu00ba%20Ciclo%20do%20Ensino%20B%5Cu00e1sico%20de%20Cabecinhas%22%2C%20%22DESC_DESCR%22%3A%20%22%22%2C%20%22DESC_PALAV%22%3A%20%22%22%2C%20%22N_ALUNOS%22%3A%200%2C%20%22HORARIO%22%3A%20%22%22%2C%20%22ORGANIZACA%22%3A%200%2C%20%22CONTACTO_I%22%3A%200%2C%20%22LOTACAO%22%3A%200%2C%20%22Legenda%22%3A%206%2C%20%22Publico%22%3A%200%2C%20%222_CEB%22%3A%200%2C%20%223_CEB%22%3A%200%7D%7D%2C%20%7B%22type%22%3A%20%22Feature%22%2C%20%22geometry%22%3A%20%7B%22type%22%3A%20%22Point%22%2C%20%22coordinates%22%3A%20%5B-8.697142386076381%2C%2040.522986573712814%5D%7D%2C%20%22properties%22%3A%20%7B%22OBJECTID%22%3A%20846%2C%20%22ESTADO_EDI%22%3A%200%2C%20%22ALTURA%22%3A%200%2C%20%22N_PISOS%22%3A%200%2C%20%22IDADE%22%3A%200%2C%20%22TIPO%22%3A%200%2C%20%22CONT_CONTE%22%3A%20%22%22%2C%20%22DESC_TITUL%22%3A%20%22Jardim%20de%20Inf%5Cu00e2ncia%20da%20Lomba%22%2C%20%22DESC_DESCR%22%3A%20%22%22%2C%20%22DESC_PALAV%22%3A%20%22%22%2C%20%22N_ALUNOS%22%3A%200%2C%20%22HORARIO%22%3A%20%22%22%2C%20%22ORGANIZACA%22%3A%200%2C%20%22CONTACTO_I%22%3A%200%2C%20%22LOTACAO%22%3A%200%2C%20%22Legenda%22%3A%200%2C%20%22Publico%22%3A%200%2C%20%222_CEB%22%3A%200%2C%20%223_CEB%22%3A%200%7D%7D%2C%20%7B%22type%22%3A%20%22Feature%22%2C%20%22geometry%22%3A%20%7B%22type%22%3A%20%22Point%22%2C%20%22coordinates%22%3A%20%5B-8.695838483393436%2C%2040.541452747338305%5D%7D%2C%20%22properties%22%3A%20%7B%22OBJECTID%22%3A%20847%2C%20%22ESTADO_EDI%22%3A%200%2C%20%22ALTURA%22%3A%200%2C%20%22N_PISOS%22%3A%200%2C%20%22IDADE%22%3A%200%2C%20%22TIPO%22%3A%200%2C%20%22CONT_CONTE%22%3A%20%22%22%2C%20%22DESC_TITUL%22%3A%20%22Escola%20do%201%5Cu00ba%20Ciclo%20do%20Ensino%20B%5Cu00e1sico%20de%20Lombome%5Cu00e3o%22%2C%20%22DESC_DESCR%22%3A%20%22%22%2C%20%22DESC_PALAV%22%3A%20%22%22%2C%20%22N_ALUNOS%22 ...

# %%
# geojsonio.display(contents)
display(contents)
# Out:
# 'http://geojson.io/#data=data:application/json,%7B%22type%22%3A%20%22FeatureCollection%22%2C%20%22features%22%3A%20%5B%7B%22type%22%3A%20%22Feature%22%2C%20%22geometry%22%3A%20%7B%22type%22%3A%20%22Point%22%2C%20%22coordinates%22%3A%20%5B-8.705604482289335%2C%2040.479016736280435%5D%7D%2C%20%22properties%22%3A%20%7B%22OBJECTID%22%3A%20834%2C%20%22ESTADO_EDI%22%3A%200%2C%20%22ALTURA%22%3A%200%2C%20%22N_PISOS%22%3A%200%2C%20%22IDADE%22%3A%200%2C%20%22TIPO%22%3A%200%2C%20%22CONT_CONTE%22%3A%20%22%22%2C%20%22DESC_TITUL%22%3A%20%22Col%5Cu00e9gio%20Diocesano%20de%20N.%20Sra.%20Apresenta%5Cu00e7%5Cu00e3o%20%28b%5Cu00e1sico%202%2C3%2C%20secund%5Cu00e1rio%29%22%2C%20%22DESC_DESCR%22%3A%20%22%22%2C%20%22DESC_PALAV%22%3A%20%22%22%2C%20%22N_ALUNOS%22%3A%200%2C%20%22HORARIO%22%3A%20%22%22%2C%20%22ORGANIZACA%22%3A%200%2C%20%22CONTACTO_I%22%3A%200%2C%20%22LOTACAO%22%3A%200%2C%20%22Legenda%22%3A%200%2C%20%22Publico%22%3A%201%2C%20%222_CEB%22%3A%201%2C%20%223_CEB%22%3A%201%7D%7D%2C%20%7B%22type%22%3A%20%22Feature%22%2C%20%22geometry%22%3A%20%7B%22type%22%3A%20%22Point%22%2C%20%22coordinates%22%3A%20%5B-8.69828323132238%2C%2040.47415595381745%5D%7D%2C%20%22properties%22%3A%20%7B%22OBJECTID%22%3A%20837%2C%20%22ESTADO_EDI%22%3A%200%2C%20%22ALTURA%22%3A%200%2C%20%22N_PISOS%22%3A%200%2C%20%22IDADE%22%3A%200%2C%20%22TIPO%22%3A%200%2C%20%22CONT_CONTE%22%3A%20%22%22%2C%20%22DESC_TITUL%22%3A%20%22Escola%20do%201%5Cu00ba%20Ciclo%20do%20Ensino%20B%5Cu00e1sico%20de%20Calv%5Cu00e3o%22%2C%20%22DESC_DESCR%22%3A%20%22%22%2C%20%22DESC_PALAV%22%3A%20%22%22%2C%20%22N_ALUNOS%22%3A%200%2C%20%22HORARIO%22%3A%20%22%22%2C%20%22ORGANIZACA%22%3A%200%2C%20%22CONTACTO_I%22%3A%200%2C%20%22LOTACAO%22%3A%200%2C%20%22Legenda%22%3A%207%2C%20%22Publico%22%3A%200%2C%20%222_CEB%22%3A%200%2C%20%223_CEB%22%3A%200%7D%7D%2C%20%7B%22type%22%3A%20%22Feature%22%2C%20%22geometry%22%3A%20%7B%22type%22%3A%20%22Point%22%2C%20%22coordinates%22%3A%20%5B-8.690559804343296%2C%2040.48895594351363%5D%7D%2C%20%22properties%22%3A%20%7B%22OBJECTID%22%3A%20838%2C%20%22ESTADO_EDI%22%3A%200%2C%20%22ALTURA%22%3A%200%2C%20%22N_PISOS%22%3A%200%2C%20%22IDADE%22%3A%200%2C%20%22TIPO%22%3A%200%2C%20%22CONT_CONTE%22%3A%20%22%22%2C%20%22DESC_TITUL%22%3A%20%22Escola%20do%201%5Cu00ba%20Ciclo%20do%20Ensino%20B%5Cu00e1sico%20de%20Cabecinhas%22%2C%20%22DESC_DESCR%22%3A%20%22%22%2C%20%22DESC_PALAV%22%3A%20%22%22%2C%20%22N_ALUNOS%22%3A%200%2C%20%22HORARIO%22%3A%20%22%22%2C%20%22ORGANIZACA%22%3A%200%2C%20%22CONTACTO_I%22%3A%200%2C%20%22LOTACAO%22%3A%200%2C%20%22Legenda%22%3A%206%2C%20%22Publico%22%3A%200%2C%20%222_CEB%22%3A%200%2C%20%223_CEB%22%3A%200%7D%7D%2C%20%7B%22type%22%3A%20%22Feature%22%2C%20%22geometry%22%3A%20%7B%22type%22%3A%20%22Point%22%2C%20%22coordinates%22%3A%20%5B-8.697142386076381%2C%2040.522986573712814%5D%7D%2C%20%22properties%22%3A%20%7B%22OBJECTID%22%3A%20846%2C%20%22ESTADO_EDI%22%3A%200%2C%20%22ALTURA%22%3A%200%2C%20%22N_PISOS%22%3A%200%2C%20%22IDADE%22%3A%200%2C%20%22TIPO%22%3A%200%2C%20%22CONT_CONTE%22%3A%20%22%22%2C%20%22DESC_TITUL%22%3A%20%22Jardim%20de%20Inf%5Cu00e2ncia%20da%20Lomba%22%2C%20%22DESC_DESCR%22%3A%20%22%22%2C%20%22DESC_PALAV%22%3A%20%22%22%2C%20%22N_ALUNOS%22%3A%200%2C%20%22HORARIO%22%3A%20%22%22%2C%20%22ORGANIZACA%22%3A%200%2C%20%22CONTACTO_I%22%3A%200%2C%20%22LOTACAO%22%3A%200%2C%20%22Legenda%22%3A%200%2C%20%22Publico%22%3A%200%2C%20%222_CEB%22%3A%200%2C%20%223_CEB%22%3A%200%7D%7D%2C%20%7B%22type%22%3A%20%22Feature%22%2C%20%22geometry%22%3A%20%7B%22type%22%3A%20%22Point%22%2C%20%22coordinates%22%3A%20%5B-8.695838483393436%2C%2040.541452747338305%5D%7D%2C%20%22properties%22%3A%20%7B%22OBJECTID%22%3A%20847%2C%20%22ESTADO_EDI%22%3A%200%2C%20%22ALTURA%22%3A%200%2C%20%22N_PISOS%22%3A%200%2C%20%22IDADE%22%3A%200%2C%20%22TIPO%22%3A%200%2C%20%22CONT_CONTE%22%3A%20%22%22%2C%20%22DESC_TITUL%22%3A%20%22Escola%20do%201%5Cu00ba%20Ciclo%20do%20Ensino%20B%5Cu00e1sico%20de%20Lombome%5Cu00e3o%22%2C%20%22DESC_DESCR%22%3A%20%22%22%2C%20%22DESC_PALAV%22%3A%20%22%22%2C%20%22N_ALUNOS%22%3A%200%2C% ...

# %%
# import json
json.dumps(['foo', {'bar': ('baz', None, 1.0, 2)}])
# Out:
# '["foo", {"bar": ["baz", null, 1.0, 2]}]'
