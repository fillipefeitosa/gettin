# %%
# List of Imports
import json
from geojson_utils import centroid
box_str = '{"type": "Polygon","coordinates": [[ [0, 0], [10, 0], [10, 10], [0, 10] ]]}'
box = json.loads(box_str)

centroid(box)
# box

#{"type": "Point", "coordinates": [5, 5]})
# Out:
# {'type': 'Point', 'coordinates': [5.0, 5.0]}

# %%
centroid = centroid(box)

# %%
centroid
# Out:
# {'type': 'Point', 'coordinates': [5.0, 5.0]}

# %%
centroid.values()
# Out:
# dict_values(['Point', [5.0, 5.0]])

# %%
centroidCoord = list(centroid.values())

# %%
# Usar este método
centroid['coordinates']
# Out:
# [5.0, 5.0]

# %%
import geojson
with open('../data_gettin/vagos.geojson') as f:
    gj = json.load(f)
polygonObj = gj['features'][0]['geometry']
#print(json.dumps(polygonObj, indent=2))
json.dumps(polygonObj)
# Out:
# '{"type": "Polygon", "coordinates": [[[-8.660301612151732, 40.4315075431546], [-8.66053907486046, 40.431260735152], [-8.660949176943323, 40.430899799383106], [-8.661204181614954, 40.43073541887656], [-8.661658357838686, 40.43054837109378], [-8.662069645427959, 40.430339752455346], [-8.66259560000015, 40.43022853537632], [-8.66305036910212, 40.43011764223161], [-8.663619047329236, 40.43000621474466], [-8.66418939424523, 40.43002745522196], [-8.664184476261733, 40.430228764374064], [-8.664199436630817, 40.43047470964581], [-8.66421739146174, 40.4306908249562], [-8.664264244940565, 40.431478348248774], [-8.664317768932486, 40.43228820943088], [-8.66434836511466, 40.432630839228764], [-8.664377562957586, 40.43280518406885], [-8.664417729439094, 40.43295677662079], [-8.664461350914616, 40.43307715115458], [-8.664623660830907, 40.43354025469144], [-8.664778570798555, 40.43400621970573], [-8.664944562787511, 40.434465055200214], [-8.665103133091787, 40.43492534743139], [-8.665269141935305, 
# ...

# %%
gj.keys()
# centroid(gj['features'][0]
# Out:
# dict_keys(['type', 'features'])

# %%
# -----------------------  GEOJSON  ----------------------#
import geopandas as gpd
vagos = gpd.read_file('../data_gettin/vagos.geojson');

#for index, row in vagos.iterrows():
    # centroids.append(row.geometry.centroid)
    # print(row.geometry.centroid.x)
# Out:
# -8.66377668296862
# -8.667266486223651
# -8.762815602291013
# -8.764141525766831
# -8.761782210224224
# -8.762049921724474
# -8.742376902561267
# -8.748642886216743
# -8.759863961411654
# -8.716327217900835
# -8.690630621526843
# -8.688997639405068
# -8.687761244402779
# -8.686066040871214
# -8.671836368711876
# -8.684470918011062
# -8.687153559439174
# -8.689030544435754
# -8.671947973431696
# -8.686069364314765
# -8.67537725889719
# -8.688072569219758
# -8.690609013605036
# -8.676091645176031
# -8.689500012931372
# -8.673966718271844
# -8.680481158398518
# -8.67734779028947
# -8.683983809374851
# -8.687020581143205
# -8.6876582342777
# -8.671870255262075
# -8.64488511656482
# -8.641215469203896
# -8.686055328801158
# -8.678442618910191
# -8.644710961022746
# -8.689153186925095
# -8.691798131440605
# -8.665389482872587
# -8.683584463279221
# -8.692646893776407
# -8.640232305611313
# -8.689452208761681
# -8.657758280992079
# -8.643826767901757
# -8.650940335840428
# ...

# %%
centroids = vagos.centroid
#centroids.to_file('centroids.geojson', 'GeoJSON')

iteratorHandler = centroids.size
centroidVector = []
for centroid in centroids:
    obj = [centroid.xy[0][0], centroid.xy[1][0]]
    centroidVector.append(obj)

# %%
centroidVector
# Out:
# [[-8.66377668296862, 40.43498978403321],
#  [-8.667266486223651, 40.434720252768344],
#  [-8.762815602291013, 40.56397304188675],
#  [-8.764141525766831, 40.562949678516226],
#  [-8.761782210224224, 40.56368107940843],
#  [-8.762049921724474, 40.56379714921472],
#  [-8.742376902561267, 40.57696080731299],
#  [-8.748642886216743, 40.573450274781074],
#  [-8.759863961411654, 40.57320586179287],
#  [-8.716327217900835, 40.4775963570931],
#  [-8.690630621526843, 40.50413584930182],
#  [-8.688997639405068, 40.50654388167653],
#  [-8.687761244402779, 40.50684770589882],
#  [-8.686066040871214, 40.50796901218898],
#  [-8.671836368711876, 40.50576903457918],
#  [-8.684470918011062, 40.50300020685901],
#  [-8.687153559439174, 40.50789112786155],
#  [-8.689030544435754, 40.507955092095806],
#  [-8.671947973431696, 40.50870248053603],
#  [-8.686069364314765, 40.50891557287068],
#  [-8.67537725889719, 40.506690506352165],
#  [-8.688072569219758, 40.50904139035364],
# ...

# %%
import geojson
import tempfile

def write_json(self, features):
   # feature is a shapely geometry type
   geom_in_geojson = geojson.Feature(geometry=features, properties={})
   tmp_file = tempfile.mkstemp(suffix='.geojson')
   with open(tmp_file[1], 'w') as outfile:
      geojson.dump(geom_in_geojson, outfile)
   return tmp_file[1]

# %%
import fiona; fiona.supported_drivers
# Out:
# {'AeronavFAA': 'r',
#  'ARCGEN': 'r',
#  'BNA': 'raw',
#  'DXF': 'raw',
#  'OpenFileGDB': 'r',
#  'ESRI Shapefile': 'raw',
#  'GeoJSON': 'rw',
#  'GPKG': 'rw',
#  'GPX': 'raw',
#  'GPSTrackMaker': 'raw',
#  'Idrisi': 'r',
#  'MapInfo File': 'raw',
#  'DGN': 'raw',
#  'PCIDSK': 'r',
#  'SEGY': 'r',
#  'SUA': 'r'}

# %%
import shapefile

# %%
sf = shapefile.Reader('../subseccao_vagos/Subseccao_vagos')
subsecoes = sf.shapeRecords()

# %%
# Out:
# -8.66377668296862
# -8.667266486223651
# -8.762815602291013
# -8.764141525766831
# -8.761782210224224
# -8.762049921724474
# -8.742376902561267
# -8.748642886216743
# -8.759863961411654
# -8.716327217900835
# -8.690630621526843
# -8.688997639405068
# -8.687761244402779
# -8.686066040871214
# -8.671836368711876
# -8.684470918011062
# -8.687153559439174
# -8.689030544435754
# -8.671947973431696
# -8.686069364314765
# -8.67537725889719
# -8.688072569219758
# -8.690609013605036
# -8.676091645176031
# -8.689500012931372
# -8.673966718271844
# -8.680481158398518
# -8.67734779028947
# -8.683983809374851
# -8.687020581143205
# -8.6876582342777
# -8.671870255262075
# -8.64488511656482
# -8.641215469203896
# -8.686055328801158
# -8.678442618910191
# -8.644710961022746
# -8.689153186925095
# -8.691798131440605
# -8.665389482872587
# -8.683584463279221
# -8.692646893776407
# -8.640232305611313
# -8.689452208761681
# -8.657758280992079
# -8.643826767901757
# -8.650940335840428
# ...

# %%
centroidVector
# Out:
# [[-8.66377668296862, 40.43498978403321],
#  [-8.667266486223651, 40.434720252768344],
#  [-8.762815602291013, 40.56397304188675],
#  [-8.764141525766831, 40.562949678516226],
#  [-8.761782210224224, 40.56368107940843],
#  [-8.762049921724474, 40.56379714921472],
#  [-8.742376902561267, 40.57696080731299],
#  [-8.748642886216743, 40.573450274781074],
#  [-8.759863961411654, 40.57320586179287],
#  [-8.716327217900835, 40.4775963570931],
#  [-8.690630621526843, 40.50413584930182],
#  [-8.688997639405068, 40.50654388167653],
#  [-8.687761244402779, 40.50684770589882],
#  [-8.686066040871214, 40.50796901218898],
#  [-8.671836368711876, 40.50576903457918],
#  [-8.684470918011062, 40.50300020685901],
#  [-8.687153559439174, 40.50789112786155],
#  [-8.689030544435754, 40.507955092095806],
#  [-8.671947973431696, 40.50870248053603],
#  [-8.686069364314765, 40.50891557287068],
#  [-8.67537725889719, 40.506690506352165],
#  [-8.688072569219758, 40.50904139035364],
# ...

# %%
centroids.size
# Out:
# 693
